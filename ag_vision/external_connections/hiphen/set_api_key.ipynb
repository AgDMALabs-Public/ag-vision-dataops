# %%
from databricks.sdk import WorkspaceClient
w = WorkspaceClient()
w.secrets.create_scope("hiphen")

# %%
w.secrets.put_secret("hiphen",
                     "hiphen-api-key",
                     string_value="PUT SECRETE HERE")

# %%
client_secret = dbutils.secrets.get(scope="hiphen",
                                    key="hiphen-api-key")
