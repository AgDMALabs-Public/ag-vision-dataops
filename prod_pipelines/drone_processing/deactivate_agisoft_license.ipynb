# %% [markdown]
# # Task: deactivate_license

# %%
import Metashape

if Metashape.license.valid:
    Metashape.license.deactivate()
    print("Metashape license deactivated")
else:
    print("No active Metashape license to deactivate")
# Out:
# No active Metashape license to deactivate
