# %% [markdown]
# # Databricks Host and Token
# ### The Personal Access Token is used to authenticate your SDK calls. It's a secret key, so treat it like a password!
# 1. In your Databricks workspace, click your username in the top-right corner.
# 2. Select Settings.
# 3. Click the Developer tab.
# 4. Next to Access tokens, click Manage.
# 5. Click the Generate new token button.
# 6. Enter a Comment (e.g., "SDK Access") and set a Lifetime for the token (the recommended practice is to set an expiration date).
# 7. Click Generate.
# 8. Immediately copy the displayed token. This is the only time Databricks will show you the token. If you lose it, you'll have to generate a new one.
# 9. Add them to the databricksconfig file generated by the cli install.

# %% [markdown]
# # Notes
# * The data uplaoding is for one flight and one camera.
# * If you have multiple cameras upload them as separate events and change the CAMERA_TYPE variable.
# * This is just an example if you have lots of stuff to upload feel free build your own script to upload many events in series.
# * Please following the data standards tho. This will make it run smoothly through the pipelines being built by CIAT COLOMBIA and others.

# %%
from uuid import uuid4
import os
import pandas as pd
from databricks.sdk import WorkspaceClient

from ag_vision.drone.ingest import DroneDataIngest

# %%
w = WorkspaceClient() # If you only have one profile called default it will automatcally call that one
w.config.host
# Out:
# 'https://dbc-0f3d94f2-e27b.cloud.databricks.com'

# %% [markdown]
# # Set the Variables below along with Metadata

# %%
FLIGHT_DATE = '11/25/2025'

YEAR = 2025
COUNTRY = 'IND' # Three letter coutry code.
CROP = 'maize'
CROP_GROWTH_STAGE = 'VT'
SEASON = 'spring'

TRIAL_NAME = 'BETS'
SITE = 'TNAU-Coimbatore-1'
FIELD = 'West_Field_03'
LOCATION = 'Section_B'

MISSION_NAME = 'corn_health_assessment_flight'
CAMERA_TYPE = 'multi-spec' # can be rgb or multi-spec

# Set this to your DB Volume you want to upload to. If your workspace is brand new you will need to create a volume.
DB_VOLUME = "/Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data" # EX: '/Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data'

# these are the paths to the specific data types. You will need to change based on how you have the data structured.
LOCAL_DATA_DIR = "/Users/danielwilliams/Documents/Field Data/drone_upload_test" # EX: '/Users/danielwilliams/Documents/Field Data/drone_upload_test'
RAW_IMAGES_DIR = f'{LOCAL_DATA_DIR}/raw_flight_data/'
PLOT_BOUNDARY_FILE = f"{LOCAL_DATA_DIR}/plot_boundary.geojson"
GROUND_CONTROL_PT_FILE = f"{LOCAL_DATA_DIR}/gcp_details.geojson"
ORTHOMOSAIC_FILE = f"{LOCAL_DATA_DIR}/30112024_ORTHO.tif"
DEM_FILE = f"{LOCAL_DATA_DIR}/30112024_DSM.tif"

ORTHO_METHOD = 'agisoft'
ORTHO_DATE = '11/25/2024'


flight_metadata = {
    "id": str(uuid4()),
    "name": MISSION_NAME,
    "task": "drone_phenotyping",
    "location": {
        "site": SITE.lower(),  # Try to keep these standard ORG-Site EX CIAT-Cali, or CIAT-Arusha....
        "field": FIELD.lower(),
        # what is the name of the field that the trial was run on? The field and location can be the same name if there is no difference.
        "location": LOCATION.lower()
        # The location corresponds to a specific field book. If data is in EBS match the location name.
    },
    "trialProperties": {
        "name": TRIAL_NAME
    },
    "drone_acquisition_properties": {
        'date': FLIGHT_DATE,
        'drone_make': "DJI",
        'drone_model': "Phantom Mavic 4 Enterprise",
        'camera_make': "Sony",
        'camera_model': "UCM-R",
        'groundControlPoints': True,
        'reflectancePanels': True,
        'reflectancePanelType': 'Micasense',
        'flightHeight': 90.0,
        'horizontalOverlapPercentage': 75.0,
        'verticalOverlapPercentage': 75.0,
        'gpsQuality': "RTK",
        'multispecChannels': ["Red", "Green", "Blue", "NIR"]
    },
    "agronomic_properties": {
        "crop_type": CROP,  # Required
        "growth_stage": CROP_GROWTH_STAGE,  # optional
        "soil_color": None,
        "weed_pressure": None,
        "irrigation_level": None,
        "tillage_type": None,
        "fertilizer_level": None
    }
}

# %% [markdown]
# # You should not need to change anything below this. All variables were set above.

# %% [markdown]
# # List out the flight data to upload.

# %%
files = os.listdir(RAW_IMAGES_DIR)
files = [RAW_IMAGES_DIR + x for x in files]
print(f"Number of files found {len(files)}")
# Out:
# Number of files found 81

# %% [markdown]
# # Start of the ingest process.

# %%
ingest = DroneDataIngest(platform='local',  # DONT CHANGE THIS
                         cloud_bucket=DB_VOLUME,
                         cloud_client=w, # should not need to change.
                         flight_date=FLIGHT_DATE,
                         plot_boundary_key=PLOT_BOUNDARY_FILE,
                         gcp_key=GROUND_CONTROL_PT_FILE,
                         orthomosaic_key=ORTHOMOSAIC_FILE,
                         dem_key=DEM_FILE,
                         flight_metadata_key=f"{LOCAL_DATA_DIR}/flight_details.json")

# %%
ingest.load_metadata_from_dict(metadata_dict=flight_metadata)

# season is needed to generate the mission dir, This has lots of Validation and will throw assert errors.
ingest.add_season_code_to_metadata(year=YEAR,
                                   country=COUNTRY,
                                   crop=CROP,
                                   time_of_year=SEASON)

# This is the main dir where all the data will be stored.
ingest.generate_drone_mission_dir_path()

# %%
# This saves the metadata locally do it can be uploaded.
ingest.save_flight_metadata_to_json_local()

# %%
# This will be a list of all the raw files from the flight eg: nav, bin, tif, and jpg files.
ingest.generate_raw_ingest_df(file_list=files)

# %%
ingest.raw_ingest_df['camera'] = CAMERA_TYPE

# %%
# generates the new path names where to save it in databricks
ingest.generate_raw_image_dst_path_name()

# %%
# Upload the metadata to databricks
ingest.upload_metadata_to_db()
# Out:
# Uploading: 100%|██████████| 1.65k/1.65k [00:01<00:00, 1.11kB/s]

# %%
# uploads the plot boundaries to databricks
ingest.upload_plot_boundary_to_db()
# Out:
# Saving to /Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data/tnau-coimbatore-1/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/plot_boundary.geojson
# Uploading: 100%|██████████| 190k/190k [00:00<00:00, 310kB/s]

# %%
# Uploads the ground control points to databricks
ingest.upload_gcp_to_db()
# Out:
# Saving to /Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data/tnau-coimbatore-1/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/ground_control_points.geojson
# Uploading: 100%|██████████| 1.28k/1.28k [00:00<00:00, 1.68kB/s]

# %%
# uploads all the raw flight data to databricks
ingest.upload_raw_flight_data_to_db()
# Out:
# 0it [00:00, ?it/s]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   1%|▏         | 144k/9.62M [00:00<00:07, 1.39MB/s]
# Uploading:   3%|▎         | 288k/9.62M [00:00<00:07, 1.32MB/s]
# Uploading:   6%|▌         | 544k/9.62M [00:00<00:06, 1.41MB/s]
# Uploading:   8%|▊         | 816k/9.62M [00:00<00:05, 1.82MB/s]
# Uploading:  10%|█         | 0.98M/9.62M [00:00<00:05, 1.78MB/s]
# Uploading:  15%|█▌        | 1.48M/9.62M [00:00<00:03, 2.71MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:00<00:01, 4.62MB/s]
# Uploading:  35%|███▌      | 3.39M/9.62M [00:00<00:01, 6.23MB/s]
# Uploading:  47%|████▋     | 4.53M/9.62M [00:01<00:00, 7.82MB/s]
# Uploading:  57%|█████▋    | 5.44M/9.62M [00:01<00:00, 8.15MB/s]
# Uploading:  65%|██████▍   | 6.23M/9.62M [00:01<00:00, 6.54MB/s]
# Uploading:  72%|███████▏  | 6.92M/9.62M [00:01<00:00, 5.48MB/s]
# Uploading:  78%|███████▊  | 7.52M/9.62M [00:01<00:00, 4.98MB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:07<00:04, 375kB/s]
# Uploading:  88%|████████▊ | 8.42M/9.62M [00:07<00:02, 427kB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:08<00:01, 491kB/s]
# Uploading:  93%|█████████▎| 8.97M/9.62M [00:08<00:01, 542kB/s]
# Uploading:  95%|█████████▌| 9.17M/9.62M [00:08<00:00, 594kB/s]
# Uploading:  97%|█████████▋| 9.34M/9.62M [00:08<00:00, 620kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:09<00:00, 1.05MB/s][A
# 1it [00:09,  9.59s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   3%|▎         | 304k/9.62M [00:00<00:03, 3.03MB/s]
# Uploading:   6%|▌         | 608k/9.62M [00:00<00:05, 1.66MB/s]
# Uploading:   8%|▊         | 816k/9.62M [00:00<00:05, 1.71MB/s]
# Uploading:  10%|█         | 0.98M/9.62M [00:00<00:06, 1.45MB/s]
# Uploading:  12%|█▏        | 1.14M/9.62M [00:00<00:06, 1.40MB/s]
# Uploading:  13%|█▎        | 1.30M/9.62M [00:00<00:06, 1.45MB/s]
# Uploading:  15%|█▌        | 1.47M/9.62M [00:00<00:05, 1.54MB/s]
# Uploading:  17%|█▋        | 1.64M/9.62M [00:01<00:05, 1.61MB/s]
# Uploading:  19%|█▉        | 1.84M/9.62M [00:01<00:04, 1.75MB/s]
# Uploading:  21%|██        | 2.03M/9.62M [00:01<00:05, 1.36MB/s]
# Uploading:  24%|██▎       | 2.27M/9.62M [00:01<00:04, 1.60MB/s]
# Uploading:  26%|██▌       | 2.48M/9.62M [00:01<00:04, 1.76MB/s]
# Uploading:  29%|██▊       | 2.75M/9.62M [00:01<00:03, 2.02MB/s]
# Uploading:  31%|███       | 2.97M/9.62M [00:01<00:03, 1.99MB/s]
# Uploading:  33%|███▎      | 3.17M/9.62M [00:01<00:03, 1.94MB/s]
# Uploading:  35%|███▌      | 3.38M/9.62M [00:02<00:03, 1.95MB/s]
# Uploading:  39%|███▊      | 3.72M/9.62M [00:02<00:02, 2.36MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:02<00:02, 2.05MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:02<00:02, 2.41MB/s]
# Uploading:  48%|████▊     | 4.64M/9.62M [00:02<00:02, 2.49MB/s]
# Uploading:  51%|█████▏    | 4.95M/9.62M [00:02<00:01, 2.68MB/s]
# Uploading:  55%|█████▍    | 5.25M/9.62M [00:02<00:01, 2.79MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.76MB/s]
# Uploading:  60%|██████    | 5.81M/9.62M [00:02<00:01, 2.79MB/s]
# Uploading:  64%|██████▍   | 6.14M/9.62M [00:03<00:01, 2.96MB/s]
# Uploading:  67%|██████▋   | 6.48M/9.62M [00:03<00:01, 3.14MB/s]
# Uploading:  72%|███████▏  | 6.91M/9.62M [00:03<00:00, 3.51MB/s]
# Uploading:  75%|███████▌  | 7.25M/9.62M [00:03<00:00, 3.34MB/s]
# Uploading:  79%|███████▉  | 7.59M/9.62M [00:03<00:00, 3.34MB/s]
# Uploading:  83%|████████▎ | 8.03M/9.62M [00:03<00:00, 3.68MB/s]
# Uploading:  88%|████████▊ | 8.45M/9.62M [00:03<00:00, 3.80MB/s]
# Uploading:  92%|█████████▏| 8.83M/9.62M [00:04<00:00, 1.70MB/s]
# Uploading:  96%|█████████▌| 9.23M/9.62M [00:04<00:00, 1.83MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.90MB/s]
# 2it [00:14,  7.08s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   3%|▎         | 256k/9.62M [00:00<00:16, 613kB/s]
# Uploading:   3%|▎         | 320k/9.62M [00:00<00:21, 447kB/s]
# Uploading:   4%|▍         | 416k/9.62M [00:00<00:17, 553kB/s]
# Uploading:   9%|▊         | 848k/9.62M [00:00<00:06, 1.42MB/s]
# Uploading:  12%|█▏        | 1.12M/9.62M [00:00<00:04, 1.80MB/s]
# Uploading:  15%|█▍        | 1.42M/9.62M [00:01<00:04, 2.11MB/s]
# Uploading:  17%|█▋        | 1.67M/9.62M [00:01<00:03, 2.18MB/s]
# Uploading:  20%|█▉        | 1.92M/9.62M [00:01<00:03, 2.09MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:01<00:03, 2.34MB/s]
# Uploading:  26%|██▌       | 2.48M/9.62M [00:01<00:03, 2.32MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:01<00:03, 2.07MB/s]
# Uploading:  31%|███       | 3.00M/9.62M [00:01<00:03, 2.21MB/s]
# Uploading:  34%|███▍      | 3.30M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  37%|███▋      | 3.59M/9.62M [00:02<00:02, 2.54MB/s]
# Uploading:  40%|████      | 3.86M/9.62M [00:02<00:02, 2.03MB/s]
# Uploading:  43%|████▎     | 4.16M/9.62M [00:02<00:02, 2.28MB/s]
# Uploading:  46%|████▌     | 4.41M/9.62M [00:02<00:02, 2.27MB/s]
# Uploading:  49%|████▉     | 4.72M/9.62M [00:02<00:02, 2.51MB/s]
# Uploading:  52%|█████▏    | 4.98M/9.62M [00:02<00:02, 2.02MB/s]
# Uploading:  54%|█████▍    | 5.22M/9.62M [00:02<00:02, 2.12MB/s]
# Uploading:  57%|█████▋    | 5.52M/9.62M [00:02<00:01, 2.32MB/s]
# Uploading:  61%|██████    | 5.83M/9.62M [00:03<00:01, 2.56MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:03<00:01, 2.51MB/s]
# Uploading:  66%|██████▌   | 6.36M/9.62M [00:03<00:01, 2.55MB/s]
# Uploading:  69%|██████▉   | 6.62M/9.62M [00:03<00:01, 2.20MB/s]
# Uploading:  71%|███████▏  | 6.86M/9.62M [00:03<00:01, 2.25MB/s]
# Uploading:  74%|███████▎  | 7.09M/9.62M [00:03<00:01, 2.25MB/s]
# Uploading:  76%|███████▌  | 7.33M/9.62M [00:03<00:01, 2.09MB/s]
# Uploading:  78%|███████▊  | 7.55M/9.62M [00:03<00:01, 2.04MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading:  84%|████████▍ | 8.11M/9.62M [00:04<00:00, 2.39MB/s]
# Uploading:  87%|████████▋ | 8.41M/9.62M [00:04<00:00, 2.08MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:04<00:00, 2.36MB/s]
# Uploading:  94%|█████████▎| 9.00M/9.62M [00:04<00:00, 2.49MB/s]
# Uploading:  97%|█████████▋| 9.34M/9.62M [00:04<00:00, 2.76MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.83MB/s]
# 3it [00:20,  6.37s/it]
# Uploading:   0%|          | 0.00/4.96M [00:00<?, ?B/s]
# Uploading:   9%|▊         | 416k/4.73M [00:00<00:01, 3.96MB/s]
# Uploading:  17%|█▋        | 816k/4.73M [00:00<00:01, 3.54MB/s]
# Uploading:  24%|██▍       | 1.14M/4.73M [00:00<00:01, 2.76MB/s]
# Uploading:  30%|███       | 1.42M/4.73M [00:00<00:01, 2.23MB/s]
# Uploading:  35%|███▌      | 1.67M/4.73M [00:00<00:01, 2.32MB/s]
# Uploading:  41%|████      | 1.94M/4.73M [00:00<00:01, 2.36MB/s]
# Uploading:  46%|████▌     | 2.17M/4.73M [00:00<00:01, 2.23MB/s]
# Uploading:  51%|█████     | 2.39M/4.73M [00:01<00:01, 2.13MB/s]
# Uploading:  56%|█████▌    | 2.66M/4.73M [00:01<00:00, 2.28MB/s]
# Uploading:  62%|██████▏   | 2.95M/4.73M [00:01<00:00, 2.48MB/s]
# Uploading:  68%|██████▊   | 3.20M/4.73M [00:01<00:00, 2.48MB/s]
# Uploading:  74%|███████▎  | 3.48M/4.73M [00:01<00:00, 2.14MB/s]
# Uploading:  80%|███████▉  | 3.77M/4.73M [00:01<00:00, 2.32MB/s]
# Uploading:  85%|████████▌ | 4.03M/4.73M [00:01<00:00, 2.42MB/s]
# Uploading:  92%|█████████▏| 4.34M/4.73M [00:01<00:00, 2.42MB/s]
# Uploading: 100%|██████████| 4.73M/4.73M [00:02<00:00, 1.98MB/s]
# 4it [00:22,  4.85s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▋         | 624k/9.62M [00:00<00:01, 6.17MB/s]
# Uploading:  13%|█▎        | 1.20M/9.62M [00:00<00:02, 3.75MB/s]
# Uploading:  17%|█▋        | 1.61M/9.62M [00:00<00:02, 2.91MB/s]
# Uploading:  20%|█▉        | 1.92M/9.62M [00:00<00:02, 2.83MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:00<00:02, 2.84MB/s]
# Uploading:  26%|██▋       | 2.53M/9.62M [00:00<00:02, 2.91MB/s]
# Uploading:  29%|██▉       | 2.83M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  32%|███▏      | 3.08M/9.62M [00:01<00:05, 1.22MB/s]
# Uploading:  36%|███▌      | 3.45M/9.62M [00:01<00:04, 1.60MB/s]
# Uploading:  38%|███▊      | 3.70M/9.62M [00:01<00:03, 1.70MB/s]
# Uploading:  41%|████      | 3.94M/9.62M [00:01<00:03, 1.81MB/s]
# Uploading:  43%|████▎     | 4.17M/9.62M [00:02<00:03, 1.65MB/s]
# Uploading:  45%|████▌     | 4.38M/9.62M [00:02<00:03, 1.70MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:02<00:03, 1.74MB/s]
# Uploading:  50%|█████     | 4.84M/9.62M [00:02<00:02, 1.94MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:02<00:02, 1.64MB/s]
# Uploading:  56%|█████▌    | 5.34M/9.62M [00:02<00:02, 1.95MB/s]
# Uploading:  58%|█████▊    | 5.58M/9.62M [00:02<00:02, 2.06MB/s]
# Uploading:  61%|██████    | 5.86M/9.62M [00:02<00:01, 2.26MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:03<00:01, 2.26MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:03<00:01, 1.83MB/s]
# Uploading:  69%|██████▊   | 6.61M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  72%|███████▏  | 6.89M/9.62M [00:03<00:01, 2.15MB/s]
# Uploading:  74%|███████▍  | 7.11M/9.62M [00:03<00:01, 2.16MB/s]
# Uploading:  76%|███████▋  | 7.36M/9.62M [00:03<00:01, 1.86MB/s]
# Uploading:  79%|███████▉  | 7.58M/9.62M [00:03<00:01, 1.92MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:03<00:00, 2.07MB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:04<00:00, 2.11MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:04<00:00, 1.97MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:04<00:00, 1.92MB/s]
# Uploading:  90%|█████████ | 8.67M/9.62M [00:04<00:00, 1.95MB/s]
# Uploading:  93%|█████████▎| 8.95M/9.62M [00:04<00:00, 2.18MB/s]
# Uploading:  95%|█████████▌| 9.17M/9.62M [00:04<00:00, 1.84MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.89MB/s]
# 5it [00:28,  5.02s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 560k/9.62M [00:00<00:01, 5.37MB/s]
# Uploading:  11%|█         | 1.06M/9.62M [00:00<00:02, 3.33MB/s]
# Uploading:  15%|█▍        | 1.42M/9.62M [00:00<00:03, 2.46MB/s]
# Uploading:  18%|█▊        | 1.70M/9.62M [00:00<00:03, 2.45MB/s]
# Uploading:  20%|██        | 1.97M/9.62M [00:00<00:03, 2.48MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:00<00:03, 2.05MB/s]
# Uploading:  25%|██▌       | 2.44M/9.62M [00:01<00:03, 2.06MB/s]
# Uploading:  28%|██▊       | 2.67M/9.62M [00:01<00:03, 2.15MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:01<00:03, 2.25MB/s]
# Uploading:  33%|███▎      | 3.19M/9.62M [00:01<00:02, 2.38MB/s]
# Uploading:  36%|███▌      | 3.42M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  38%|███▊      | 3.66M/9.62M [00:01<00:02, 2.12MB/s]
# Uploading:  40%|████      | 3.88M/9.62M [00:01<00:02, 2.14MB/s]
# Uploading:  43%|████▎     | 4.09M/9.62M [00:01<00:02, 2.10MB/s]
# Uploading:  45%|████▍     | 4.31M/9.62M [00:02<00:03, 1.85MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:02<00:02, 2.06MB/s]
# Uploading:  50%|█████     | 4.81M/9.62M [00:02<00:02, 2.16MB/s]
# Uploading:  53%|█████▎    | 5.08M/9.62M [00:02<00:02, 2.33MB/s]
# Uploading:  55%|█████▌    | 5.31M/9.62M [00:02<00:04, 1.06MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:02<00:02, 1.46MB/s]
# Uploading:  61%|██████▏   | 5.91M/9.62M [00:03<00:02, 1.39MB/s]
# Uploading:  64%|██████▎   | 6.11M/9.62M [00:03<00:02, 1.51MB/s]
# Uploading:  66%|██████▌   | 6.31M/9.62M [00:03<00:02, 1.61MB/s]
# Uploading:  68%|██████▊   | 6.56M/9.62M [00:03<00:01, 1.82MB/s]
# Uploading:  70%|███████   | 6.78M/9.62M [00:03<00:01, 1.58MB/s]
# Uploading:  73%|███████▎  | 7.03M/9.62M [00:03<00:01, 1.78MB/s]
# Uploading:  76%|███████▌  | 7.28M/9.62M [00:03<00:01, 1.95MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:03<00:01, 2.03MB/s]
# Uploading:  80%|████████  | 7.72M/9.62M [00:04<00:01, 1.98MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:04<00:00, 1.97MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:04<00:00, 2.05MB/s]
# Uploading:  87%|████████▋ | 8.38M/9.62M [00:04<00:00, 2.16MB/s]
# Uploading:  89%|████████▉ | 8.59M/9.62M [00:04<00:00, 2.17MB/s]
# Uploading:  92%|█████████▏| 8.81M/9.62M [00:04<00:00, 2.14MB/s]
# Uploading:  94%|█████████▍| 9.03M/9.62M [00:04<00:00, 2.03MB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:04<00:00, 2.19MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.69MB/s]
# 6it [00:34,  5.35s/it]
# Uploading:   0%|          | 0.00/7.43M [00:00<?, ?B/s]
# Uploading:   8%|▊         | 560k/7.08M [00:00<00:01, 5.57MB/s]
# Uploading:  15%|█▌        | 1.08M/7.08M [00:00<00:02, 3.04MB/s]
# Uploading:  20%|██        | 1.44M/7.08M [00:00<00:02, 2.61MB/s]
# Uploading:  24%|██▍       | 1.72M/7.08M [00:00<00:02, 2.57MB/s]
# Uploading:  28%|██▊       | 2.00M/7.08M [00:00<00:02, 2.09MB/s]
# Uploading:  32%|███▏      | 2.23M/7.08M [00:00<00:02, 2.14MB/s]
# Uploading:  36%|███▌      | 2.52M/7.08M [00:01<00:02, 2.31MB/s]
# Uploading:  40%|███▉      | 2.81M/7.08M [00:01<00:02, 2.00MB/s]
# Uploading:  44%|████▍     | 3.14M/7.08M [00:01<00:01, 2.30MB/s]
# Uploading:  48%|████▊     | 3.41M/7.08M [00:01<00:01, 2.39MB/s]
# Uploading:  52%|█████▏    | 3.70M/7.08M [00:01<00:01, 2.55MB/s]
# Uploading:  57%|█████▋    | 4.02M/7.08M [00:01<00:01, 2.11MB/s]
# Uploading:  60%|██████    | 4.28M/7.08M [00:01<00:01, 2.25MB/s]
# Uploading:  64%|██████▍   | 4.56M/7.08M [00:01<00:01, 2.41MB/s]
# Uploading:  69%|██████▊   | 4.86M/7.08M [00:02<00:00, 2.54MB/s]
# Uploading:  72%|███████▏  | 5.12M/7.08M [00:02<00:00, 2.51MB/s]
# Uploading:  76%|███████▌  | 5.38M/7.08M [00:02<00:00, 2.44MB/s]
# Uploading:  79%|███████▉  | 5.62M/7.08M [00:02<00:00, 2.12MB/s]
# Uploading:  83%|████████▎ | 5.91M/7.08M [00:02<00:00, 2.32MB/s]
# Uploading:  87%|████████▋ | 6.17M/7.08M [00:02<00:00, 2.41MB/s]
# Uploading:  91%|█████████ | 6.42M/7.08M [00:02<00:00, 2.24MB/s]
# Uploading:  94%|█████████▍| 6.66M/7.08M [00:02<00:00, 2.28MB/s]
# Uploading: 100%|██████████| 7.08M/7.08M [00:03<00:00, 2.07MB/s]
# 7it [00:37,  4.77s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 592k/9.62M [00:00<00:01, 5.95MB/s]
# Uploading:  12%|█▏        | 1.16M/9.62M [00:00<00:02, 2.97MB/s]
# Uploading:  16%|█▌        | 1.52M/9.62M [00:00<00:02, 2.87MB/s]
# Uploading:  19%|█▉        | 1.83M/9.62M [00:00<00:02, 2.84MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:00<00:03, 2.35MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:00<00:02, 2.52MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:01<00:02, 2.63MB/s]
# Uploading:  32%|███▏      | 3.05M/9.62M [00:01<00:02, 2.79MB/s]
# Uploading:  35%|███▍      | 3.33M/9.62M [00:01<00:02, 2.71MB/s]
# Uploading:  38%|███▊      | 3.61M/9.62M [00:01<00:02, 2.28MB/s]
# Uploading:  41%|████      | 3.92M/9.62M [00:01<00:02, 2.51MB/s]
# Uploading:  44%|████▎     | 4.19M/9.62M [00:01<00:02, 2.50MB/s]
# Uploading:  47%|████▋     | 4.48M/9.62M [00:01<00:02, 2.62MB/s]
# Uploading:  49%|████▉     | 4.75M/9.62M [00:01<00:01, 2.56MB/s]
# Uploading:  52%|█████▏    | 5.02M/9.62M [00:02<00:02, 2.41MB/s]
# Uploading:  55%|█████▍    | 5.27M/9.62M [00:02<00:01, 2.45MB/s]
# Uploading:  58%|█████▊    | 5.58M/9.62M [00:02<00:03, 1.29MB/s]
# Uploading:  63%|██████▎   | 6.03M/9.62M [00:02<00:02, 1.83MB/s]
# Uploading:  65%|██████▌   | 6.30M/9.62M [00:02<00:01, 1.97MB/s]
# Uploading:  68%|██████▊   | 6.56M/9.62M [00:03<00:01, 1.76MB/s]
# Uploading:  71%|███████   | 6.81M/9.62M [00:03<00:01, 1.92MB/s]
# Uploading:  74%|███████▎  | 7.08M/9.62M [00:03<00:01, 2.09MB/s]
# Uploading:  76%|███████▋  | 7.34M/9.62M [00:03<00:01, 2.25MB/s]
# Uploading:  79%|███████▉  | 7.59M/9.62M [00:03<00:00, 2.23MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:03<00:00, 2.14MB/s]
# Uploading:  84%|████████▍ | 8.09M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  87%|████████▋ | 8.36M/9.62M [00:03<00:00, 2.19MB/s]
# Uploading:  89%|████████▉ | 8.59M/9.62M [00:04<00:00, 1.19MB/s]
# Uploading:  93%|█████████▎| 8.94M/9.62M [00:04<00:00, 1.58MB/s]
# Uploading:  95%|█████████▌| 9.17M/9.62M [00:04<00:00, 1.66MB/s]
# Uploading:  98%|█████████▊| 9.39M/9.62M [00:04<00:00, 1.74MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.93MB/s]
# 8it [00:43,  4.91s/it]
# Uploading:   0%|          | 0.00/7.26M [00:00<?, ?B/s]
# Uploading:   7%|▋         | 464k/6.92M [00:00<00:01, 4.40MB/s]
# Uploading:  13%|█▎        | 896k/6.92M [00:00<00:03, 1.99MB/s]
# Uploading:  16%|█▋        | 1.14M/6.92M [00:00<00:02, 2.10MB/s]
# Uploading:  20%|██        | 1.39M/6.92M [00:00<00:02, 2.17MB/s]
# Uploading:  23%|██▎       | 1.62M/6.92M [00:00<00:03, 1.79MB/s]
# Uploading:  27%|██▋       | 1.86M/6.92M [00:00<00:02, 1.91MB/s]
# Uploading:  30%|███       | 2.09M/6.92M [00:01<00:02, 2.03MB/s]
# Uploading:  33%|███▎      | 2.31M/6.92M [00:01<00:02, 2.07MB/s]
# Uploading:  37%|███▋      | 2.56M/6.92M [00:01<00:02, 2.20MB/s]
# Uploading:  40%|████      | 2.80M/6.92M [00:01<00:02, 1.81MB/s]
# Uploading:  43%|████▎     | 3.00M/6.92M [00:01<00:02, 1.87MB/s]
# Uploading:  47%|████▋     | 3.22M/6.92M [00:01<00:01, 1.96MB/s]
# Uploading:  49%|████▉     | 3.42M/6.92M [00:01<00:01, 1.97MB/s]
# Uploading:  52%|█████▏    | 3.62M/6.92M [00:01<00:01, 1.91MB/s]
# Uploading:  55%|█████▌    | 3.81M/6.92M [00:01<00:01, 1.91MB/s]
# Uploading:  58%|█████▊    | 4.03M/6.92M [00:02<00:01, 2.00MB/s]
# Uploading:  62%|██████▏   | 4.30M/6.92M [00:02<00:01, 2.20MB/s]
# Uploading:  65%|██████▌   | 4.52M/6.92M [00:02<00:01, 1.67MB/s]
# Uploading:  68%|██████▊   | 4.72M/6.92M [00:02<00:01, 1.77MB/s]
# Uploading:  71%|███████▏  | 4.94M/6.92M [00:02<00:01, 1.90MB/s]
# Uploading:  74%|███████▍  | 5.16M/6.92M [00:02<00:00, 1.95MB/s]
# Uploading:  79%|███████▊  | 5.44M/6.92M [00:02<00:00, 2.17MB/s]
# Uploading:  82%|████████▏ | 5.66M/6.92M [00:02<00:00, 2.18MB/s]
# Uploading:  85%|████████▍ | 5.88M/6.92M [00:03<00:00, 1.75MB/s]
# Uploading:  88%|████████▊ | 6.08M/6.92M [00:03<00:00, 1.84MB/s]
# Uploading:  91%|█████████ | 6.30M/6.92M [00:03<00:00, 1.92MB/s]
# Uploading:  94%|█████████▍| 6.50M/6.92M [00:03<00:00, 1.87MB/s]
# Uploading:  97%|█████████▋| 6.69M/6.92M [00:03<00:00, 1.86MB/s]
# Uploading: 100%|██████████| 6.92M/6.92M [00:04<00:00, 1.77MB/s]
# 9it [00:47,  4.66s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   5%|▌         | 528k/9.62M [00:00<00:01, 5.31MB/s]
# Uploading:  11%|█         | 1.03M/9.62M [00:00<00:03, 2.47MB/s]
# Uploading:  14%|█▍        | 1.34M/9.62M [00:00<00:03, 2.57MB/s]
# Uploading:  17%|█▋        | 1.64M/9.62M [00:00<00:03, 2.23MB/s]
# Uploading:  20%|█▉        | 1.89M/9.62M [00:00<00:03, 2.31MB/s]
# Uploading:  22%|██▏       | 2.14M/9.62M [00:00<00:03, 2.25MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:03, 1.97MB/s]
# Uploading:  27%|██▋       | 2.58M/9.62M [00:01<00:03, 1.86MB/s]
# Uploading:  29%|██▉       | 2.78M/9.62M [00:01<00:03, 1.92MB/s]
# Uploading:  31%|███       | 2.98M/9.62M [00:01<00:03, 1.87MB/s]
# Uploading:  33%|███▎      | 3.17M/9.62M [00:01<00:03, 1.84MB/s]
# Uploading:  35%|███▍      | 3.36M/9.62M [00:01<00:03, 1.81MB/s]
# Uploading:  37%|███▋      | 3.55M/9.62M [00:01<00:03, 1.64MB/s]
# Uploading:  39%|███▊      | 3.72M/9.62M [00:01<00:04, 1.49MB/s]
# Uploading:  41%|████▏     | 3.98M/9.62M [00:02<00:03, 1.78MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:02<00:02, 1.91MB/s]
# Uploading:  47%|████▋     | 4.48M/9.62M [00:02<00:02, 2.11MB/s]
# Uploading:  49%|████▉     | 4.70M/9.62M [00:02<00:02, 2.10MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:02<00:02, 1.86MB/s]
# Uploading:  54%|█████▍    | 5.22M/9.62M [00:02<00:02, 2.02MB/s]
# Uploading:  57%|█████▋    | 5.44M/9.62M [00:02<00:02, 2.07MB/s]
# Uploading:  59%|█████▉    | 5.70M/9.62M [00:02<00:01, 2.25MB/s]
# Uploading:  62%|██████▏   | 5.94M/9.62M [00:03<00:01, 2.16MB/s]
# Uploading:  64%|██████▍   | 6.16M/9.62M [00:03<00:01, 2.19MB/s]
# Uploading:  67%|██████▋   | 6.44M/9.62M [00:03<00:01, 2.36MB/s]
# Uploading:  70%|██████▉   | 6.70M/9.62M [00:03<00:01, 2.44MB/s]
# Uploading:  72%|███████▏  | 6.95M/9.62M [00:03<00:01, 2.44MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:01, 2.45MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  80%|████████  | 7.73M/9.62M [00:03<00:00, 2.45MB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:03<00:00, 2.66MB/s]
# Uploading:  87%|████████▋ | 8.33M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading:  90%|████████▉ | 8.64M/9.62M [00:04<00:00, 2.47MB/s]
# Uploading:  94%|█████████▎| 9.00M/9.62M [00:04<00:00, 2.80MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.02MB/s]
# 10it [00:52,  4.77s/it]
# Uploading:   0%|          | 0.00/8.22M [00:00<?, ?B/s]
# Uploading:   9%|▉         | 720k/7.84M [00:00<00:01, 6.01MB/s]
# Uploading:  16%|█▋        | 1.28M/7.84M [00:00<00:01, 4.95MB/s]
# Uploading:  23%|██▎       | 1.77M/7.84M [00:00<00:01, 4.32MB/s]
# Uploading:  28%|██▊       | 2.19M/7.84M [00:00<00:01, 3.99MB/s]
# Uploading:  33%|███▎      | 2.58M/7.84M [00:00<00:01, 3.85MB/s]
# Uploading:  38%|███▊      | 2.95M/7.84M [00:00<00:01, 3.16MB/s]
# Uploading:  43%|████▎     | 3.38M/7.84M [00:00<00:01, 3.47MB/s]
# Uploading:  48%|████▊     | 3.73M/7.84M [00:01<00:02, 1.79MB/s]
# Uploading:  53%|█████▎    | 4.14M/7.84M [00:01<00:01, 2.15MB/s]
# Uploading:  57%|█████▋    | 4.48M/7.84M [00:01<00:01, 2.09MB/s]
# Uploading:  61%|██████    | 4.75M/7.84M [00:02<00:02, 1.24MB/s]
# Uploading:  64%|██████▍   | 5.03M/7.84M [00:02<00:02, 1.45MB/s]
# Uploading:  67%|██████▋   | 5.25M/7.84M [00:02<00:01, 1.55MB/s]
# Uploading:  70%|██████▉   | 5.47M/7.84M [00:02<00:01, 1.58MB/s]
# Uploading:  72%|███████▏  | 5.67M/7.84M [00:02<00:01, 1.49MB/s]
# Uploading:  76%|███████▌  | 5.95M/7.84M [00:02<00:01, 1.76MB/s]
# Uploading:  79%|███████▊  | 6.17M/7.84M [00:02<00:00, 1.87MB/s]
# Uploading:  82%|████████▏ | 6.42M/7.84M [00:03<00:00, 2.03MB/s]
# Uploading:  85%|████████▌ | 6.69M/7.84M [00:03<00:00, 2.19MB/s]
# Uploading:  88%|████████▊ | 6.92M/7.84M [00:03<00:00, 2.20MB/s]
# Uploading:  91%|█████████▏| 7.16M/7.84M [00:03<00:00, 2.03MB/s]
# Uploading:  94%|█████████▍| 7.41M/7.84M [00:03<00:00, 2.17MB/s]
# Uploading: 100%|██████████| 7.84M/7.84M [00:04<00:00, 1.67MB/s]
# 11it [00:57,  4.81s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 576k/9.62M [00:00<00:01, 4.84MB/s]
# Uploading:  11%|█         | 1.03M/9.62M [00:00<00:02, 3.17MB/s]
# Uploading:  14%|█▍        | 1.36M/9.62M [00:00<00:02, 2.99MB/s]
# Uploading:  17%|█▋        | 1.66M/9.62M [00:00<00:03, 2.26MB/s]
# Uploading:  20%|█▉        | 1.92M/9.62M [00:00<00:03, 2.36MB/s]
# Uploading:  23%|██▎       | 2.20M/9.62M [00:00<00:03, 2.50MB/s]
# Uploading:  26%|██▌       | 2.47M/9.62M [00:00<00:02, 2.54MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:01<00:03, 2.32MB/s]
# Uploading:  31%|███       | 2.97M/9.62M [00:01<00:03, 2.28MB/s]
# Uploading:  34%|███▍      | 3.27M/9.62M [00:01<00:02, 2.50MB/s]
# Uploading:  37%|███▋      | 3.52M/9.62M [00:01<00:02, 2.15MB/s]
# Uploading:  39%|███▉      | 3.77M/9.62M [00:01<00:02, 2.26MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:01<00:02, 2.34MB/s]
# Uploading:  44%|████▍     | 4.25M/9.62M [00:01<00:02, 2.33MB/s]
# Uploading:  47%|████▋     | 4.53M/9.62M [00:01<00:02, 2.47MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:02<00:02, 2.45MB/s]
# Uploading:  52%|█████▏    | 5.03M/9.62M [00:02<00:02, 2.39MB/s]
# Uploading:  55%|█████▍    | 5.27M/9.62M [00:02<00:01, 2.34MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  60%|█████▉    | 5.73M/9.62M [00:02<00:02, 1.88MB/s]
# Uploading:  62%|██████▏   | 6.00M/9.62M [00:02<00:01, 2.08MB/s]
# Uploading:  65%|██████▌   | 6.30M/9.62M [00:02<00:01, 2.32MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:02<00:01, 2.08MB/s]
# Uploading:  70%|███████   | 6.77M/9.62M [00:03<00:01, 1.86MB/s]
# Uploading:  72%|███████▏  | 6.97M/9.62M [00:03<00:01, 1.87MB/s]
# Uploading:  76%|███████▌  | 7.27M/9.62M [00:03<00:01, 2.11MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:03<00:00, 2.27MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  84%|████████▍ | 8.06M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading:  86%|████████▌ | 8.30M/9.62M [00:03<00:00, 2.02MB/s]
# Uploading:  89%|████████▉ | 8.58M/9.62M [00:03<00:00, 2.23MB/s]
# Uploading:  92%|█████████▏| 8.88M/9.62M [00:04<00:00, 2.42MB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:04<00:00, 2.37MB/s]
# Uploading:  97%|█████████▋| 9.36M/9.62M [00:04<00:00, 2.20MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.05MB/s]
# 12it [01:02,  4.84s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▋         | 624k/9.62M [00:00<00:01, 5.65MB/s]
# Uploading:  12%|█▏        | 1.16M/9.62M [00:00<00:02, 3.12MB/s]
# Uploading:  16%|█▌        | 1.52M/9.62M [00:00<00:02, 2.91MB/s]
# Uploading:  19%|█▉        | 1.84M/9.62M [00:00<00:02, 3.03MB/s]
# Uploading:  22%|██▏       | 2.16M/9.62M [00:00<00:03, 2.60MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:00<00:02, 2.56MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:00<00:02, 2.67MB/s]
# Uploading:  31%|███▏      | 3.02M/9.62M [00:01<00:02, 2.75MB/s]
# Uploading:  35%|███▍      | 3.36M/9.62M [00:01<00:02, 2.92MB/s]
# Uploading:  39%|███▊      | 3.72M/9.62M [00:01<00:02, 2.53MB/s]
# Uploading:  42%|████▏     | 4.05M/9.62M [00:01<00:02, 2.68MB/s]
# Uploading:  46%|████▌     | 4.42M/9.62M [00:01<00:01, 2.96MB/s]
# Uploading:  50%|████▉     | 4.77M/9.62M [00:01<00:01, 3.09MB/s]
# Uploading:  53%|█████▎    | 5.08M/9.62M [00:02<00:02, 1.67MB/s]
# Uploading:  56%|█████▌    | 5.34M/9.62M [00:02<00:02, 1.58MB/s]
# Uploading:  58%|█████▊    | 5.59M/9.62M [00:02<00:02, 1.75MB/s]
# Uploading:  61%|██████    | 5.86M/9.62M [00:02<00:02, 1.94MB/s]
# Uploading:  64%|██████▍   | 6.17M/9.62M [00:02<00:01, 2.19MB/s]
# Uploading:  67%|██████▋   | 6.47M/9.62M [00:02<00:01, 2.39MB/s]
# Uploading:  70%|███████   | 6.73M/9.62M [00:03<00:02, 1.24MB/s]
# Uploading:  72%|███████▏  | 6.94M/9.62M [00:03<00:02, 1.32MB/s]
# Uploading:  74%|███████▍  | 7.12M/9.62M [00:03<00:01, 1.42MB/s]
# Uploading:  76%|███████▌  | 7.33M/9.62M [00:03<00:01, 1.56MB/s]
# Uploading:  79%|███████▉  | 7.59M/9.62M [00:03<00:01, 1.82MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:03<00:01, 1.87MB/s]
# Uploading:  83%|████████▎ | 8.03M/9.62M [00:03<00:00, 1.89MB/s]
# Uploading:  86%|████████▌ | 8.23M/9.62M [00:04<00:00, 1.71MB/s]
# Uploading:  88%|████████▊ | 8.50M/9.62M [00:04<00:00, 1.84MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:04<00:00, 1.94MB/s]
# Uploading:  93%|█████████▎| 8.92M/9.62M [00:04<00:00, 1.88MB/s]
# Uploading:  95%|█████████▍| 9.11M/9.62M [00:04<00:00, 1.85MB/s]
# Uploading:  97%|█████████▋| 9.36M/9.62M [00:04<00:00, 2.03MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.92MB/s]
# 13it [01:07,  4.97s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 576k/9.62M [00:00<00:01, 5.59MB/s]
# Uploading:  12%|█▏        | 1.11M/9.62M [00:00<00:03, 2.59MB/s]
# Uploading:  15%|█▍        | 1.44M/9.62M [00:00<00:03, 2.45MB/s]
# Uploading:  18%|█▊        | 1.72M/9.62M [00:00<00:03, 2.51MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:00<00:03, 2.09MB/s]
# Uploading:  23%|██▎       | 2.23M/9.62M [00:00<00:03, 2.14MB/s]
# Uploading:  26%|██▌       | 2.47M/9.62M [00:01<00:03, 2.08MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:01<00:03, 1.86MB/s]
# Uploading:  31%|███       | 2.98M/9.62M [00:01<00:03, 2.02MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:01<00:03, 2.17MB/s]
# Uploading:  36%|███▌      | 3.48M/9.62M [00:01<00:03, 2.14MB/s]
# Uploading:  38%|███▊      | 3.70M/9.62M [00:01<00:03, 1.76MB/s]
# Uploading:  41%|████▏     | 3.97M/9.62M [00:01<00:03, 1.95MB/s]
# Uploading:  44%|████▎     | 4.20M/9.62M [00:02<00:02, 2.05MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  48%|████▊     | 4.66M/9.62M [00:02<00:02, 2.12MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:02<00:02, 2.16MB/s]
# Uploading:  53%|█████▎    | 5.09M/9.62M [00:02<00:02, 2.01MB/s]
# Uploading:  55%|█████▌    | 5.31M/9.62M [00:02<00:02, 2.05MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:02, 2.00MB/s]
# Uploading:  60%|█████▉    | 5.75M/9.62M [00:02<00:02, 1.79MB/s]
# Uploading:  62%|██████▏   | 6.00M/9.62M [00:02<00:01, 1.99MB/s]
# Uploading:  65%|██████▌   | 6.28M/9.62M [00:03<00:01, 2.24MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:03<00:01, 2.34MB/s]
# Uploading:  70%|███████   | 6.78M/9.62M [00:03<00:01, 2.35MB/s]
# Uploading:  73%|███████▎  | 7.02M/9.62M [00:03<00:01, 2.28MB/s]
# Uploading:  75%|███████▌  | 7.25M/9.62M [00:03<00:01, 2.12MB/s]
# Uploading:  78%|███████▊  | 7.47M/9.62M [00:03<00:01, 2.09MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:03<00:00, 2.14MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:03<00:00, 1.86MB/s]
# Uploading:  85%|████████▌ | 8.20M/9.62M [00:04<00:00, 2.09MB/s]
# Uploading:  88%|████████▊ | 8.50M/9.62M [00:04<00:00, 2.32MB/s]
# Uploading:  91%|█████████ | 8.75M/9.62M [00:04<00:00, 2.37MB/s]
# Uploading:  94%|█████████▍| 9.03M/9.62M [00:04<00:00, 1.96MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:04<00:00, 2.06MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.99MB/s]
# 14it [01:12,  5.00s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 592k/9.62M [00:00<00:01, 5.97MB/s]
# Uploading:  12%|█▏        | 1.16M/9.62M [00:00<00:02, 3.44MB/s]
# Uploading:  16%|█▌        | 1.55M/9.62M [00:00<00:03, 2.62MB/s]
# Uploading:  19%|█▉        | 1.84M/9.62M [00:00<00:03, 2.64MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:00<00:03, 2.47MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:00<00:03, 2.30MB/s]
# Uploading:  27%|██▋       | 2.61M/9.62M [00:01<00:03, 2.33MB/s]
# Uploading:  30%|██▉       | 2.84M/9.62M [00:01<00:03, 2.27MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  35%|███▌      | 3.39M/9.62M [00:01<00:02, 2.51MB/s]
# Uploading:  38%|███▊      | 3.64M/9.62M [00:01<00:02, 2.52MB/s]
# Uploading:  40%|████      | 3.89M/9.62M [00:01<00:02, 2.38MB/s]
# Uploading:  44%|████▎     | 4.20M/9.62M [00:01<00:02, 2.60MB/s]
# Uploading:  47%|████▋     | 4.55M/9.62M [00:01<00:01, 2.84MB/s]
# Uploading:  50%|█████     | 4.83M/9.62M [00:02<00:03, 1.28MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:02<00:03, 1.29MB/s]
# Uploading:  54%|█████▍    | 5.23M/9.62M [00:02<00:03, 1.38MB/s]
# Uploading:  57%|█████▋    | 5.45M/9.62M [00:02<00:02, 1.54MB/s]
# Uploading:  59%|█████▉    | 5.72M/9.62M [00:02<00:02, 1.77MB/s]
# Uploading:  62%|██████▏   | 6.00M/9.62M [00:02<00:01, 2.03MB/s]
# Uploading:  65%|██████▍   | 6.23M/9.62M [00:03<00:01, 2.03MB/s]
# Uploading:  67%|██████▋   | 6.45M/9.62M [00:03<00:01, 1.95MB/s]
# Uploading:  70%|██████▉   | 6.69M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  72%|███████▏  | 6.95M/9.62M [00:03<00:01, 2.22MB/s]
# Uploading:  75%|███████▍  | 7.19M/9.62M [00:03<00:01, 1.94MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading:  81%|████████  | 7.78M/9.62M [00:03<00:00, 2.42MB/s]
# Uploading:  84%|████████▍ | 8.06M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  87%|████████▋ | 8.33M/9.62M [00:03<00:00, 2.54MB/s]
# Uploading:  89%|████████▉ | 8.58M/9.62M [00:04<00:00, 2.51MB/s]
# Uploading:  92%|█████████▏| 8.83M/9.62M [00:04<00:00, 2.40MB/s]
# Uploading:  94%|█████████▍| 9.06M/9.62M [00:04<00:00, 1.02MB/s]
# Uploading:  97%|█████████▋| 9.33M/9.62M [00:04<00:00, 1.26MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.75MB/s]
# 15it [01:18,  5.23s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   5%|▍         | 480k/9.62M [00:00<00:02, 4.71MB/s]
# Uploading:  10%|▉         | 944k/9.62M [00:00<00:03, 3.03MB/s]
# Uploading:  13%|█▎        | 1.25M/9.62M [00:00<00:03, 2.28MB/s]
# Uploading:  16%|█▌        | 1.50M/9.62M [00:00<00:03, 2.37MB/s]
# Uploading:  18%|█▊        | 1.75M/9.62M [00:00<00:03, 2.39MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:00<00:03, 2.36MB/s]
# Uploading:  23%|██▎       | 2.23M/9.62M [00:00<00:03, 2.29MB/s]
# Uploading:  26%|██▌       | 2.47M/9.62M [00:01<00:03, 2.14MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:01<00:03, 2.24MB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:01<00:03, 2.23MB/s]
# Uploading:  33%|███▎      | 3.19M/9.62M [00:01<00:03, 1.91MB/s]
# Uploading:  36%|███▌      | 3.45M/9.62M [00:01<00:03, 2.12MB/s]
# Uploading:  38%|███▊      | 3.70M/9.62M [00:01<00:02, 2.23MB/s]
# Uploading:  41%|████      | 3.95M/9.62M [00:01<00:02, 2.31MB/s]
# Uploading:  44%|████▎     | 4.20M/9.62M [00:01<00:02, 2.38MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:01<00:02, 2.31MB/s]
# Uploading:  49%|████▊     | 4.67M/9.62M [00:02<00:02, 2.17MB/s]
# Uploading:  51%|█████     | 4.89M/9.62M [00:02<00:02, 2.18MB/s]
# Uploading:  53%|█████▎    | 5.14M/9.62M [00:02<00:02, 2.07MB/s]
# Uploading:  56%|█████▌    | 5.34M/9.62M [00:02<00:02, 1.85MB/s]
# Uploading:  58%|█████▊    | 5.58M/9.62M [00:02<00:02, 1.96MB/s]
# Uploading:  61%|██████    | 5.84M/9.62M [00:02<00:01, 2.15MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:02<00:01, 2.26MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 2.27MB/s]
# Uploading:  68%|██████▊   | 6.56M/9.62M [00:03<00:01, 2.29MB/s]
# Uploading:  71%|███████   | 6.80M/9.62M [00:03<00:01, 2.17MB/s]
# Uploading:  73%|███████▎  | 7.02M/9.62M [00:03<00:01, 2.20MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:03<00:01, 2.23MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:03<00:01, 1.77MB/s]
# Uploading:  80%|███████▉  | 7.69M/9.62M [00:03<00:01, 1.93MB/s]
# Uploading:  83%|████████▎ | 7.94M/9.62M [00:03<00:00, 2.09MB/s]
# Uploading:  85%|████████▌ | 8.22M/9.62M [00:03<00:00, 2.27MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:03<00:00, 2.35MB/s]
# Uploading:  90%|█████████ | 8.70M/9.62M [00:04<00:00, 2.32MB/s]
# Uploading:  93%|█████████▎| 8.94M/9.62M [00:04<00:00, 2.23MB/s]
# Uploading:  95%|█████████▌| 9.16M/9.62M [00:04<00:00, 2.22MB/s]
# Uploading:  98%|█████████▊| 9.39M/9.62M [00:04<00:00, 2.23MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.96MB/s]
# 16it [01:23,  5.20s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 576k/9.62M [00:00<00:01, 5.74MB/s]
# Uploading:  12%|█▏        | 1.12M/9.62M [00:00<00:04, 2.05MB/s]
# Uploading:  15%|█▌        | 1.47M/9.62M [00:00<00:03, 2.32MB/s]
# Uploading:  19%|█▊        | 1.78M/9.62M [00:00<00:03, 2.54MB/s]
# Uploading:  22%|██▏       | 2.09M/9.62M [00:00<00:03, 2.50MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:03, 2.21MB/s]
# Uploading:  27%|██▋       | 2.62M/9.62M [00:01<00:03, 2.25MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  34%|███▎      | 3.23M/9.62M [00:01<00:02, 2.61MB/s]
# Uploading:  36%|███▋      | 3.50M/9.62M [00:01<00:02, 2.59MB/s]
# Uploading:  39%|███▉      | 3.78M/9.62M [00:01<00:02, 2.16MB/s]
# Uploading:  42%|████▏     | 4.08M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  49%|████▊     | 4.69M/9.62M [00:01<00:01, 2.68MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  54%|█████▍    | 5.23M/9.62M [00:02<00:02, 2.29MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.48MB/s]
# Uploading:  60%|██████    | 5.81M/9.62M [00:02<00:01, 2.57MB/s]
# Uploading:  63%|██████▎   | 6.08M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 2.31MB/s]
# Uploading:  68%|██████▊   | 6.58M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  72%|███████▏  | 6.91M/9.62M [00:02<00:01, 2.65MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:01, 2.24MB/s]
# Uploading:  79%|███████▉  | 7.58M/9.62M [00:03<00:00, 2.63MB/s]
# Uploading:  82%|████████▏ | 7.88M/9.62M [00:03<00:00, 2.68MB/s]
# Uploading:  85%|████████▌ | 8.20M/9.62M [00:03<00:00, 2.61MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:03<00:00, 2.25MB/s]
# Uploading:  92%|█████████▏| 8.86M/9.62M [00:03<00:00, 2.65MB/s]
# Uploading:  95%|█████████▌| 9.14M/9.62M [00:04<00:00, 1.18MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.98MB/s]
# 17it [01:28,  5.18s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 592k/9.62M [00:00<00:02, 4.61MB/s]
# Uploading:  11%|█         | 1.03M/9.62M [00:00<00:02, 4.31MB/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:02, 3.62MB/s]
# Uploading:  19%|█▉        | 1.81M/9.62M [00:00<00:02, 3.55MB/s]
# Uploading:  22%|██▏       | 2.16M/9.62M [00:00<00:02, 3.11MB/s]
# Uploading:  26%|██▌       | 2.47M/9.62M [00:00<00:02, 3.01MB/s]
# Uploading:  29%|██▊       | 2.77M/9.62M [00:00<00:02, 2.61MB/s]
# Uploading:  32%|███▏      | 3.03M/9.62M [00:01<00:02, 2.63MB/s]
# Uploading:  34%|███▍      | 3.30M/9.62M [00:01<00:03, 2.21MB/s]
# Uploading:  37%|███▋      | 3.53M/9.62M [00:01<00:02, 2.21MB/s]
# Uploading:  40%|████      | 3.86M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  43%|████▎     | 4.11M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:01<00:02, 2.17MB/s]
# Uploading:  48%|████▊     | 4.66M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  52%|█████▏    | 5.03M/9.62M [00:01<00:01, 2.75MB/s]
# Uploading:  56%|█████▌    | 5.36M/9.62M [00:02<00:01, 2.91MB/s]
# Uploading:  59%|█████▉    | 5.66M/9.62M [00:02<00:03, 1.31MB/s]
# Uploading:  64%|██████▎   | 6.12M/9.62M [00:02<00:02, 1.66MB/s]
# Uploading:  67%|██████▋   | 6.42M/9.62M [00:02<00:01, 1.88MB/s]
# Uploading:  69%|██████▉   | 6.67M/9.62M [00:02<00:01, 1.97MB/s]
# Uploading:  72%|███████▏  | 6.97M/9.62M [00:03<00:01, 2.19MB/s]
# Uploading:  76%|███████▌  | 7.27M/9.62M [00:03<00:01, 2.37MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  81%|████████  | 7.80M/9.62M [00:03<00:00, 2.18MB/s]
# Uploading:  84%|████████▍ | 8.08M/9.62M [00:03<00:00, 2.34MB/s]
# Uploading:  87%|████████▋ | 8.33M/9.62M [00:04<00:01, 1.22MB/s]
# Uploading:  89%|████████▊ | 8.52M/9.62M [00:04<00:00, 1.25MB/s]
# Uploading:  90%|█████████ | 8.69M/9.62M [00:04<00:00, 1.29MB/s]
# Uploading:  93%|█████████▎| 8.91M/9.62M [00:04<00:00, 1.47MB/s]
# Uploading:  95%|█████████▍| 9.09M/9.62M [00:04<00:00, 1.50MB/s]
# Uploading:  96%|█████████▋| 9.28M/9.62M [00:04<00:00, 1.60MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.88MB/s]
# 18it [01:33,  5.24s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   5%|▍         | 480k/9.62M [00:00<00:02, 4.43MB/s]
# Uploading:   9%|▉         | 928k/9.62M [00:00<00:03, 2.83MB/s]
# Uploading:  13%|█▎        | 1.22M/9.62M [00:00<00:03, 2.21MB/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:03, 2.21MB/s]
# Uploading:  18%|█▊        | 1.72M/9.62M [00:00<00:03, 2.36MB/s]
# Uploading:  20%|██        | 1.97M/9.62M [00:00<00:03, 2.36MB/s]
# Uploading:  23%|██▎       | 2.20M/9.62M [00:01<00:04, 1.86MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:01<00:03, 1.96MB/s]
# Uploading:  27%|██▋       | 2.62M/9.62M [00:01<00:03, 1.99MB/s]
# Uploading:  30%|██▉       | 2.86M/9.62M [00:01<00:03, 2.06MB/s]
# Uploading:  32%|███▏      | 3.09M/9.62M [00:01<00:03, 2.10MB/s]
# Uploading:  34%|███▍      | 3.31M/9.62M [00:01<00:03, 2.15MB/s]
# Uploading:  37%|███▋      | 3.53M/9.62M [00:01<00:03, 1.91MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:01<00:03, 2.00MB/s]
# Uploading:  41%|████▏     | 3.98M/9.62M [00:01<00:02, 2.02MB/s]
# Uploading:  44%|████▎     | 4.19M/9.62M [00:02<00:03, 1.81MB/s]
# Uploading:  46%|████▌     | 4.42M/9.62M [00:02<00:02, 1.96MB/s]
# Uploading:  49%|████▊     | 4.69M/9.62M [00:02<00:02, 2.18MB/s]
# Uploading:  51%|█████     | 4.91M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  53%|█████▎    | 5.12M/9.62M [00:02<00:02, 2.16MB/s]
# Uploading:  56%|█████▌    | 5.34M/9.62M [00:02<00:02, 2.07MB/s]
# Uploading:  58%|█████▊    | 5.55M/9.62M [00:02<00:02, 2.08MB/s]
# Uploading:  60%|██████    | 5.80M/9.62M [00:02<00:01, 2.22MB/s]
# Uploading:  63%|██████▎   | 6.05M/9.62M [00:02<00:01, 2.17MB/s]
# Uploading:  65%|██████▌   | 6.27M/9.62M [00:03<00:01, 1.81MB/s]
# Uploading:  68%|██████▊   | 6.53M/9.62M [00:03<00:01, 2.02MB/s]
# Uploading:  70%|███████   | 6.75M/9.62M [00:03<00:01, 2.05MB/s]
# Uploading:  73%|███████▎  | 7.00M/9.62M [00:03<00:01, 2.17MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:03<00:01, 2.19MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:03<00:01, 1.85MB/s]
# Uploading:  81%|████████  | 7.75M/9.62M [00:03<00:00, 2.06MB/s]
# Uploading:  83%|████████▎ | 8.02M/9.62M [00:03<00:00, 2.24MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:04<00:00, 2.32MB/s]
# Uploading:  88%|████████▊ | 8.50M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:04<00:00, 2.00MB/s]
# Uploading:  93%|█████████▎| 8.98M/9.62M [00:04<00:00, 2.09MB/s]
# Uploading:  96%|█████████▋| 9.28M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.92MB/s]
# 19it [01:38,  5.24s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 560k/9.62M [00:00<00:01, 5.27MB/s]
# Uploading:  11%|█         | 1.06M/9.62M [00:00<00:02, 3.41MB/s]
# Uploading:  15%|█▍        | 1.42M/9.62M [00:00<00:02, 3.26MB/s]
# Uploading:  18%|█▊        | 1.75M/9.62M [00:00<00:03, 2.49MB/s]
# Uploading:  21%|██        | 2.02M/9.62M [00:00<00:03, 2.51MB/s]
# Uploading:  24%|██▎       | 2.28M/9.62M [00:00<00:03, 2.48MB/s]
# Uploading:  26%|██▋       | 2.53M/9.62M [00:01<00:03, 2.08MB/s]
# Uploading:  29%|██▉       | 2.80M/9.62M [00:01<00:03, 2.24MB/s]
# Uploading:  32%|███▏      | 3.09M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  35%|███▍      | 3.36M/9.62M [00:01<00:02, 2.49MB/s]
# Uploading:  38%|███▊      | 3.61M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  40%|████      | 3.86M/9.62M [00:01<00:02, 2.02MB/s]
# Uploading:  43%|████▎     | 4.12M/9.62M [00:01<00:02, 2.16MB/s]
# Uploading:  46%|████▌     | 4.39M/9.62M [00:01<00:02, 2.31MB/s]
# Uploading:  48%|████▊     | 4.62M/9.62M [00:01<00:02, 2.34MB/s]
# Uploading:  51%|█████     | 4.86M/9.62M [00:02<00:02, 2.21MB/s]
# Uploading:  54%|█████▍    | 5.17M/9.62M [00:02<00:01, 2.48MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  59%|█████▉    | 5.69M/9.62M [00:02<00:01, 2.54MB/s]
# Uploading:  62%|██████▏   | 5.97M/9.62M [00:02<00:01, 2.64MB/s]
# Uploading:  65%|██████▍   | 6.23M/9.62M [00:02<00:01, 2.60MB/s]
# Uploading:  68%|██████▊   | 6.50M/9.62M [00:02<00:01, 2.55MB/s]
# Uploading:  71%|███████   | 6.81M/9.62M [00:02<00:01, 2.72MB/s]
# Uploading:  74%|███████▍  | 7.14M/9.62M [00:02<00:00, 2.88MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:03<00:01, 1.19MB/s]
# Uploading:  86%|████████▋ | 8.31M/9.62M [00:03<00:00, 1.72MB/s]
# Uploading:  89%|████████▉ | 8.59M/9.62M [00:03<00:00, 1.88MB/s]
# Uploading:  92%|█████████▏| 8.88M/9.62M [00:04<00:00, 2.06MB/s]
# Uploading:  95%|█████████▌| 9.16M/9.62M [00:04<00:00, 1.82MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.05MB/s]
# 20it [01:43,  5.14s/it]
# Uploading:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Uploading:   8%|▊         | 608k/7.37M [00:00<00:01, 5.93MB/s]
# Uploading:  16%|█▌        | 1.17M/7.37M [00:00<00:01, 3.70MB/s]
# Uploading:  21%|██▏       | 1.58M/7.37M [00:00<00:02, 2.83MB/s]
# Uploading:  26%|██▌       | 1.91M/7.37M [00:00<00:01, 2.99MB/s]
# Uploading:  30%|███       | 2.22M/7.37M [00:00<00:01, 2.99MB/s]
# Uploading:  34%|███▍      | 2.53M/7.37M [00:00<00:02, 2.43MB/s]
# Uploading:  39%|███▉      | 2.86M/7.37M [00:01<00:01, 2.56MB/s]
# Uploading:  43%|████▎     | 3.17M/7.37M [00:01<00:01, 2.72MB/s]
# Uploading:  47%|████▋     | 3.47M/7.37M [00:01<00:01, 2.82MB/s]
# Uploading:  51%|█████     | 3.77M/7.37M [00:01<00:01, 2.81MB/s]
# Uploading:  55%|█████▍    | 4.05M/7.37M [00:01<00:02, 1.50MB/s]
# Uploading:  58%|█████▊    | 4.28M/7.37M [00:01<00:02, 1.46MB/s]
# Uploading:  61%|██████▏   | 4.53M/7.37M [00:02<00:01, 1.66MB/s]
# Uploading:  65%|██████▍   | 4.78M/7.37M [00:02<00:01, 1.81MB/s]
# Uploading:  68%|██████▊   | 5.00M/7.37M [00:02<00:01, 1.91MB/s]
# Uploading:  71%|███████   | 5.22M/7.37M [00:02<00:01, 1.91MB/s]
# Uploading:  74%|███████▎  | 5.42M/7.37M [00:02<00:01, 1.96MB/s]
# Uploading:  77%|███████▋  | 5.67M/7.37M [00:02<00:00, 2.13MB/s]
# Uploading:  80%|███████▉  | 5.89M/7.37M [00:02<00:00, 2.13MB/s]
# Uploading:  84%|████████▎ | 6.16M/7.37M [00:02<00:00, 2.30MB/s]
# Uploading:  87%|████████▋ | 6.39M/7.37M [00:02<00:00, 2.25MB/s]
# Uploading:  90%|████████▉ | 6.62M/7.37M [00:03<00:00, 2.14MB/s]
# Uploading:  93%|█████████▎| 6.88M/7.37M [00:03<00:00, 2.10MB/s]
# Uploading:  97%|█████████▋| 7.12M/7.37M [00:03<00:00, 2.23MB/s]
# Uploading: 100%|██████████| 7.37M/7.37M [00:04<00:00, 1.80MB/s]
# 21it [01:48,  4.89s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   4%|▎         | 368k/9.62M [00:00<00:02, 3.71MB/s]
# Uploading:   7%|▋         | 736k/9.62M [00:00<00:04, 2.17MB/s]
# Uploading:  10%|█         | 992k/9.62M [00:00<00:04, 2.24MB/s]
# Uploading:  13%|█▎        | 1.20M/9.62M [00:00<00:04, 1.95MB/s]
# Uploading:  15%|█▍        | 1.41M/9.62M [00:00<00:04, 1.86MB/s]
# Uploading:  17%|█▋        | 1.59M/9.62M [00:00<00:04, 1.82MB/s]
# Uploading:  19%|█▉        | 1.81M/9.62M [00:00<00:04, 1.95MB/s]
# Uploading:  21%|██▏       | 2.05M/9.62M [00:01<00:03, 2.03MB/s]
# Uploading:  24%|██▎       | 2.27M/9.62M [00:01<00:04, 1.65MB/s]
# Uploading:  26%|██▌       | 2.48M/9.62M [00:01<00:04, 1.79MB/s]
# Uploading:  28%|██▊       | 2.69M/9.62M [00:01<00:03, 1.88MB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:01<00:03, 2.05MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:01<00:03, 2.09MB/s]
# Uploading:  35%|███▌      | 3.38M/9.62M [00:01<00:03, 2.00MB/s]
# Uploading:  37%|███▋      | 3.58M/9.62M [00:01<00:03, 1.98MB/s]
# Uploading:  39%|███▉      | 3.78M/9.62M [00:02<00:03, 1.99MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:02<00:02, 1.97MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:02<00:03, 1.71MB/s]
# Uploading:  46%|████▋     | 4.45M/9.62M [00:02<00:02, 1.86MB/s]
# Uploading:  49%|████▊     | 4.67M/9.62M [00:02<00:02, 1.94MB/s]
# Uploading:  51%|█████     | 4.92M/9.62M [00:02<00:02, 2.11MB/s]
# Uploading:  53%|█████▎    | 5.14M/9.62M [00:02<00:02, 2.08MB/s]
# Uploading:  56%|█████▌    | 5.36M/9.62M [00:02<00:02, 1.99MB/s]
# Uploading:  58%|█████▊    | 5.56M/9.62M [00:03<00:02, 1.74MB/s]
# Uploading:  60%|██████    | 5.80M/9.62M [00:03<00:02, 1.91MB/s]
# Uploading:  63%|██████▎   | 6.02M/9.62M [00:03<00:01, 1.96MB/s]
# Uploading:  65%|██████▍   | 6.22M/9.62M [00:03<00:01, 1.91MB/s]
# Uploading:  67%|██████▋   | 6.41M/9.62M [00:03<00:01, 1.86MB/s]
# Uploading:  70%|██████▉   | 6.70M/9.62M [00:03<00:01, 2.15MB/s]
# Uploading:  72%|███████▏  | 6.94M/9.62M [00:03<00:01, 2.03MB/s]
# Uploading:  74%|███████▍  | 7.14M/9.62M [00:03<00:01, 1.75MB/s]
# Uploading:  76%|███████▋  | 7.36M/9.62M [00:03<00:01, 1.86MB/s]
# Uploading:  79%|███████▉  | 7.62M/9.62M [00:04<00:01, 2.09MB/s]
# Uploading:  82%|████████▏ | 7.84M/9.62M [00:04<00:00, 2.06MB/s]
# Uploading:  84%|████████▍ | 8.09M/9.62M [00:04<00:00, 2.18MB/s]
# Uploading:  86%|████████▋ | 8.31M/9.62M [00:04<00:00, 2.05MB/s]
# Uploading:  89%|████████▊ | 8.53M/9.62M [00:04<00:00, 1.91MB/s]
# Uploading:  91%|█████████ | 8.77M/9.62M [00:04<00:00, 2.03MB/s]
# Uploading:  94%|█████████▎| 9.00M/9.62M [00:04<00:00, 2.11MB/s]
# Uploading:  96%|█████████▌| 9.22M/9.62M [00:04<00:00, 1.94MB/s]
# Uploading:  98%|█████████▊| 9.42M/9.62M [00:05<00:00, 1.92MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.62MB/s]
# 22it [01:54,  5.29s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   5%|▌         | 528k/9.62M [00:00<00:01, 5.17MB/s]
# Uploading:  11%|█         | 1.02M/9.62M [00:00<00:03, 2.51MB/s]
# Uploading:  14%|█▍        | 1.33M/9.62M [00:00<00:03, 2.56MB/s]
# Uploading:  17%|█▋        | 1.62M/9.62M [00:00<00:03, 2.34MB/s]
# Uploading:  19%|█▉        | 1.88M/9.62M [00:00<00:03, 2.28MB/s]
# Uploading:  22%|██▏       | 2.11M/9.62M [00:00<00:03, 2.31MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:03, 2.41MB/s]
# Uploading:  28%|██▊       | 2.66M/9.62M [00:01<00:02, 2.56MB/s]
# Uploading:  31%|███       | 2.95M/9.62M [00:01<00:03, 2.04MB/s]
# Uploading:  34%|███▍      | 3.27M/9.62M [00:01<00:02, 2.32MB/s]
# Uploading:  37%|███▋      | 3.59M/9.62M [00:01<00:02, 2.58MB/s]
# Uploading:  40%|████      | 3.88M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  43%|████▎     | 4.17M/9.62M [00:01<00:02, 2.63MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:01<00:02, 2.22MB/s]
# Uploading:  49%|████▉     | 4.73M/9.62M [00:02<00:02, 2.43MB/s]
# Uploading:  52%|█████▏    | 4.98M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  55%|█████▍    | 5.27M/9.62M [00:02<00:01, 2.58MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.43MB/s]
# Uploading:  60%|██████    | 5.78M/9.62M [00:02<00:01, 2.43MB/s]
# Uploading:  63%|██████▎   | 6.08M/9.62M [00:02<00:01, 2.60MB/s]
# Uploading:  67%|██████▋   | 6.41M/9.62M [00:02<00:01, 2.76MB/s]
# Uploading:  70%|██████▉   | 6.69M/9.62M [00:02<00:01, 2.81MB/s]
# Uploading:  72%|███████▏  | 6.97M/9.62M [00:02<00:01, 2.65MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:03<00:00, 2.62MB/s]
# Uploading:  78%|███████▊  | 7.55M/9.62M [00:03<00:00, 2.77MB/s]
# Uploading:  82%|████████▏ | 7.86M/9.62M [00:03<00:00, 2.89MB/s]
# Uploading:  85%|████████▍ | 8.17M/9.62M [00:03<00:00, 3.00MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:03<00:00, 1.22MB/s]
# Uploading:  93%|█████████▎| 8.94M/9.62M [00:04<00:00, 1.72MB/s]
# ...
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:02<00:01, 2.48MB/s]
# Uploading:  54%|█████▍    | 5.22M/9.62M [00:02<00:01, 2.48MB/s]
# Uploading:  57%|█████▋    | 5.47M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  59%|█████▉    | 5.72M/9.62M [00:02<00:01, 2.32MB/s]
# Uploading:  62%|██████▏   | 5.97M/9.62M [00:02<00:01, 2.40MB/s]
# Uploading:  64%|██████▍   | 6.20M/9.62M [00:02<00:01, 2.00MB/s]
# Uploading:  68%|██████▊   | 6.52M/9.62M [00:02<00:01, 2.28MB/s]
# Uploading:  70%|███████   | 6.75M/9.62M [00:03<00:01, 2.33MB/s]
# Uploading:  73%|███████▎  | 6.98M/9.62M [00:03<00:01, 2.34MB/s]
# Uploading:  75%|███████▌  | 7.25M/9.62M [00:03<00:01, 2.46MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  80%|████████  | 7.73M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  83%|████████▎ | 7.97M/9.62M [00:03<00:00, 2.31MB/s]
# Uploading:  85%|████████▌ | 8.20M/9.62M [00:03<00:00, 2.34MB/s]
# Uploading:  88%|████████▊ | 8.50M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  91%|█████████ | 8.75M/9.62M [00:03<00:00, 2.03MB/s]
# Uploading:  94%|█████████▍| 9.05M/9.62M [00:04<00:00, 2.27MB/s]
# Uploading:  96%|█████████▋| 9.28M/9.62M [00:04<00:00, 2.28MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.09MB/s]
# 28it [02:33,  5.82s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 576k/9.62M [00:00<00:01, 5.59MB/s]
# Uploading:  12%|█▏        | 1.11M/9.62M [00:00<00:02, 3.38MB/s]
# Uploading:  15%|█▌        | 1.48M/9.62M [00:00<00:02, 3.31MB/s]
# Uploading:  19%|█▉        | 1.83M/9.62M [00:00<00:03, 2.71MB/s]
# Uploading:  22%|██▏       | 2.11M/9.62M [00:00<00:03, 2.36MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:00<00:03, 2.44MB/s]
# Uploading:  28%|██▊       | 2.66M/9.62M [00:01<00:02, 2.54MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:01<00:03, 2.33MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:01<00:03, 2.22MB/s]
# Uploading:  35%|███▌      | 3.41M/9.62M [00:01<00:02, 2.32MB/s]
# Uploading:  38%|███▊      | 3.67M/9.62M [00:01<00:02, 2.43MB/s]
# Uploading:  41%|████▏     | 3.98M/9.62M [00:01<00:02, 2.66MB/s]
# Uploading:  44%|████▍     | 4.25M/9.62M [00:01<00:02, 2.66MB/s]
# Uploading:  47%|████▋     | 4.52M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  53%|█████▎    | 5.06M/9.62M [00:02<00:01, 2.58MB/s]
# Uploading:  55%|█████▌    | 5.33M/9.62M [00:02<00:03, 1.13MB/s]
# Uploading:  58%|█████▊    | 5.58M/9.62M [00:02<00:03, 1.33MB/s]
# Uploading:  61%|██████    | 5.84M/9.62M [00:02<00:02, 1.56MB/s]
# Uploading:  63%|██████▎   | 6.08M/9.62M [00:02<00:02, 1.68MB/s]
# Uploading:  65%|██████▌   | 6.30M/9.62M [00:03<00:01, 1.81MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:03<00:01, 1.99MB/s]
# Uploading:  70%|███████   | 6.78M/9.62M [00:03<00:01, 2.10MB/s]
# Uploading:  73%|███████▎  | 7.02M/9.62M [00:03<00:01, 1.99MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:03<00:01, 1.99MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading:  81%|████████  | 7.77M/9.62M [00:03<00:00, 1.97MB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:03<00:00, 2.16MB/s]
# Uploading:  86%|████████▋ | 8.31M/9.62M [00:03<00:00, 2.29MB/s]
# Uploading:  89%|████████▉ | 8.61M/9.62M [00:04<00:00, 2.49MB/s]
# Uploading:  93%|█████████▎| 8.92M/9.62M [00:04<00:00, 2.66MB/s]
# Uploading:  96%|█████████▌| 9.19M/9.62M [00:04<00:00, 2.67MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.85MB/s]
# 29it [02:39,  5.71s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   2%|▏         | 208k/9.62M [00:00<00:04, 2.08MB/s]
# Uploading:   4%|▍         | 416k/9.62M [00:00<00:10, 937kB/s]
# Uploading:   7%|▋         | 720k/9.62M [00:00<00:06, 1.51MB/s]
# Uploading:  10%|█         | 992k/9.62M [00:00<00:04, 1.84MB/s]
# Uploading:  13%|█▎        | 1.20M/9.62M [00:00<00:04, 1.92MB/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:04, 2.08MB/s]
# Uploading:  18%|█▊        | 1.69M/9.62M [00:01<00:04, 1.70MB/s]
# Uploading:  20%|█▉        | 1.91M/9.62M [00:01<00:04, 1.83MB/s]
# Uploading:  22%|██▏       | 2.16M/9.62M [00:01<00:03, 2.02MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:03, 2.06MB/s]
# Uploading:  27%|██▋       | 2.59M/9.62M [00:01<00:03, 2.10MB/s]
# Uploading:  29%|██▉       | 2.81M/9.62M [00:01<00:03, 2.01MB/s]
# Uploading:  31%|███▏      | 3.02M/9.62M [00:01<00:03, 2.00MB/s]
# Uploading:  34%|███▍      | 3.27M/9.62M [00:01<00:03, 2.17MB/s]
# Uploading:  36%|███▌      | 3.48M/9.62M [00:01<00:03, 1.76MB/s]
# Uploading:  38%|███▊      | 3.70M/9.62M [00:02<00:03, 1.88MB/s]
# Uploading:  41%|████      | 3.91M/9.62M [00:02<00:03, 1.92MB/s]
# Uploading:  43%|████▎     | 4.12M/9.62M [00:02<00:02, 2.01MB/s]
# Uploading:  46%|████▌     | 4.39M/9.62M [00:02<00:02, 2.10MB/s]
# Uploading:  48%|████▊     | 4.61M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  50%|█████     | 4.83M/9.62M [00:02<00:02, 1.95MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:02<00:02, 2.01MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:02<00:02, 2.08MB/s]
# Uploading:  57%|█████▋    | 5.48M/9.62M [00:03<00:02, 1.81MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:03<00:02, 1.77MB/s]
# Uploading:  62%|██████▏   | 5.92M/9.62M [00:03<00:01, 1.96MB/s]
# Uploading:  64%|██████▍   | 6.17M/9.62M [00:03<00:01, 2.13MB/s]
# Uploading:  67%|██████▋   | 6.42M/9.62M [00:03<00:01, 2.24MB/s]
# Uploading:  69%|██████▉   | 6.67M/9.62M [00:03<00:01, 1.83MB/s]
# Uploading:  72%|███████▏  | 6.92M/9.62M [00:03<00:01, 2.00MB/s]
# Uploading:  75%|███████▍  | 7.19M/9.62M [00:03<00:01, 1.94MB/s]
# 29it [02:43,  5.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # uploads all the raw flight data to databricks
# ----> 2 ingest.upload_raw_flight_data_to_db()
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/drone/ingest.py:288, in DroneDataIngest.upload_raw_flight_data_to_db(self)
#     286 for idx, row in tqdm(self.raw_ingest_df.iterrows()):
#     287     try:
# --> 288         dio.upload_file_with_progress(w=self.cloud_client,
#     289                                       local_file_path=row['src_path'],
#     290                                       volume_path=row['dst_path'])
#     291         self.raw_ingest_df.loc[idx, 'status'] = "success"
#     292     except Exception as e:
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/data_io/databricks_io.py:37, in upload_file_with_progress(w, local_file_path, volume_path, chunk_size)
#      35 with open(local_file_path, "rb") as f:
#      36     with tqdm.wrapattr(f, "read", total=file_size, unit="B", unit_scale=True, desc="Uploading") as f_wrapped:
# ---> 37         w.files.upload(volume_path, f_wrapped, overwrite=True)
#      39 logger.info(f"Upload complete: {volume_path}")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1149, in FilesExt.upload(self, file_path, contents, overwrite, part_size, use_parallel, parallelism)
#    1147     return UploadStreamResult()
#    1148 elif ctx.content_length is not None:
# -> 1149     self._upload_single_thread_with_known_size(ctx, contents)
#    1150     return UploadStreamResult()
#    1151 else:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1229, in FilesExt._upload_single_thread_with_known_size(self, ctx, contents)
#    1227 if ctx.content_length < self._config.files_ext_multipart_upload_min_stream_size:
#    1228     _LOG.debug(f"Using single-shot upload for input stream of size {ctx.content_length} bytes")
# -> 1229     return self._single_thread_single_shot_upload(ctx, contents)
#    1230 else:
#    1231     _LOG.debug(f"Using multipart upload for input stream of size {ctx.content_length} bytes")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1237, in FilesExt._single_thread_single_shot_upload(self, ctx, contents)
#    1235 """Upload a file with a known size."""
#    1236 _LOG.debug(f"Using single-shot upload for input stream")
# -> 1237 return super().upload(file_path=ctx.target_path, contents=contents, overwrite=ctx.overwrite)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/service/files.py:953, in FilesAPI.upload(self, file_path, contents, overwrite)
#     948     query["overwrite"] = overwrite
#     949 headers = {
#     950     "Content-Type": "application/octet-stream",
#     951 }
# --> 953 self._api.do(
#     954     "PUT",
#     955     f"/api/2.0/fs/files{_escape_multi_segment_path_parameter(file_path)}",
#     956     query=query,
#     957     headers=headers,
#     958     data=contents,
#     959 )
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/core.py:94, in ApiClient.do(self, method, path, url, query, headers, body, raw, files, data, auth, response_headers)
#      92     path = re.sub("^/api/2.0/fs/files//", "/api/2.0/fs/files/", path)
#      93     url = f"{self._cfg.host}{path}"
# ---> 94 return self._api_client.do(
#      95     method=method,
#      96     url=url,
#      97     query=query,
#      98     headers=headers,
#      99     body=body,
#     100     raw=raw,
#     101     files=files,
#     102     data=data,
#     103     auth=auth,
#     104     response_headers=response_headers,
#     105 )
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:199, in _BaseClient.do(self, method, url, query, headers, body, raw, files, data, auth, response_headers)
#     196     logger.debug(f"Retry disabled for non-seekable stream: type={type(data)}")
#     197     call = self._perform
# --> 199 response = call(
#     200     method,
#     201     url,
#     202     query=query,
#     203     headers=headers,
#     204     body=body,
#     205     raw=raw,
#     206     files=files,
#     207     data=data,
#     208     auth=auth,
#     209 )
#     211 resp = dict()
#     212 for header in response_headers if response_headers else []:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:286, in _BaseClient._perform(self, method, url, query, headers, body, raw, files, data, auth)
#     274 def _perform(
#     275     self,
#     276     method: str,
#    (...)    284     auth: Callable[[requests.PreparedRequest], requests.PreparedRequest] = None,
#     285 ):
# --> 286     response = self._session.request(
#     287         method,
#     288         url,
#     289         params=self._fix_query_string(query),
#     290         json=body,
#     291         headers=headers,
#     292         files=files,
#     293         data=data,
#     294         auth=auth,
#     295         stream=raw,
#     296         timeout=self._http_timeout_seconds,
#     297     )
#     298     self._record_request_log(response, raw=raw or data is not None or files is not None)
#     299     error = self._error_parser.get_api_error(response)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connection.py:514, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     512             self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     513         else:
# --> 514             self.send(chunk)
#     516 # Regardless of whether we have a body or not, if we're in
#     517 # chunked mode we want to send an explicit empty chunk.
#     518 if chunked:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1002, in HTTPConnection.send(self, data)
#    1000 sys.audit("http.client.send", self, data)
#    1001 try:
# -> 1002     self.sock.sendall(data)
#    1003 except TypeError:
#    1004     if isinstance(data, collections.abc.Iterable):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1274, in SSLSocket.sendall(self, data, flags)
#    1272         amount = len(byte_view)
#    1273         while count < amount:
# -> 1274             v = self.send(byte_view[count:])
#    1275             count += v
#    1276 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1243, in SSLSocket.send(self, data, flags)
#    1239     if flags != 0:
#    1240         raise ValueError(
#    1241             "non-zero flags not allowed in calls to send() on %s" %
#    1242             self.__class__)
# -> 1243     return self._sslobj.write(data)
#    1244 else:
#    1245     return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
# If you have a dem generated, you can upload it so we don't need to reprocess.
ingest.upload_dem_to_db(method=ORTHO_METHOD,  # the method used to generate the dem.
                        dem_date=ORTHO_DATE,  # the date the dem was generated.
                        file_name='dem.tif')
# Out:
# Saving to /Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data/tnau-coimbatore-1/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/2025-11-25/dem/agisoft_2024-11-25/dem.tif
# Uploading:   1%|▏         | 20.0M/1.45G [00:09<12:00, 2.13MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 # If you have a dem generated, you can upload it so we don't need to reprocess.
# ----> 2 ingest.upload_dem_to_db(method=ORTHO_METHOD,  # the method used to generate the dem.
#       3                         dem_date=ORTHO_DATE,  # the date the dem was generated.
#       4                         file_name='dem.tif')
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/drone/ingest.py:383, in DroneDataIngest.upload_dem_to_db(self, method, dem_date, file_name)
#     376 upload_path = paths.drone_flight_dem_path(mission_dir=self.drone_mission_dir,
#     377                                           flight_date=self.flight_date,
#     378                                           method=method,
#     379                                           dem_date=dem_date,
#     380                                           image_name=file_name)
#     381 print(f"Saving to {upload_path}")
# --> 383 dio.upload_file_with_progress(w=self.cloud_client,
#     384                               local_file_path=self.dem_key,
#     385                               volume_path=upload_path)
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/data_io/databricks_io.py:37, in upload_file_with_progress(w, local_file_path, volume_path, chunk_size)
#      35 with open(local_file_path, "rb") as f:
#      36     with tqdm.wrapattr(f, "read", total=file_size, unit="B", unit_scale=True, desc="Uploading") as f_wrapped:
# ---> 37         w.files.upload(volume_path, f_wrapped, overwrite=True)
#      39 logger.info(f"Upload complete: {volume_path}")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1146, in FilesExt.upload(self, file_path, contents, overwrite, part_size, use_parallel, parallelism)
#    1139 _LOG.debug(
#    1140     f"Upload context: part_size={ctx.part_size}, batch_size={ctx.batch_size}, content_length={ctx.content_length}"
#    1141 )
#    1143 if ctx.use_parallel and (
#    1144     ctx.content_length is None or ctx.content_length >= self._config.files_ext_multipart_upload_min_stream_size
#    1145 ):
# -> 1146     self._parallel_upload_from_stream(ctx, contents)
#    1147     return UploadStreamResult()
#    1148 elif ctx.content_length is not None:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1326, in FilesExt._parallel_upload_from_stream(self, ctx, contents)
#    1324     raise ValueError(f"Unexpected server response: {initiate_upload_response}")
#    1325 try:
# -> 1326     self._parallel_multipart_upload_from_stream(ctx, session_token, contents, cloud_provider_session)
#    1327 except FallbackToUploadUsingFilesApi as e:
#    1328     try:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1501, in FilesExt._parallel_multipart_upload_from_stream(self, ctx, session_token, content, cloud_provider_session)
#    1497     raise FallbackToUploadUsingFilesApi(
#    1498         b"", "Falling back to single-shot upload with Files API due to empty input stream"
#    1499     )
#    1500 try:
# -> 1501     etag = self._do_upload_one_part(
#    1502         ctx,
#    1503         cloud_provider_session,
#    1504         1,
#    1505         0,
#    1506         len(pre_read_buffer),
#    1507         session_token,
#    1508         BytesIO(pre_read_buffer),
#    1509         is_first_part=True,
#    1510     )
#    1511     etags_result_queue.put((1, etag))
#    1512 except FallbackToUploadUsingFilesApi as e:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1727, in FilesExt._do_upload_one_part(self, ctx, cloud_provider_session, part_index, part_offset, part_size, session_token, part_content, is_first_part)
#    1718 def perform_upload() -> requests.Response:
#    1719     return cloud_provider_session.request(
#    1720         "PUT",
#    1721         url,
#    (...)   1724         timeout=self._config.files_ext_network_transfer_inactivity_timeout_seconds,
#    1725     )
# -> 1727 upload_response = self._retry_cloud_idempotent_operation(perform_upload, rewind)
#    1729 if upload_response.status_code in (200, 201):
#    1730     etag = upload_response.headers.get("ETag", "")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:2331, in FilesExt._retry_cloud_idempotent_operation(self, operation, before_retry)
#    2328 # following _BaseClient timeout
#    2329 retry_timeout_seconds = self._config.retry_timeout_seconds or 300
# -> 2331 return retried(
#    2332     timeout=timedelta(seconds=retry_timeout_seconds),
#    2333     # also retry on network errors (connection error, connection timeout)
#    2334     # where we believe request didn't reach the server
#    2335     is_retryable=extended_is_retryable,
#    2336     before_retry=before_retry,
#    2337     clock=self._config.clock,
#    2338 )(delegate)()
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/retries.py:38, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      36 while clock.time() < deadline:
#      37     try:
# ---> 38         return func(*args, **kwargs)
#      39     except Exception as err:
#      40         last_err = err
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:2312, in FilesExt._retry_cloud_idempotent_operation.<locals>.delegate()
#    2311 def delegate() -> requests.Response:
# -> 2312     response = operation()
#    2313     if response.status_code in self._RETRYABLE_STATUS_CODES:
#    2314         raise _RetryableException.make_error(response)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1719, in FilesExt._do_upload_one_part.<locals>.perform_upload()
#    1718 def perform_upload() -> requests.Response:
# -> 1719     return cloud_provider_session.request(
#    1720         "PUT",
#    1721         url,
#    1722         headers=headers,
#    1723         data=part_content,
#    1724         timeout=self._config.files_ext_network_transfer_inactivity_timeout_seconds,
#    1725     )
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connection.py:514, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     512             self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     513         else:
# --> 514             self.send(chunk)
#     516 # Regardless of whether we have a body or not, if we're in
#     517 # chunked mode we want to send an explicit empty chunk.
#     518 if chunked:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1002, in HTTPConnection.send(self, data)
#    1000 sys.audit("http.client.send", self, data)
#    1001 try:
# -> 1002     self.sock.sendall(data)
#    1003 except TypeError:
#    1004     if isinstance(data, collections.abc.Iterable):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1274, in SSLSocket.sendall(self, data, flags)
#    1272         amount = len(byte_view)
#    1273         while count < amount:
# -> 1274             v = self.send(byte_view[count:])
#    1275             count += v
#    1276 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1243, in SSLSocket.send(self, data, flags)
#    1239     if flags != 0:
#    1240         raise ValueError(
#    1241             "non-zero flags not allowed in calls to send() on %s" %
#    1242             self.__class__)
# -> 1243     return self._sslobj.write(data)
#    1244 else:
#    1245     return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
# f"{drone_flight_path}/orthomosaic/{method}_{date}/{image_name}"
ingest.upload_orthomosaic_to_db(method=ORTHO_METHOD,  # the method used to generate the ortho.
                                ortho_date=ORTHO_DATE, # the date the ortho was generated.
                                camera=CAMERA_TYPE, # The camera that was used.
                                file_name=f'{CAMERA_TYPE}.tif')  # if RGB then you can name it rgb.tif
