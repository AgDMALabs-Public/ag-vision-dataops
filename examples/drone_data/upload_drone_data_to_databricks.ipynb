# %%
from uuid import uuid4
import os
import pandas as pd
from databricks.sdk import WorkspaceClient

from ag_vision.drone.ingest import DroneDataIngest

os.environ.pop('DATABRICKS_HOST', None)
os.environ.pop('DATABRICKS_TOKEN', None)

w = WorkspaceClient(profile='tnau')

# %%
w.config.host
# Out:
# 'https://dbc-d9e47e1c-4080.cloud.databricks.com'

# %%
# Change the following to the location where the local data is stored.
parent_folder_path = '/Users/danielwilliams/Documents/Field Data/drone_upload_test'
raw_image_dir = f'{parent_folder_path}/raw_flight_data/'
files = os.listdir(raw_image_dir)
files = [raw_image_dir + x for x in files]
files
# Out:
# ['/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144351_0235_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKRAW.bin',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144509_0274_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKOBS.obs',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144509_0274_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKNAV.nav',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_Timestamp.MRK',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144413_0246_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_NIR.TIF']

# %%
flight_metadata = {
    "id": str(uuid4()),
    "name": "corn_health_assessment_flight",  # this will be the mission name in the folder path
    "task": "drone_phenotyping",
    "location": {
        "site": "TNAU-Coimbatore".lower(),  # Try to keep these standard ORG-Site EX CIAT-Cali, or CIAT-Arusha....
        "field": "West_Field_03".lower(),
        # what is the name of the field that the trial was run on? The field and location can be the same name if there is no difference.
        "location": "Section_B".lower()
        # The location corresponds to a specific field book. If data is in EBS match the location name.
    },
    "trialProperties": {
        "name": "BETS"  # What is the name of the trial, a trial usually has multiple locations.
    },
    "drone_acquisition_properties": {
        'date': '11/25/2024',
        'drone_make': "DJI",
        'drone_model': "Phantom Mavic 4 Enterprise",
        'camera_make': "Sony",
        'camera_model': "UCM-R",
        'groundControlPoints': True,
        'reflectancePanels': True,
        'reflectancePanelType': 'Micasense',
        'flightHeight': 90.0,
        'horizontalOverlapPercentage': 75.0,
        'verticalOverlapPercentage': 75.0,
        'gpsQuality': "RTK",
        'multispecChannels': ["Red", "Green", "Blue", "NIR"]
    },
    "agronomic_properties": {
        "crop_type": "corn",  # Required
        "growth_stage": "VT",  # optional
        "soil_color": None,
        "weed_pressure": None,
        "irrigation_level": None,
        "tillage_type": None,
        "fertilizer_level": None
    }
}

# %%
# This points to the aps1-prod-tnau-fg workspace _YOU SHOULD NOT NEED TO CHANGE THIS.
workspace_bucket = '/Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data'

ingest = DroneDataIngest(platform='local',  # DONT CHANGE THIS
                         cloud_bucket=workspace_bucket, # Set this to the bucket you want to save the data to.
                         cloud_client=w, # should not need to change.
                         flight_date='11/25/2024',
                         plot_boundary_key=f"{parent_folder_path}/plot_boundary.geojson",
                         gcp_key=f"{parent_folder_path}/gcp_details.geojson",
                         orthomosaic_key=f"{parent_folder_path}/30112024_ORTHO.tif",
                         dem_key=f"{parent_folder_path}/30112024_DSM.tif",
                         flight_metadata_key=f"{parent_folder_path}/flight_details.json")  # If this does not exist then this just tells the code were to save it so it can be uploaded.

# %%
ingest.load_metadata_from_dict(metadata_dict=flight_metadata)

# season is needed to generate the mission dir, This has lots of Validation and will throw assert errors.
ingest.add_season_code_to_metadata(year=2025,
                                   country='IND',
                                   crop='maize',
                                   time_of_year='spring')

# This is the main dir where all the data will be stored.
ingest.generate_drone_mission_dir_path()

# %%
# This saves the metadata locally do it can be uploaded.
ingest.save_flight_metadata_to_json_local()

# %%
# This will be a list of all the raw files from the flight eg: nav, bin, tif, and jpg files.
ingest.generate_raw_ingest_df(file_list=files)

# %%
def determine_camera_type(f_name):
    if "_MS_" in f_name:
        return 'multi-spec'
    elif ".JPG" in f_name:
        return 'rgb'
    else:
        return 'flight_data'

ingest.raw_ingest_df['camera'] = ingest.raw_ingest_df['file_name'].apply(determine_camera_type)

flight_data = ingest.raw_ingest_df[ingest.raw_ingest_df['file_type'] == 'flight_data']

f_ingest_df_list = []

# The flight data needs to be saved with both camera data sets.
for idx, df in ingest.raw_ingest_df.groupby('camera'):
    if idx in ['rgb', 'multi-spec']:
        out_df = pd.concat([df, flight_data])
        out_df['camera'] = idx
        f_ingest_df_list.append(out_df)

f_ingest_df = pd.concat(f_ingest_df_list)
# Out:
# flight_data
# multi-spec
# rgb

# %%
ingest.raw_ingest_df = f_ingest_df

# %%
# generates the new path names where to save it in databricks
ingest.generate_raw_image_dst_path_name()

# %%
ingest.raw_ingest_df.sample(10)
# Out:
#                                              src_path  \
# 37  /Users/danielwilliams/Documents/Field Data/dro...
# 75  /Users/danielwilliams/Documents/Field Data/dro...
# 1   /Users/danielwilliams/Documents/Field Data/dro...
# 38  /Users/danielwilliams/Documents/Field Data/dro...
# 41  /Users/danielwilliams/Documents/Field Data/dro...
# 7   /Users/danielwilliams/Documents/Field Data/dro...
# 70  /Users/danielwilliams/Documents/Field Data/dro...
# 56  /Users/danielwilliams/Documents/Field Data/dro...
# 26  /Users/danielwilliams/Documents/Field Data/dro...
# 27  /Users/danielwilliams/Documents/Field Data/dro...
#
#                              file_name img_ext file_type      camera  \
# 37   DJI_20241124144459_0269_MS_RE.TIF    .TIF      None  multi-spec
# 75       DJI_20241124144501_0270_D.JPG    .JPG      None         rgb
# 1     DJI_20241124144459_0269_MS_R.TIF    .TIF      None  multi-spec
# 38    DJI_20241124144457_0268_MS_R.TIF    .TIF      None  multi-spec
# 41    DJI_20241124144455_0267_MS_G.TIF    .TIF      None  multi-spec
# 7    DJI_20241124144449_0264_MS_RE.TIF    .TIF      None  multi-spec
# 70  DJI_20241124144455_0267_MS_NIR.TIF    .TIF      None  multi-spec
# 56       DJI_20241124144413_0246_D.JPG    .JPG      None         rgb
# 26   DJI_20241124144447_0263_MS_RE.TIF    .TIF      None  multi-spec
# 27    DJI_20241124144501_0270_MS_G.TIF    .TIF      None  multi-spec
#
#                                              dst_path
# 37  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 75  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 1   /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 38  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 41  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 7   /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 70  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 56  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 26  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 27  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...

# %%
# Upload the metadata to databricks
ingest.upload_metadata_to_db()
# Out:
# Uploading: 100%|██████████| 1.65k/1.65k [00:02<00:00, 695B/s]

# %%
# uploads the plot boundaries to databricks
ingest.upload_plot_boundary_to_db()
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/plot_boundary.geojson
# Uploading: 100%|██████████| 190k/190k [00:01<00:00, 125kB/s]

# %%
# Uploads the ground control points to databricks
ingest.upload_gcp_to_db()
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/ground_control_points.geojson
# Uploading: 100%|██████████| 1.28k/1.28k [00:00<00:00, 2.85kB/s]

# %%
# uploads all the raw flight data to databricks
ingest.upload_raw_flight_data_to_db()
# Out:
# 0it [00:00, ?it/s]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   3%|▎         | 256k/9.62M [00:00<00:10, 896kB/s]
# Uploading:   5%|▍         | 480k/9.62M [00:00<00:11, 803kB/s]
# Uploading:  10%|▉         | 976k/9.62M [00:00<00:06, 1.31MB/s]
# Uploading:  15%|█▍        | 1.41M/9.62M [00:00<00:04, 1.97MB/s]
# Uploading:  17%|█▋        | 1.67M/9.62M [00:01<00:05, 1.64MB/s]
# Uploading:  20%|█▉        | 1.89M/9.62M [00:01<00:04, 1.74MB/s]
# Uploading:  26%|██▌       | 2.52M/9.62M [00:01<00:02, 2.67MB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:01<00:02, 2.70MB/s]
# Uploading:  35%|███▌      | 3.39M/9.62M [00:01<00:02, 3.06MB/s]
# Uploading:  39%|███▉      | 3.73M/9.62M [00:01<00:02, 2.93MB/s]
# Uploading:  42%|████▏     | 4.05M/9.62M [00:01<00:02, 2.70MB/s]
# Uploading:  45%|████▍     | 4.33M/9.62M [00:02<00:02, 2.57MB/s]
# Uploading:  48%|████▊     | 4.59M/9.62M [00:02<00:02, 2.57MB/s]
# Uploading:  51%|█████     | 4.92M/9.62M [00:02<00:01, 2.56MB/s]
# Uploading:  55%|█████▌    | 5.31M/9.62M [00:02<00:01, 2.74MB/s]
# Uploading:  61%|██████    | 5.86M/9.62M [00:02<00:01, 2.85MB/s]
# Uploading:  67%|██████▋   | 6.42M/9.62M [00:02<00:01, 2.86MB/s]
# Uploading:  73%|███████▎  | 7.02M/9.62M [00:03<00:00, 3.17MB/s]
# Uploading:  76%|███████▌  | 7.33M/9.62M [00:05<00:04, 570kB/s]
# Uploading:  78%|███████▊  | 7.55M/9.62M [00:06<00:05, 383kB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:08<00:06, 305kB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:08<00:06, 272kB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:09<00:07, 246kB/s]
# Uploading:  83%|████████▎ | 8.00M/9.62M [00:09<00:07, 225kB/s]
# Uploading:  84%|████████▍ | 8.06M/9.62M [00:10<00:07, 225kB/s]
# Uploading:  84%|████████▍ | 8.12M/9.62M [00:10<00:06, 226kB/s]
# Uploading:  85%|████████▌ | 8.22M/9.62M [00:10<00:05, 261kB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:10<00:05, 281kB/s]
# Uploading:  87%|████████▋ | 8.33M/9.62M [00:11<00:04, 297kB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:11<00:04, 303kB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:11<00:03, 360kB/s]
# Uploading:  89%|████████▊ | 8.53M/9.62M [00:11<00:03, 363kB/s]
# Uploading:  90%|████████▉ | 8.62M/9.62M [00:11<00:02, 392kB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:11<00:01, 486kB/s]
# Uploading:  91%|█████████▏| 8.78M/9.62M [00:12<00:02, 407kB/s]
# Uploading:  93%|█████████▎| 8.91M/9.62M [00:12<00:01, 501kB/s]
# Uploading:  93%|█████████▎| 8.97M/9.62M [00:12<00:01, 476kB/s]
# Uploading:  94%|█████████▍| 9.06M/9.62M [00:12<00:01, 532kB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:12<00:01, 445kB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:13<00:00, 510kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:14<00:00, 709kB/s]
# 1it [00:14, 14.23s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 576k/9.62M [00:00<00:04, 2.09MB/s]
# Uploading:   9%|▉         | 928k/9.62M [00:00<00:05, 1.63MB/s]
# Uploading:  11%|█         | 1.06M/9.62M [00:00<00:06, 1.48MB/s]
# Uploading:  13%|█▎        | 1.27M/9.62M [00:00<00:05, 1.50MB/s]
# Uploading:  15%|█▍        | 1.41M/9.62M [00:01<00:06, 1.31MB/s]
# Uploading:  17%|█▋        | 1.66M/9.62M [00:01<00:05, 1.54MB/s]
# Uploading:  19%|█▉        | 1.81M/9.62M [00:01<00:06, 1.35MB/s]
# Uploading:  21%|██▏       | 2.05M/9.62M [00:01<00:04, 1.60MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:01<00:05, 1.43MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:05, 1.44MB/s]
# Uploading:  27%|██▋       | 2.59M/9.62M [00:01<00:05, 1.46MB/s]
# Uploading:  29%|██▊       | 2.77M/9.62M [00:01<00:04, 1.50MB/s]
# Uploading:  31%|███       | 2.95M/9.62M [00:02<00:04, 1.62MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:02<00:05, 1.19MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:02<00:04, 1.36MB/s]
# Uploading:  38%|███▊      | 3.62M/9.62M [00:02<00:04, 1.28MB/s]
# Uploading:  39%|███▉      | 3.78M/9.62M [00:02<00:04, 1.23MB/s]
# Uploading:  43%|████▎     | 4.11M/9.62M [00:02<00:03, 1.64MB/s]
# Uploading:  45%|████▍     | 4.31M/9.62M [00:03<00:03, 1.50MB/s]
# Uploading:  47%|████▋     | 4.50M/9.62M [00:03<00:03, 1.56MB/s]
# Uploading:  49%|████▊     | 4.67M/9.62M [00:03<00:03, 1.52MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:03<00:02, 2.00MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:03<00:02, 1.80MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:03<00:01, 2.17MB/s]
# Uploading:  61%|██████    | 5.89M/9.62M [00:03<00:01, 2.18MB/s]
# Uploading:  64%|██████▎   | 6.11M/9.62M [00:03<00:01, 2.05MB/s]
# Uploading:  66%|██████▋   | 6.38M/9.62M [00:04<00:01, 2.22MB/s]
# Uploading:  69%|██████▉   | 6.64M/9.62M [00:04<00:01, 2.08MB/s]
# Uploading:  72%|███████▏  | 6.91M/9.62M [00:04<00:01, 2.07MB/s]
# Uploading:  76%|███████▌  | 7.33M/9.62M [00:04<00:00, 2.61MB/s]
# Uploading:  79%|███████▉  | 7.59M/9.62M [00:04<00:00, 2.44MB/s]
# Uploading:  82%|████████▏ | 7.84M/9.62M [00:04<00:00, 2.37MB/s]
# Uploading:  85%|████████▍ | 8.17M/9.62M [00:04<00:00, 2.27MB/s]
# Uploading:  90%|████████▉ | 8.66M/9.62M [00:05<00:00, 2.93MB/s]
# Uploading:  93%|█████████▎| 8.98M/9.62M [00:05<00:00, 2.98MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.66MB/s]
# 2it [00:20,  9.44s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  20%|█▉        | 1.91M/9.62M [00:00<00:01, 5.16MB/s]
# Uploading:  25%|██▌       | 2.41M/9.62M [00:00<00:01, 4.81MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:00<00:01, 4.17MB/s]
# Uploading:  34%|███▍      | 3.30M/9.62M [00:00<00:02, 3.18MB/s]
# Uploading:  39%|███▉      | 3.77M/9.62M [00:01<00:01, 3.42MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:01<00:01, 3.22MB/s]
# Uploading:  50%|████▉     | 4.77M/9.62M [00:01<00:01, 2.90MB/s]
# Uploading:  54%|█████▍    | 5.20M/9.62M [00:02<00:04, 1.04MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:02<00:04, 1.04MB/s]
# Uploading:  63%|██████▎   | 6.03M/9.62M [00:03<00:03, 1.22MB/s]
# Uploading:  70%|██████▉   | 6.69M/9.62M [00:03<00:01, 1.78MB/s]
# Uploading:  73%|███████▎  | 7.02M/9.62M [00:03<00:01, 1.66MB/s]
# Uploading:  76%|███████▌  | 7.33M/9.62M [00:03<00:01, 1.57MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:03<00:01, 1.89MB/s]
# Uploading:  83%|████████▎ | 7.97M/9.62M [00:04<00:01, 1.67MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:04<00:00, 2.09MB/s]
# Uploading:  90%|█████████ | 8.67M/9.62M [00:04<00:00, 1.84MB/s]
# Uploading:  94%|█████████▍| 9.05M/9.62M [00:04<00:00, 2.02MB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:04<00:00, 2.00MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.76MB/s]
# 3it [00:26,  7.74s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.36M/9.62M [00:00<00:02, 3.10MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:00<00:02, 2.70MB/s]
# Uploading:  23%|██▎       | 2.25M/9.62M [00:02<00:10, 715kB/s]
# Uploading:  27%|██▋       | 2.64M/9.62M [00:02<00:07, 938kB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:02<00:07, 988kB/s]
# Uploading:  33%|███▎      | 3.20M/9.62M [00:02<00:06, 1.10MB/s]
# Uploading:  35%|███▌      | 3.39M/9.62M [00:03<00:06, 1.08MB/s]
# Uploading:  37%|███▋      | 3.59M/9.62M [00:03<00:05, 1.21MB/s]
# Uploading:  40%|███▉      | 3.84M/9.62M [00:03<00:04, 1.22MB/s]
# Uploading:  42%|████▏     | 4.08M/9.62M [00:03<00:04, 1.20MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:03<00:03, 1.39MB/s]
# Uploading:  48%|████▊     | 4.59M/9.62M [00:03<00:03, 1.42MB/s]
# Uploading:  50%|█████     | 4.83M/9.62M [00:03<00:03, 1.61MB/s]
# Uploading:  52%|█████▏    | 5.02M/9.62M [00:04<00:02, 1.63MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:04<00:02, 1.59MB/s]
# Uploading:  56%|█████▌    | 5.39M/9.62M [00:04<00:03, 1.45MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:04<00:02, 1.69MB/s]
# Uploading:  61%|██████    | 5.88M/9.62M [00:04<00:02, 1.79MB/s]
# Uploading:  63%|██████▎   | 6.06M/9.62M [00:04<00:02, 1.70MB/s]
# Uploading:  65%|██████▍   | 6.25M/9.62M [00:04<00:02, 1.53MB/s]
# Uploading:  67%|██████▋   | 6.48M/9.62M [00:05<00:01, 1.70MB/s]
# Uploading:  69%|██████▉   | 6.66M/9.62M [00:05<00:01, 1.65MB/s]
# Uploading:  72%|███████▏  | 6.89M/9.62M [00:05<00:01, 1.85MB/s]
# Uploading:  74%|███████▎  | 7.09M/9.62M [00:05<00:01, 1.53MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:05<00:01, 2.04MB/s]
# Uploading:  80%|███████▉  | 7.67M/9.62M [00:05<00:01, 1.60MB/s]
# Uploading:  84%|████████▍ | 8.06M/9.62M [00:05<00:00, 1.79MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:06<00:00, 1.78MB/s]
# Uploading:  88%|████████▊ | 8.45M/9.62M [00:06<00:00, 1.78MB/s]
# Uploading:  90%|█████████ | 8.70M/9.62M [00:06<00:00, 1.94MB/s]
# Uploading:  93%|█████████▎| 8.91M/9.62M [00:06<00:00, 1.55MB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:06<00:00, 1.72MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:07<00:00, 1.30MB/s]
# 4it [00:33,  7.76s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  13%|█▎        | 1.22M/9.62M [00:00<00:02, 4.18MB/s]
# Uploading:  17%|█▋        | 1.67M/9.62M [00:00<00:01, 4.34MB/s]
# Uploading:  22%|██▏       | 2.11M/9.62M [00:00<00:02, 2.63MB/s]
# Uploading:  25%|██▌       | 2.41M/9.62M [00:01<00:04, 1.88MB/s]
# Uploading:  27%|██▋       | 2.62M/9.62M [00:01<00:04, 1.75MB/s]
# Uploading:  30%|███       | 2.91M/9.62M [00:01<00:04, 1.72MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:01<00:04, 1.60MB/s]
# Uploading:  36%|███▌      | 3.45M/9.62M [00:01<00:03, 1.94MB/s]
# Uploading:  38%|███▊      | 3.67M/9.62M [00:01<00:03, 1.64MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:02<00:03, 1.62MB/s]
# Uploading:  44%|████▍     | 4.25M/9.62M [00:02<00:03, 1.76MB/s]
# Uploading:  47%|████▋     | 4.55M/9.62M [00:02<00:03, 1.68MB/s]
# Uploading:  50%|█████     | 4.81M/9.62M [00:02<00:03, 1.57MB/s]
# Uploading:  53%|█████▎    | 5.08M/9.62M [00:02<00:02, 1.73MB/s]
# Uploading:  55%|█████▌    | 5.31M/9.62M [00:02<00:02, 1.81MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:02<00:02, 1.75MB/s]
# Uploading:  59%|█████▉    | 5.69M/9.62M [00:03<00:02, 1.58MB/s]
# Uploading:  61%|██████▏   | 5.91M/9.62M [00:03<00:02, 1.42MB/s]
# Uploading:  64%|██████▎   | 6.12M/9.62M [00:03<00:02, 1.49MB/s]
# Uploading:  67%|██████▋   | 6.45M/9.62M [00:03<00:02, 1.61MB/s]
# Uploading:  69%|██████▉   | 6.66M/9.62M [00:03<00:02, 1.54MB/s]
# Uploading:  72%|███████▏  | 6.91M/9.62M [00:03<00:01, 1.60MB/s]
# Uploading:  74%|███████▍  | 7.12M/9.62M [00:04<00:01, 1.73MB/s]
# Uploading:  76%|███████▌  | 7.30M/9.62M [00:04<00:01, 1.69MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:04<00:01, 1.75MB/s]
# Uploading:  80%|████████  | 7.73M/9.62M [00:04<00:01, 1.94MB/s]
# Uploading:  83%|████████▎ | 7.94M/9.62M [00:04<00:00, 1.77MB/s]
# Uploading:  85%|████████▌ | 8.19M/9.62M [00:04<00:00, 1.69MB/s]
# Uploading:  89%|████████▊ | 8.53M/9.62M [00:04<00:00, 2.13MB/s]
# Uploading:  91%|█████████▏| 8.78M/9.62M [00:04<00:00, 2.22MB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:05<00:00, 1.96MB/s]
# Uploading:  96%|█████████▌| 9.22M/9.62M [00:05<00:00, 1.77MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.61MB/s]
# 5it [00:40,  7.23s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▍        | 1.44M/9.62M [00:00<00:01, 5.17MB/s]
# Uploading:  20%|██        | 1.94M/9.62M [00:00<00:02, 3.67MB/s]
# Uploading:  24%|██▎       | 2.28M/9.62M [00:00<00:02, 3.49MB/s]
# Uploading:  27%|██▋       | 2.61M/9.62M [00:00<00:02, 2.88MB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:00<00:02, 2.97MB/s]
# Uploading:  33%|███▎      | 3.22M/9.62M [00:01<00:02, 2.84MB/s]
# Uploading:  36%|███▌      | 3.48M/9.62M [00:01<00:02, 2.78MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:01<00:02, 2.67MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  44%|████▍     | 4.27M/9.62M [00:01<00:02, 2.15MB/s]
# Uploading:  50%|████▉     | 4.77M/9.62M [00:01<00:01, 2.73MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:01<00:01, 2.74MB/s]
# Uploading:  55%|█████▌    | 5.33M/9.62M [00:01<00:01, 2.58MB/s]
# Uploading:  58%|█████▊    | 5.58M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  64%|██████▎   | 6.11M/9.62M [00:02<00:01, 2.95MB/s]
# Uploading:  67%|██████▋   | 6.48M/9.62M [00:02<00:01, 2.63MB/s]
# Uploading:  71%|███████▏  | 6.88M/9.62M [00:02<00:00, 2.92MB/s]
# Uploading:  75%|███████▍  | 7.19M/9.62M [00:02<00:00, 2.87MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:02<00:00, 2.85MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:02<00:00, 2.98MB/s]
# Uploading:  84%|████████▍ | 8.12M/9.62M [00:03<00:00, 2.37MB/s]
# Uploading:  87%|████████▋ | 8.38M/9.62M [00:03<00:00, 2.43MB/s]
# Uploading:  90%|████████▉ | 8.62M/9.62M [00:03<00:00, 2.39MB/s]
# Uploading:  92%|█████████▏| 8.88M/9.62M [00:03<00:00, 1.93MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.82MB/s]
# 6it [00:45,  6.66s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▌        | 1.48M/9.62M [00:00<00:01, 5.29MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:00<00:01, 4.90MB/s]
# Uploading:  25%|██▌       | 2.45M/9.62M [00:00<00:02, 3.72MB/s]
# Uploading:  29%|██▉       | 2.81M/9.62M [00:00<00:02, 3.18MB/s]
# Uploading:  34%|███▎      | 3.23M/9.62M [00:00<00:01, 3.38MB/s]
# Uploading:  37%|███▋      | 3.56M/9.62M [00:01<00:02, 2.93MB/s]
# Uploading:  40%|████      | 3.88M/9.62M [00:01<00:02, 2.54MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:01<00:01, 3.21MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:01<00:01, 3.17MB/s]
# Uploading:  53%|█████▎    | 5.11M/9.62M [00:01<00:01, 3.05MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:01<00:01, 2.63MB/s]
# Uploading:  60%|█████▉    | 5.73M/9.62M [00:01<00:01, 2.62MB/s]
# Uploading:  65%|██████▌   | 6.28M/9.62M [00:02<00:01, 2.63MB/s]
# Uploading:  69%|██████▊   | 6.59M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  74%|███████▍  | 7.11M/9.62M [00:02<00:00, 2.94MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:02<00:00, 2.58MB/s]
# Uploading:  83%|████████▎ | 7.94M/9.62M [00:02<00:00, 2.44MB/s]
# Uploading:  85%|████████▌ | 8.20M/9.62M [00:03<00:01, 1.29MB/s]
# Uploading:  91%|█████████ | 8.75M/9.62M [00:03<00:00, 1.80MB/s]
# Uploading:  94%|█████████▍| 9.03M/9.62M [00:03<00:00, 1.76MB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:03<00:00, 1.77MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.91MB/s]
# 7it [00:50,  6.21s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   5%|▌         | 528k/9.62M [00:00<00:17, 557kB/s]
# Uploading:   6%|▌         | 592k/9.62M [00:01<00:32, 288kB/s]
# Uploading:   7%|▋         | 656k/9.62M [00:02<00:33, 279kB/s]
# Uploading:   8%|▊         | 768k/9.62M [00:02<00:30, 309kB/s]
# Uploading:  13%|█▎        | 1.25M/9.62M [00:02<00:12, 695kB/s]
# Uploading:  14%|█▍        | 1.38M/9.62M [00:02<00:11, 737kB/s]
# Uploading:  20%|█▉        | 1.91M/9.62M [00:02<00:06, 1.29MB/s]
# Uploading:  22%|██▏       | 2.08M/9.62M [00:03<00:06, 1.23MB/s]
# Uploading:  26%|██▌       | 2.47M/9.62M [00:03<00:05, 1.46MB/s]
# Uploading:  27%|██▋       | 2.64M/9.62M [00:03<00:04, 1.52MB/s]
# Uploading:  31%|███       | 3.00M/9.62M [00:03<00:04, 1.67MB/s]
# Uploading:  33%|███▎      | 3.19M/9.62M [00:03<00:03, 1.69MB/s]
# Uploading:  35%|███▍      | 3.36M/9.62M [00:03<00:04, 1.63MB/s]
# Uploading:  38%|███▊      | 3.66M/9.62M [00:03<00:03, 1.95MB/s]
# Uploading:  40%|████      | 3.86M/9.62M [00:04<00:03, 1.63MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:04<00:02, 2.05MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:04<00:03, 1.75MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:04<00:02, 1.97MB/s]
# Uploading:  52%|█████▏    | 5.00M/9.62M [00:04<00:02, 1.76MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:04<00:02, 1.65MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:04<00:02, 2.06MB/s]
# Uploading:  60%|██████    | 5.80M/9.62M [00:05<00:02, 1.82MB/s]
# Uploading:  64%|██████▎   | 6.12M/9.62M [00:05<00:01, 2.12MB/s]
# Uploading:  66%|██████▌   | 6.36M/9.62M [00:05<00:01, 1.86MB/s]
# Uploading:  69%|██████▉   | 6.64M/9.62M [00:05<00:01, 2.03MB/s]
# Uploading:  71%|███████▏  | 6.86M/9.62M [00:05<00:01, 1.87MB/s]
# Uploading:  74%|███████▎  | 7.09M/9.62M [00:05<00:01, 1.99MB/s]
# Uploading:  76%|███████▋  | 7.36M/9.62M [00:06<00:01, 1.76MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:06<00:01, 1.87MB/s]
# Uploading:  82%|████████▏ | 7.89M/9.62M [00:06<00:01, 1.80MB/s]
# Uploading:  84%|████████▍ | 8.08M/9.62M [00:06<00:00, 1.76MB/s]
# Uploading:  87%|████████▋ | 8.33M/9.62M [00:06<00:00, 1.87MB/s]
# Uploading:  89%|████████▉ | 8.56M/9.62M [00:06<00:00, 1.95MB/s]
# Uploading:  91%|█████████ | 8.77M/9.62M [00:06<00:00, 1.82MB/s]
# Uploading:  93%|█████████▎| 8.98M/9.62M [00:06<00:00, 1.72MB/s]
# Uploading:  96%|█████████▌| 9.25M/9.62M [00:07<00:00, 1.95MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:08<00:00, 1.24MB/s]
# 8it [00:59,  6.81s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.38M/9.62M [00:00<00:01, 4.80MB/s]
# Uploading:  19%|█▉        | 1.84M/9.62M [00:00<00:01, 4.18MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:00<00:03, 2.51MB/s]
# Uploading:  27%|██▋       | 2.56M/9.62M [00:00<00:03, 2.27MB/s]
# Uploading:  29%|██▉       | 2.81M/9.62M [00:01<00:03, 2.27MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:01<00:03, 2.19MB/s]
# Uploading:  35%|███▌      | 3.38M/9.62M [00:01<00:03, 2.14MB/s]
# Uploading:  37%|███▋      | 3.59M/9.62M [00:01<00:02, 2.11MB/s]
# Uploading:  39%|███▉      | 3.80M/9.62M [00:01<00:03, 1.99MB/s]
# Uploading:  42%|████▏     | 4.02M/9.62M [00:01<00:03, 1.74MB/s]
# Uploading:  45%|████▌     | 4.34M/9.62M [00:02<00:03, 1.45MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:03<00:09, 532kB/s]
# Uploading:  58%|█████▊    | 5.62M/9.62M [00:03<00:03, 1.21MB/s]
# Uploading:  61%|██████    | 5.89M/9.62M [00:03<00:02, 1.33MB/s]
# Uploading:  64%|██████▎   | 6.11M/9.62M [00:03<00:02, 1.43MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:03<00:02, 1.54MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:04<00:02, 1.44MB/s]
# Uploading:  71%|███████▏  | 6.86M/9.62M [00:04<00:01, 1.68MB/s]
# Uploading:  73%|███████▎  | 7.06M/9.62M [00:04<00:01, 1.68MB/s]
# Uploading:  76%|███████▌  | 7.27M/9.62M [00:04<00:01, 1.54MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:04<00:01, 1.72MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:04<00:01, 1.74MB/s]
# Uploading:  82%|████████▏ | 7.89M/9.62M [00:04<00:01, 1.79MB/s]
# Uploading:  84%|████████▍ | 8.08M/9.62M [00:04<00:00, 1.74MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:05<00:00, 1.48MB/s]
# Uploading:  90%|████████▉ | 8.62M/9.62M [00:05<00:00, 1.75MB/s]
# Uploading:  92%|█████████▏| 8.86M/9.62M [00:05<00:00, 1.66MB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:05<00:00, 1.90MB/s]
# Uploading:  97%|█████████▋| 9.33M/9.62M [00:05<00:00, 1.84MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.48MB/s]
# 9it [01:05,  6.82s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▍        | 1.42M/9.62M [00:00<00:02, 3.46MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:00<00:02, 3.87MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:00<00:02, 2.87MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:00<00:02, 2.69MB/s]
# Uploading:  31%|███       | 2.98M/9.62M [00:01<00:03, 2.15MB/s]
# Uploading:  33%|███▎      | 3.20M/9.62M [00:01<00:03, 2.13MB/s]
# Uploading:  36%|███▌      | 3.45M/9.62M [00:01<00:03, 1.88MB/s]
# Uploading:  40%|████      | 3.89M/9.62M [00:01<00:02, 2.14MB/s]
# Uploading:  44%|████▎     | 4.19M/9.62M [00:01<00:02, 2.13MB/s]
# Uploading:  47%|████▋     | 4.56M/9.62M [00:02<00:02, 2.04MB/s]
# Uploading:  51%|█████▏    | 4.94M/9.62M [00:02<00:02, 2.35MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  57%|█████▋    | 5.44M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:02<00:02, 1.98MB/s]
# Uploading:  62%|██████▏   | 5.95M/9.62M [00:02<00:01, 2.09MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 2.42MB/s]
# Uploading:  68%|██████▊   | 6.58M/9.62M [00:02<00:01, 2.20MB/s]
# Uploading:  71%|███████   | 6.80M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:01, 2.27MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:03<00:01, 2.09MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:03<00:00, 2.69MB/s]
# Uploading:  85%|████████▌ | 8.20M/9.62M [00:03<00:00, 2.71MB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:03<00:00, 2.53MB/s]
# Uploading:  92%|█████████▏| 8.81M/9.62M [00:03<00:00, 2.46MB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:03<00:00, 2.64MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.86MB/s]
# 10it [01:11,  6.39s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   7%|▋         | 672k/9.62M [00:00<00:12, 744kB/s]
# Uploading:   8%|▊         | 752k/9.62M [00:01<00:26, 349kB/s]
# Uploading:   8%|▊         | 800k/9.62M [00:02<00:29, 315kB/s]
# Uploading:   9%|▉         | 912k/9.62M [00:02<00:26, 347kB/s]
# Uploading:  10%|█         | 1.00M/9.62M [00:02<00:21, 421kB/s]
# Uploading:  11%|█▏        | 1.09M/9.62M [00:02<00:19, 465kB/s]
# Uploading:  13%|█▎        | 1.25M/9.62M [00:02<00:15, 567kB/s]
# Uploading:  19%|█▊        | 1.78M/9.62M [00:02<00:06, 1.30MB/s]
# Uploading:  22%|██▏       | 2.08M/9.62M [00:03<00:05, 1.43MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:03<00:04, 1.81MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:03<00:03, 2.00MB/s]
# Uploading:  31%|███▏      | 3.02M/9.62M [00:03<00:03, 2.12MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:03<00:03, 2.16MB/s]
# Uploading:  37%|███▋      | 3.56M/9.62M [00:03<00:02, 2.33MB/s]
# Uploading:  40%|███▉      | 3.81M/9.62M [00:03<00:02, 2.04MB/s]
# Uploading:  44%|████▎     | 4.19M/9.62M [00:04<00:02, 2.46MB/s]
# Uploading:  46%|████▋     | 4.45M/9.62M [00:04<00:02, 2.40MB/s]
# Uploading:  49%|████▉     | 4.70M/9.62M [00:04<00:02, 2.21MB/s]
# Uploading:  51%|█████▏    | 4.94M/9.62M [00:04<00:02, 2.01MB/s]
# Uploading:  56%|█████▌    | 5.38M/9.62M [00:04<00:01, 2.55MB/s]
# Uploading:  59%|█████▉    | 5.66M/9.62M [00:04<00:01, 2.13MB/s]
# Uploading:  61%|██████    | 5.89M/9.62M [00:04<00:01, 2.17MB/s]
# Uploading:  64%|██████▎   | 6.12M/9.62M [00:04<00:01, 2.20MB/s]
# Uploading:  69%|██████▊   | 6.59M/9.62M [00:05<00:01, 2.81MB/s]
# Uploading:  72%|███████▏  | 6.89M/9.62M [00:05<00:01, 2.79MB/s]
# Uploading:  75%|███████▍  | 7.17M/9.62M [00:05<00:01, 2.49MB/s]
# Uploading:  77%|███████▋  | 7.42M/9.62M [00:05<00:01, 2.26MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:05<00:00, 2.71MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:05<00:00, 2.86MB/s]
# Uploading:  88%|████████▊ | 8.44M/9.62M [00:05<00:00, 2.57MB/s]
# Uploading:  91%|█████████ | 8.73M/9.62M [00:06<00:00, 2.30MB/s]
# Uploading:  95%|█████████▌| 9.16M/9.62M [00:06<00:00, 2.60MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:07<00:00, 1.29MB/s]
# 11it [01:19,  6.84s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▋         | 640k/9.62M [00:00<00:12, 739kB/s]
# Uploading:   7%|▋         | 720k/9.62M [00:01<00:27, 335kB/s]
# Uploading:   8%|▊         | 768k/9.62M [00:02<00:29, 313kB/s]
# Uploading:   9%|▉         | 864k/9.62M [00:02<00:28, 317kB/s]
# Uploading:  11%|█         | 1.03M/9.62M [00:02<00:21, 420kB/s]
# Uploading:  12%|█▏        | 1.16M/9.62M [00:02<00:17, 515kB/s]
# Uploading:  13%|█▎        | 1.28M/9.62M [00:02<00:14, 619kB/s]
# Uploading:  16%|█▌        | 1.56M/9.62M [00:03<00:08, 965kB/s]
# Uploading:  21%|██        | 1.98M/9.62M [00:03<00:05, 1.58MB/s]
# Uploading:  24%|██▎       | 2.28M/9.62M [00:03<00:04, 1.86MB/s]
# Uploading:  26%|██▌       | 2.52M/9.62M [00:03<00:04, 1.67MB/s]
# Uploading:  31%|███       | 2.97M/9.62M [00:03<00:03, 2.31MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:03<00:03, 1.89MB/s]
# Uploading:  38%|███▊      | 3.64M/9.62M [00:03<00:03, 1.97MB/s]
# Uploading:  40%|████      | 3.89M/9.62M [00:04<00:02, 2.06MB/s]
# Uploading:  43%|████▎     | 4.12M/9.62M [00:04<00:02, 1.93MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:04<00:02, 2.16MB/s]
# Uploading:  49%|████▊     | 4.67M/9.62M [00:04<00:02, 2.00MB/s]
# Uploading:  51%|█████▏    | 4.94M/9.62M [00:04<00:02, 2.18MB/s]
# Uploading:  55%|█████▍    | 5.25M/9.62M [00:04<00:01, 2.42MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:04<00:02, 2.08MB/s]
# Uploading:  59%|█████▉    | 5.72M/9.62M [00:04<00:02, 1.92MB/s]
# Uploading:  63%|██████▎   | 6.03M/9.62M [00:05<00:01, 2.14MB/s]
# Uploading:  67%|██████▋   | 6.41M/9.62M [00:05<00:01, 2.08MB/s]
# Uploading:  70%|██████▉   | 6.70M/9.62M [00:05<00:01, 1.87MB/s]
# Uploading:  74%|███████▍  | 7.12M/9.62M [00:05<00:01, 2.31MB/s]
# Uploading:  77%|███████▋  | 7.38M/9.62M [00:05<00:01, 2.22MB/s]
# Uploading:  79%|███████▉  | 7.61M/9.62M [00:05<00:00, 2.14MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:06<00:00, 1.96MB/s]
# Uploading:  85%|████████▌ | 8.19M/9.62M [00:06<00:00, 2.34MB/s]
# Uploading:  88%|████████▊ | 8.44M/9.62M [00:06<00:00, 2.32MB/s]
# Uploading:  90%|█████████ | 8.67M/9.62M [00:06<00:00, 2.27MB/s]
# Uploading:  93%|█████████▎| 8.91M/9.62M [00:06<00:00, 1.90MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:07<00:00, 1.27MB/s]
# 12it [01:27,  7.17s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  17%|█▋        | 1.67M/9.62M [00:00<00:01, 5.75MB/s]
# Uploading:  23%|██▎       | 2.23M/9.62M [00:00<00:01, 4.90MB/s]
# Uploading:  28%|██▊       | 2.67M/9.62M [00:00<00:02, 3.43MB/s]
# Uploading:  32%|███▏      | 3.03M/9.62M [00:00<00:02, 3.19MB/s]
# Uploading:  35%|███▍      | 3.33M/9.62M [00:01<00:02, 2.68MB/s]
# Uploading:  37%|███▋      | 3.59M/9.62M [00:01<00:02, 2.69MB/s]
# Uploading:  41%|████      | 3.92M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  43%|████▎     | 4.17M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  46%|████▋     | 4.47M/9.62M [00:01<00:02, 2.46MB/s]
# Uploading:  49%|████▉     | 4.72M/9.62M [00:01<00:02, 2.47MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:01<00:01, 2.45MB/s]
# Uploading:  54%|█████▍    | 5.20M/9.62M [00:01<00:02, 2.30MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:01<00:01, 2.51MB/s]
# Uploading:  60%|█████▉    | 5.75M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  62%|██████▏   | 5.98M/9.62M [00:02<00:01, 2.05MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  69%|██████▉   | 6.66M/9.62M [00:02<00:01, 2.63MB/s]
# Uploading:  72%|███████▏  | 6.92M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  75%|███████▍  | 7.17M/9.62M [00:02<00:01, 2.09MB/s]
# Uploading:  78%|███████▊  | 7.52M/9.62M [00:02<00:00, 2.39MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  84%|████████▍ | 8.08M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  87%|████████▋ | 8.34M/9.62M [00:03<00:00, 2.09MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:03<00:00, 2.43MB/s]
# Uploading:  94%|█████████▎| 9.00M/9.62M [00:03<00:00, 2.55MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:03<00:00, 2.39MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.07MB/s]
# 12it [01:31,  7.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # uploads all the raw flight data to databricks
# ----> 2 ingest.upload_raw_flight_data_to_db()
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/drone/ingest.py:287, in DroneDataIngest.upload_raw_flight_data_to_db(self)
#     285 for idx, row in tqdm(self.raw_ingest_df.iterrows()):
#     286     try:
# --> 287         dio.upload_file_with_progress(w=self.cloud_client,
#     288                                       local_file_path=row['src_path'],
#     289                                       volume_path=row['dst_path'])
#     290         self.raw_ingest_df.loc[idx, 'status'] = "success"
#     291     except Exception as e:
#
# File ~/PycharmProjects/ag-vision-dataops/ag_vision/data_io/databricks_io.py:37, in upload_file_with_progress(w, local_file_path, volume_path, chunk_size)
#      35 with open(local_file_path, "rb") as f:
#      36     with tqdm.wrapattr(f, "read", total=file_size, unit="B", unit_scale=True, desc="Uploading") as f_wrapped:
# ---> 37         w.files.upload(volume_path, f_wrapped, overwrite=True)
#      39 logger.info(f"Upload complete: {volume_path}")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1149, in FilesExt.upload(self, file_path, contents, overwrite, part_size, use_parallel, parallelism)
#    1147     return UploadStreamResult()
#    1148 elif ctx.content_length is not None:
# -> 1149     self._upload_single_thread_with_known_size(ctx, contents)
#    1150     return UploadStreamResult()
#    1151 else:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1229, in FilesExt._upload_single_thread_with_known_size(self, ctx, contents)
#    1227 if ctx.content_length < self._config.files_ext_multipart_upload_min_stream_size:
#    1228     _LOG.debug(f"Using single-shot upload for input stream of size {ctx.content_length} bytes")
# -> 1229     return self._single_thread_single_shot_upload(ctx, contents)
#    1230 else:
#    1231     _LOG.debug(f"Using multipart upload for input stream of size {ctx.content_length} bytes")
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:1237, in FilesExt._single_thread_single_shot_upload(self, ctx, contents)
#    1235 """Upload a file with a known size."""
#    1236 _LOG.debug(f"Using single-shot upload for input stream")
# -> 1237 return super().upload(file_path=ctx.target_path, contents=contents, overwrite=ctx.overwrite)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/service/files.py:953, in FilesAPI.upload(self, file_path, contents, overwrite)
#     948     query["overwrite"] = overwrite
#     949 headers = {
#     950     "Content-Type": "application/octet-stream",
#     951 }
# --> 953 self._api.do(
#     954     "PUT",
#     955     f"/api/2.0/fs/files{_escape_multi_segment_path_parameter(file_path)}",
#     956     query=query,
#     957     headers=headers,
#     958     data=contents,
#     959 )
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/core.py:94, in ApiClient.do(self, method, path, url, query, headers, body, raw, files, data, auth, response_headers)
#      92     path = re.sub("^/api/2.0/fs/files//", "/api/2.0/fs/files/", path)
#      93     url = f"{self._cfg.host}{path}"
# ---> 94 return self._api_client.do(
#      95     method=method,
#      96     url=url,
#      97     query=query,
#      98     headers=headers,
#      99     body=body,
#     100     raw=raw,
#     101     files=files,
#     102     data=data,
#     103     auth=auth,
#     104     response_headers=response_headers,
#     105 )
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:199, in _BaseClient.do(self, method, url, query, headers, body, raw, files, data, auth, response_headers)
#     196     logger.debug(f"Retry disabled for non-seekable stream: type={type(data)}")
#     197     call = self._perform
# --> 199 response = call(
#     200     method,
#     201     url,
#     202     query=query,
#     203     headers=headers,
#     204     body=body,
#     205     raw=raw,
#     206     files=files,
#     207     data=data,
#     208     auth=auth,
#     209 )
#     211 resp = dict()
#     212 for header in response_headers if response_headers else []:
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:286, in _BaseClient._perform(self, method, url, query, headers, body, raw, files, data, auth)
#     274 def _perform(
#     275     self,
#     276     method: str,
#    (...)    284     auth: Callable[[requests.PreparedRequest], requests.PreparedRequest] = None,
#     285 ):
# --> 286     response = self._session.request(
#     287         method,
#     288         url,
#     289         params=self._fix_query_string(query),
#     290         json=body,
#     291         headers=headers,
#     292         files=files,
#     293         data=data,
#     294         auth=auth,
#     295         stream=raw,
#     296         timeout=self._http_timeout_seconds,
#     297     )
#     298     self._record_request_log(response, raw=raw or data is not None or files is not None)
#     299     error = self._error_parser.get_api_error(response)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/PycharmProjects/ag-vision-dataops/.venv/lib/python3.11/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# If you have a dem generated you can upload it so we don't need to reprocess.
ingest.upload_dem_to_db(method='agisoft',  # the method used to generate the dem.
                        dem_date='11/25/2024',  # the date the dem was generated.
                        file_name='dem.tif')
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/2024-11-25/dem/agisoft_2024-11-25/dem.tif
# Uploading:  54%|█████▍    | 800M/1.45G [05:36<08:11, 1.47MB/s]

# %%
# f"{drone_flight_path}/orthomosaic/{method}_{date}/{image_name}"
ingest.upload_orthomosaic_to_db(method='agisoft',  # the method used to generate the ortho.
                                ortho_date='11/25/2024', # the date the ortho was generated.
                                camera='multi-spec', # The camera that was used.
                                file_name='ms.tif')  # if RGB then you can name it rgb.tif
