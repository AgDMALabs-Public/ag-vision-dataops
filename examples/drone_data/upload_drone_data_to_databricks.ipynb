# %%
from uuid import uuid4
import os
from dotenv import load_dotenv
from databricks.sdk import WorkspaceClient

from ag_vision.drone.ingest import DroneDataIngest

# Load environment variables
load_dotenv(".env")

os.environ.pop('DATABRICKS_HOST', None)
os.environ.pop('DATABRICKS_TOKEN', None)

w = WorkspaceClient(profile='tnau')

# %%
# Change the following to the location where the local data is stored.
parent_folder_path = '/Users/danielwilliams/Documents/Field Data/drone_upload_test'
raw_image_dir = f'{parent_folder_path}/raw_flight_data/'
files = os.listdir(raw_image_dir)
files = [raw_image_dir + x for x in files]
files
# Out:
# ['/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144351_0235_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKRAW.bin',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144509_0274_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKOBS.obs',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144507_0273_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144509_0274_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144457_0268_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_PPKNAV.nav',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144445_0262_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_202411301311_002_TNAU-VBN-30112024-20_Timestamp.MRK',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144413_0246_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144437_0258_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144453_0266_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144459_0269_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144441_0260_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144451_0265_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144455_0267_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144443_0261_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144501_0270_D.JPG',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144439_0259_MS_G.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144505_0272_MS_R.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144449_0264_MS_NIR.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144503_0271_MS_RE.TIF',
#  '/Users/danielwilliams/Documents/Field Data/drone_upload_test/raw_flight_data/DJI_20241124144447_0263_MS_NIR.TIF']

# %%
flight_metadata = {
    "id": str(uuid4()),
    "name": "corn_health_assessment_flight",  # this will be the mission name in the folder path
    "task": "drone_phenotyping",
    "location": {
        "site": "TNAU-Coimbatore".lower(),  # Try to keep these standard ORG-Site EX CIAT-Cali, or CIAT-Arusha....
        "field": "West_Field_03".lower(),
        # what is the name of the field that the trial was run on? The field and location can be the same name if there is no difference.
        "location": "Section_B".lower()
        # The location corresponds to a specific field book. If data is in EBS match the location name.
    },
    "trialProperties": {
        "name": "BETS"  # What is the name of the trial, a trial usually has multiple locations.
    },
    "drone_acquisition_properties": {
        'date': '11/25/2024',
        'drone_make': "DJI",
        'drone_model': "Phantom Mavic 4 Enterprise",
        'camera_make': "Sony",
        'camera_model': "UCM-R",
        'groundControlPoints': True,
        'reflectancePanels': True,
        'reflectancePanelType': 'Micasense',
        'flightHeight': 90.0,
        'horizontalOverlapPercentage': 75.0,
        'verticalOverlapPercentage': 75.0,
        'gpsQuality': "RTK",
        'multispecChannels': ["Red", "Green", "Blue", "NIR"]
    },
    "agronomic_properties": {
        "crop_type": "corn",  # Required
        "growth_stage": "VT",  # optional
        "soil_color": None,
        "weed_pressure": None,
        "irrigation_level": None,
        "tillage_type": None,
        "fertilizer_level": None
    }
}

# %%
# This points to the aps1-prod-tnau-fg workspace _YOU SHOULD NOT NEED TO CHANGE THIS.
workspace_bucket = '/Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data'

ingest = DroneDataIngest(platform='local',  # DONT CHANGE THIS
                         cloud_bucket=workspace_bucket,
                         cloud_client=w,
                         ingest_df=None,  # This will be set LATER
                         flight_date='11/25/2024',
                         plot_boundary_key=f"{parent_folder_path}/plot_boundary.geojson",
                         # must be geojson but name does not matter
                         gcp_key=f"{parent_folder_path}/gcp_details.geojson",
                         # must be geojson but name does not matter
                         orthomosaic_key=f"{parent_folder_path}/30112024_ORTHO.tif",
                         dem_key=f"{parent_folder_path}/30112024_DSM.tif",
                         flight_metadata_key=f"{parent_folder_path}/flight_details.json")  # If this does not exist then this just tells the code were to save it so it can be uploaded.

# %%
ingest.load_metadata_from_dict(metadata_dict=flight_metadata)

# season is needed to generate the mission dir, This has lots of Validation and will throw assert errors.
ingest.add_season_code_to_metadata(year=2025,
                                   country='IND',
                                   crop='maize',
                                   time_of_year='spring')

# This is the main dir where all the data will be stored.
ingest.generate_drone_mission_dir_path()

# %%
# This saves the metadata locally do it can be uploaded.
ingest.save_flight_metadata_to_json_local()

# %%
# This will be a list of all the raw files from the flight eg: nav, bin, tif, and jpg files.
ingest.generate_ingest_df(file_list=files)

# %%
# This tells us if it's an image or a flight data file
ingest.ingest_df['file_type'] = ingest.ingest_df['img_ext'].apply(
    lambda x: 'raw_image' if x.lower() in ['.jpeg', '.tif', '.tiff', '.jpg'] else 'flight_data')

# %%
# generates the new path names where to save it in databricks
ingest.generate_raw_image_dst_path_name()

# %%
ingest.ingest_df.head()
# Out:
#                                             src_path  \
# 0  /Users/danielwilliams/Documents/Field Data/dro...
# 1  /Users/danielwilliams/Documents/Field Data/dro...
# 2  /Users/danielwilliams/Documents/Field Data/dro...
# 3  /Users/danielwilliams/Documents/Field Data/dro...
# 4  /Users/danielwilliams/Documents/Field Data/dro...
#
#                                            file_name img_ext    file_type  \
# 0                   DJI_20241124144351_0235_MS_R.TIF    .TIF    raw_image
# 1                   DJI_20241124144459_0269_MS_R.TIF    .TIF    raw_image
# 2                  DJI_20241124144457_0268_MS_RE.TIF    .TIF    raw_image
# 3  DJI_202411301311_002_TNAU-VBN-30112024-20_PPKR...    .bin  flight_data
# 4                 DJI_20241124144453_0266_MS_NIR.TIF    .TIF    raw_image
#
#                                             dst_path
# 0  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 1  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 2  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 3  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...
# 4  /Volumes/aps1_prod_tnau_fg_catalog_13365825920...

# %%
# Upload the metadata to databricks
ingest.upload_metadata_to_db()
# Out:
# Uploading: 100%|██████████| 1.65k/1.65k [00:02<00:00, 638B/s]

# %%
# uploads the plot boundaries to databricks
ingest.upload_plot_boundary_to_db()
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/plot_boundary.geojson
# Uploading: 100%|██████████| 190k/190k [00:01<00:00, 114kB/s]

# %%
# Uploads the ground control points to databricks
ingest.upload_gcp_to_db()
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/field_data/ground_control_points.geojson
# Uploading: 100%|██████████| 1.28k/1.28k [00:00<00:00, 2.07kB/s]

# %%
# uploads all the raw flight data to databricks
ingest.upload_raw_flight_data_to_db()
# Out:
# 0it [00:00, ?it/s]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   2%|▏         | 160k/9.62M [00:00<00:18, 535kB/s]
# Uploading:   4%|▍         | 416k/9.62M [00:00<00:14, 652kB/s]
# Uploading:   8%|▊         | 784k/9.62M [00:01<00:11, 785kB/s]
# Uploading:  14%|█▍        | 1.34M/9.62M [00:01<00:07, 1.20MB/s]
# Uploading:  23%|██▎       | 2.20M/9.62M [00:01<00:03, 2.27MB/s]
# Uploading:  27%|██▋       | 2.58M/9.62M [00:01<00:03, 2.03MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:01<00:02, 2.76MB/s]
# Uploading:  38%|███▊      | 3.64M/9.62M [00:02<00:02, 2.49MB/s]
# Uploading:  41%|████▏     | 3.97M/9.62M [00:02<00:02, 2.60MB/s]
# Uploading:  45%|████▍     | 4.28M/9.62M [00:02<00:02, 2.55MB/s]
# Uploading:  50%|█████     | 4.84M/9.62M [00:02<00:01, 2.79MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:02<00:01, 3.13MB/s]
# Uploading:  60%|█████▉    | 5.77M/9.62M [00:02<00:01, 3.27MB/s]
# Uploading:  66%|██████▋   | 6.38M/9.62M [00:02<00:00, 3.85MB/s]
# Uploading:  71%|███████   | 6.83M/9.62M [00:02<00:00, 4.01MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:14<00:18, 138kB/s]
# Uploading:  75%|███████▌  | 7.25M/9.62M [00:14<00:18, 135kB/s]
# Uploading:  78%|███████▊  | 7.55M/9.62M [00:16<00:15, 138kB/s]
# Uploading:  81%|████████  | 7.77M/9.62M [00:17<00:12, 160kB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:18<00:10, 170kB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:18<00:08, 190kB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:18<00:07, 204kB/s]
# Uploading:  86%|████████▌ | 8.30M/9.62M [00:19<00:05, 246kB/s]
# Uploading:  88%|████████▊ | 8.44M/9.62M [00:19<00:04, 268kB/s]
# Uploading:  89%|████████▉ | 8.61M/9.62M [00:19<00:03, 323kB/s]
# Uploading:  91%|█████████▏| 8.78M/9.62M [00:20<00:02, 378kB/s]
# Uploading:  93%|█████████▎| 8.97M/9.62M [00:20<00:01, 440kB/s]
# Uploading:  96%|█████████▌| 9.20M/9.62M [00:20<00:00, 533kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:21<00:00, 461kB/s]
# 1it [00:21, 21.87s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   8%|▊         | 752k/9.62M [00:00<00:03, 2.52MB/s]
# Uploading:  13%|█▎        | 1.20M/9.62M [00:00<00:04, 2.00MB/s]
# Uploading:  17%|█▋        | 1.59M/9.62M [00:00<00:03, 2.44MB/s]
# Uploading:  19%|█▉        | 1.88M/9.62M [00:00<00:04, 1.81MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:01<00:04, 1.59MB/s]
# Uploading:  26%|██▌       | 2.50M/9.62M [00:01<00:03, 1.94MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:01<00:04, 1.70MB/s]
# Uploading:  32%|███▏      | 3.05M/9.62M [00:01<00:03, 2.01MB/s]
# Uploading:  34%|███▍      | 3.28M/9.62M [00:01<00:03, 1.78MB/s]
# Uploading:  38%|███▊      | 3.61M/9.62M [00:01<00:03, 2.10MB/s]
# Uploading:  41%|████      | 3.92M/9.62M [00:02<00:02, 2.11MB/s]
# Uploading:  43%|████▎     | 4.17M/9.62M [00:02<00:02, 2.17MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:02<00:02, 2.61MB/s]
# Uploading:  51%|█████     | 4.86M/9.62M [00:02<00:02, 2.28MB/s]
# Uploading:  55%|█████▍    | 5.25M/9.62M [00:02<00:01, 2.64MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  61%|██████    | 5.83M/9.62M [00:02<00:01, 2.55MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 3.18MB/s]
# Uploading:  69%|██████▉   | 6.66M/9.62M [00:03<00:01, 2.60MB/s]
# Uploading:  76%|███████▌  | 7.27M/9.62M [00:03<00:00, 3.40MB/s]
# Uploading:  79%|███████▉  | 7.62M/9.62M [00:03<00:00, 2.89MB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:03<00:00, 3.19MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:03<00:00, 3.18MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:03<00:00, 2.97MB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:03<00:00, 3.21MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.70MB/s]
# 2it [00:27, 12.50s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   8%|▊         | 816k/9.62M [00:00<00:07, 1.18MB/s]
# Uploading:  10%|▉         | 944k/9.62M [00:02<00:27, 336kB/s]
# Uploading:  10%|█         | 0.98M/9.62M [00:02<00:28, 317kB/s]
# Uploading:  12%|█▏        | 1.12M/9.62M [00:02<00:25, 347kB/s]
# Uploading:  14%|█▍        | 1.36M/9.62M [00:03<00:19, 445kB/s]
# Uploading:  19%|█▉        | 1.86M/9.62M [00:03<00:09, 879kB/s]
# Uploading:  22%|██▏       | 2.08M/9.62M [00:03<00:08, 945kB/s]
# Uploading:  27%|██▋       | 2.58M/9.62M [00:03<00:05, 1.47MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:03<00:03, 1.92MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:03<00:03, 2.10MB/s]
# Uploading:  40%|███▉      | 3.84M/9.62M [00:04<00:02, 2.48MB/s]
# Uploading:  43%|████▎     | 4.16M/9.62M [00:04<00:02, 2.38MB/s]
# Uploading:  46%|████▌     | 4.44M/9.62M [00:04<00:02, 2.48MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:04<00:01, 2.86MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:04<00:01, 2.80MB/s]
# Uploading:  57%|█████▋    | 5.48M/9.62M [00:04<00:01, 2.86MB/s]
# Uploading:  61%|██████    | 5.84M/9.62M [00:04<00:01, 3.02MB/s]
# Uploading:  64%|██████▍   | 6.16M/9.62M [00:04<00:01, 2.99MB/s]
# Uploading:  67%|██████▋   | 6.48M/9.62M [00:04<00:01, 3.08MB/s]
# Uploading:  71%|███████   | 6.80M/9.62M [00:05<00:01, 2.82MB/s]
# Uploading:  75%|███████▍  | 7.17M/9.62M [00:05<00:00, 3.09MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:05<00:00, 3.10MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:05<00:00, 2.94MB/s]
# Uploading:  85%|████████▍ | 8.17M/9.62M [00:05<00:00, 3.15MB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:07<00:01, 646kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:08<00:00, 1.19MB/s]
# 3it [00:36, 10.67s/it]
# Uploading:   0%|          | 0.00/4.96M [00:00<?, ?B/s]
# Uploading:  34%|███▎      | 1.59M/4.73M [00:00<00:00, 5.18MB/s]
# Uploading:  44%|████▍     | 2.09M/4.73M [00:00<00:00, 5.17MB/s]
# Uploading:  55%|█████▍    | 2.59M/4.73M [00:00<00:00, 3.29MB/s]
# Uploading:  66%|██████▌   | 3.11M/4.73M [00:00<00:00, 3.60MB/s]
# Uploading:  74%|███████▍  | 3.50M/4.73M [00:01<00:00, 2.84MB/s]
# Uploading:  81%|████████  | 3.81M/4.73M [00:01<00:00, 2.89MB/s]
# Uploading:  87%|████████▋ | 4.12M/4.73M [00:01<00:00, 2.64MB/s]
# Uploading:  93%|█████████▎| 4.41M/4.73M [00:01<00:00, 2.65MB/s]
# Uploading: 100%|██████████| 4.73M/4.73M [00:03<00:00, 1.35MB/s]
# 4it [00:39,  7.91s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 592k/9.62M [00:00<00:09, 999kB/s]
# Uploading:   7%|▋         | 704k/9.62M [00:02<00:36, 254kB/s]
# Uploading:   8%|▊         | 768k/9.62M [00:02<00:37, 249kB/s]
# Uploading:   9%|▉         | 896k/9.62M [00:02<00:32, 284kB/s]
# Uploading:  12%|█▏        | 1.17M/9.62M [00:03<00:19, 450kB/s]
# Uploading:  19%|█▉        | 1.81M/9.62M [00:03<00:08, 958kB/s]
# Uploading:  20%|██        | 1.97M/9.62M [00:03<00:08, 996kB/s]
# Uploading:  25%|██▌       | 2.45M/9.62M [00:03<00:04, 1.53MB/s]
# Uploading:  28%|██▊       | 2.70M/9.62M [00:03<00:05, 1.37MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:04<00:03, 1.79MB/s]
# Uploading:  35%|███▌      | 3.41M/9.62M [00:04<00:04, 1.62MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:04<00:03, 1.94MB/s]
# Uploading:  42%|████▏     | 4.00M/9.62M [00:04<00:03, 1.71MB/s]
# Uploading:  45%|████▍     | 4.28M/9.62M [00:04<00:02, 1.92MB/s]
# Uploading:  47%|████▋     | 4.52M/9.62M [00:04<00:02, 1.84MB/s]
# Uploading:  50%|████▉     | 4.77M/9.62M [00:04<00:02, 2.00MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:05<00:02, 2.10MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:05<00:02, 1.96MB/s]
# Uploading:  58%|█████▊    | 5.59M/9.62M [00:05<00:01, 2.26MB/s]
# Uploading:  61%|██████    | 5.83M/9.62M [00:05<00:01, 2.11MB/s]
# Uploading:  63%|██████▎   | 6.05M/9.62M [00:05<00:01, 2.12MB/s]
# Uploading:  66%|██████▌   | 6.36M/9.62M [00:05<00:01, 2.30MB/s]
# Uploading:  69%|██████▊   | 6.59M/9.62M [00:05<00:01, 2.12MB/s]
# Uploading:  71%|███████▏  | 6.88M/9.62M [00:05<00:01, 2.28MB/s]
# Uploading:  74%|███████▍  | 7.11M/9.62M [00:06<00:01, 2.17MB/s]
# Uploading:  76%|███████▋  | 7.34M/9.62M [00:06<00:01, 2.19MB/s]
# Uploading:  79%|███████▉  | 7.64M/9.62M [00:06<00:00, 2.43MB/s]
# Uploading:  82%|████████▏ | 7.89M/9.62M [00:06<00:00, 2.18MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:06<00:00, 2.27MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:06<00:00, 2.29MB/s]
# Uploading:  90%|████████▉ | 8.62M/9.62M [00:06<00:00, 2.19MB/s]
# Uploading:  93%|█████████▎| 8.94M/9.62M [00:06<00:00, 2.39MB/s]
# Uploading:  95%|█████████▌| 9.17M/9.62M [00:06<00:00, 2.28MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:07<00:00, 1.27MB/s]
# 5it [00:47,  7.94s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.53M/9.62M [00:00<00:01, 4.80MB/s]
# Uploading:  22%|██▏       | 2.08M/9.62M [00:00<00:01, 4.94MB/s]
# Uploading:  27%|██▋       | 2.56M/9.62M [00:00<00:02, 3.12MB/s]
# Uploading:  30%|███       | 2.91M/9.62M [00:00<00:02, 2.69MB/s]
# Uploading:  33%|███▎      | 3.19M/9.62M [00:01<00:02, 2.73MB/s]
# Uploading:  37%|███▋      | 3.56M/9.62M [00:01<00:02, 2.51MB/s]
# Uploading:  40%|███▉      | 3.81M/9.62M [00:01<00:02, 2.49MB/s]
# Uploading:  44%|████▍     | 4.23M/9.62M [00:01<00:02, 2.50MB/s]
# Uploading:  47%|████▋     | 4.48M/9.62M [00:01<00:02, 2.32MB/s]
# Uploading:  51%|█████     | 4.86M/9.62M [00:01<00:01, 2.63MB/s]
# Uploading:  53%|█████▎    | 5.12M/9.62M [00:01<00:02, 2.23MB/s]
# Uploading:  56%|█████▌    | 5.38M/9.62M [00:02<00:01, 2.31MB/s]
# Uploading:  58%|█████▊    | 5.62M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  61%|██████    | 5.86M/9.62M [00:02<00:01, 2.27MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:02<00:01, 2.29MB/s]
# Uploading:  66%|██████▋   | 6.38M/9.62M [00:02<00:01, 2.27MB/s]
# Uploading:  69%|██████▉   | 6.64M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  72%|███████▏  | 6.89M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  74%|███████▍  | 7.12M/9.62M [00:02<00:01, 2.26MB/s]
# Uploading:  77%|███████▋  | 7.41M/9.62M [00:02<00:00, 2.42MB/s]
# Uploading:  79%|███████▉  | 7.64M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading:  82%|████████▏ | 7.88M/9.62M [00:03<00:00, 2.23MB/s]
# Uploading:  85%|████████▍ | 8.16M/9.62M [00:03<00:00, 2.34MB/s]
# Uploading:  88%|████████▊ | 8.42M/9.62M [00:03<00:00, 2.39MB/s]
# Uploading:  90%|████████▉ | 8.66M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  93%|█████████▎| 8.95M/9.62M [00:03<00:00, 2.33MB/s]
# Uploading:  96%|█████████▌| 9.19M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.80MB/s]
# 6it [00:53,  7.15s/it]
# Uploading:   0%|          | 0.00/7.43M [00:00<?, ?B/s]
# Uploading:   7%|▋         | 512k/7.08M [00:00<00:08, 819kB/s]
# Uploading:   8%|▊         | 608k/7.08M [00:01<00:24, 279kB/s]
# Uploading:   9%|▉         | 656k/7.08M [00:02<00:26, 253kB/s]
# Uploading:  10%|█         | 736k/7.08M [00:02<00:28, 237kB/s]
# Uploading:  12%|█▏        | 896k/7.08M [00:02<00:21, 308kB/s]
# Uploading:  19%|█▊        | 1.31M/7.08M [00:03<00:09, 606kB/s]
# Uploading:  28%|██▊       | 1.97M/7.08M [00:03<00:05, 1.04MB/s]
# Uploading:  35%|███▌      | 2.50M/7.08M [00:03<00:03, 1.53MB/s]
# Uploading:  39%|███▉      | 2.75M/7.08M [00:03<00:03, 1.38MB/s]
# Uploading:  43%|████▎     | 3.05M/7.08M [00:04<00:03, 1.40MB/s]
# Uploading:  46%|████▌     | 3.23M/7.08M [00:04<00:02, 1.46MB/s]
# Uploading:  51%|█████     | 3.62M/7.08M [00:04<00:02, 1.71MB/s]
# Uploading:  54%|█████▍    | 3.83M/7.08M [00:04<00:02, 1.68MB/s]
# Uploading:  59%|█████▉    | 4.20M/7.08M [00:04<00:01, 1.90MB/s]
# Uploading:  62%|██████▏   | 4.41M/7.08M [00:04<00:01, 1.78MB/s]
# Uploading:  68%|██████▊   | 4.81M/7.08M [00:04<00:01, 2.08MB/s]
# Uploading:  71%|███████   | 5.03M/7.08M [00:05<00:01, 1.81MB/s]
# Uploading:  77%|███████▋  | 5.42M/7.08M [00:05<00:00, 2.16MB/s]
# Uploading:  80%|███████▉  | 5.66M/7.08M [00:05<00:00, 1.90MB/s]
# Uploading:  85%|████████▌ | 6.05M/7.08M [00:05<00:00, 2.34MB/s]
# Uploading:  89%|████████▉ | 6.30M/7.08M [00:05<00:00, 1.98MB/s]
# Uploading:  93%|█████████▎| 6.59M/7.08M [00:05<00:00, 2.19MB/s]
# Uploading: 100%|██████████| 7.08M/7.08M [00:06<00:00, 1.07MB/s]
# 7it [01:00,  7.07s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:02, 4.04MB/s]
# Uploading:  22%|██▏       | 2.14M/9.62M [00:00<00:01, 4.58MB/s]
# Uploading:  27%|██▋       | 2.62M/9.62M [00:00<00:02, 3.09MB/s]
# Uploading:  31%|███       | 2.97M/9.62M [00:01<00:02, 2.49MB/s]
# Uploading:  35%|███▍      | 3.33M/9.62M [00:01<00:02, 2.69MB/s]
# Uploading:  38%|███▊      | 3.62M/9.62M [00:01<00:02, 2.39MB/s]
# Uploading:  41%|████      | 3.94M/9.62M [00:01<00:02, 2.50MB/s]
# Uploading:  44%|████▎     | 4.20M/9.62M [00:01<00:02, 2.28MB/s]
# Uploading:  46%|████▋     | 4.47M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  50%|█████     | 4.81M/9.62M [00:01<00:01, 2.65MB/s]
# Uploading:  53%|█████▎    | 5.09M/9.62M [00:01<00:02, 2.33MB/s]
# Uploading:  56%|█████▌    | 5.34M/9.62M [00:02<00:01, 2.39MB/s]
# Uploading:  58%|█████▊    | 5.59M/9.62M [00:02<00:01, 2.28MB/s]
# Uploading:  61%|██████    | 5.83M/9.62M [00:02<00:01, 2.30MB/s]
# Uploading:  63%|██████▎   | 6.08M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  66%|██████▌   | 6.31M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:02<00:01, 2.21MB/s]
# Uploading:  71%|███████▏  | 6.88M/9.62M [00:02<00:01, 2.44MB/s]
# Uploading:  74%|███████▍  | 7.12M/9.62M [00:02<00:01, 2.29MB/s]
# Uploading:  76%|███████▋  | 7.36M/9.62M [00:02<00:01, 2.27MB/s]
# Uploading:  80%|███████▉  | 7.69M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  83%|████████▎ | 7.94M/9.62M [00:03<00:00, 2.25MB/s]
# Uploading:  86%|████████▌ | 8.23M/9.62M [00:03<00:00, 2.46MB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:03<00:00, 2.31MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:03<00:00, 2.24MB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:03<00:00, 2.46MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:03<00:00, 2.27MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.09MB/s]
# 8it [01:05,  6.36s/it]
# Uploading:   0%|          | 0.00/7.26M [00:00<?, ?B/s]
# Uploading:  23%|██▎       | 1.58M/6.92M [00:00<00:01, 3.69MB/s]
# Uploading:  33%|███▎      | 2.30M/6.92M [00:00<00:01, 2.95MB/s]
# Uploading:  39%|███▉      | 2.69M/6.92M [00:00<00:01, 3.11MB/s]
# Uploading:  43%|████▎     | 3.00M/6.92M [00:01<00:01, 2.62MB/s]
# Uploading:  48%|████▊     | 3.33M/6.92M [00:01<00:01, 2.72MB/s]
# Uploading:  53%|█████▎    | 3.67M/6.92M [00:01<00:01, 2.47MB/s]
# Uploading:  58%|█████▊    | 3.98M/6.92M [00:01<00:01, 2.57MB/s]
# Uploading:  63%|██████▎   | 4.36M/6.92M [00:01<00:00, 2.82MB/s]
# Uploading:  67%|██████▋   | 4.66M/6.92M [00:01<00:01, 2.35MB/s]
# Uploading:  72%|███████▏  | 5.02M/6.92M [00:01<00:00, 2.64MB/s]
# Uploading:  77%|███████▋  | 5.30M/6.92M [00:02<00:00, 2.24MB/s]
# Uploading:  81%|████████▏ | 5.64M/6.92M [00:02<00:00, 2.54MB/s]
# Uploading:  86%|████████▌ | 5.92M/6.92M [00:02<00:00, 2.18MB/s]
# Uploading:  89%|████████▉ | 6.19M/6.92M [00:02<00:00, 2.29MB/s]
# Uploading:  94%|█████████▍| 6.52M/6.92M [00:02<00:00, 2.52MB/s]
# Uploading: 100%|██████████| 6.92M/6.92M [00:04<00:00, 1.60MB/s]
# 9it [01:09,  5.79s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  11%|█         | 1.08M/9.62M [00:00<00:02, 3.39MB/s]
# Uploading:  17%|█▋        | 1.66M/9.62M [00:00<00:02, 4.17MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:00<00:03, 2.52MB/s]
# Uploading:  25%|██▌       | 2.45M/9.62M [00:00<00:03, 2.25MB/s]
# Uploading:  29%|██▊       | 2.77M/9.62M [00:01<00:02, 2.41MB/s]
# Uploading:  32%|███▏      | 3.05M/9.62M [00:01<00:03, 2.09MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  39%|███▊      | 3.72M/9.62M [00:01<00:02, 2.11MB/s]
# Uploading:  42%|████▏     | 4.06M/9.62M [00:01<00:02, 2.39MB/s]
# Uploading:  45%|████▍     | 4.33M/9.62M [00:01<00:02, 2.03MB/s]
# Uploading:  48%|████▊     | 4.64M/9.62M [00:02<00:02, 2.29MB/s]
# Uploading:  51%|█████     | 4.89M/9.62M [00:02<00:02, 2.22MB/s]
# Uploading:  53%|█████▎    | 5.12M/9.62M [00:02<00:02, 2.17MB/s]
# Uploading:  57%|█████▋    | 5.48M/9.62M [00:02<00:01, 2.56MB/s]
# Uploading:  60%|█████▉    | 5.75M/9.62M [00:02<00:01, 2.14MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:02<00:01, 2.46MB/s]
# Uploading:  66%|██████▌   | 6.36M/9.62M [00:02<00:01, 2.20MB/s]
# Uploading:  69%|██████▊   | 6.59M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  72%|███████▏  | 6.97M/9.62M [00:03<00:01, 2.56MB/s]
# Uploading:  75%|███████▌  | 7.23M/9.62M [00:03<00:01, 1.99MB/s]
# Uploading:  81%|████████  | 7.75M/9.62M [00:03<00:00, 2.61MB/s]
# Uploading:  83%|████████▎ | 8.03M/9.62M [00:03<00:00, 2.15MB/s]
# Uploading:  86%|████████▌ | 8.30M/9.62M [00:03<00:00, 2.27MB/s]
# Uploading:  89%|████████▉ | 8.55M/9.62M [00:03<00:00, 2.05MB/s]
# Uploading:  92%|█████████▏| 8.83M/9.62M [00:03<00:00, 2.12MB/s]
# Uploading:  96%|█████████▌| 9.23M/9.62M [00:04<00:00, 2.19MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.96MB/s]
# 10it [01:15,  5.60s/it]
# Uploading:   0%|          | 0.00/8.22M [00:00<?, ?B/s]
# Uploading:  21%|██        | 1.62M/7.84M [00:00<00:01, 4.48MB/s]
# Uploading:  30%|██▉       | 2.33M/7.84M [00:00<00:01, 5.10MB/s]
# Uploading:  37%|███▋      | 2.88M/7.84M [00:00<00:01, 3.34MB/s]
# Uploading:  42%|████▏     | 3.27M/7.84M [00:01<00:01, 2.76MB/s]
# Uploading:  47%|████▋     | 3.69M/7.84M [00:01<00:01, 3.02MB/s]
# Uploading:  51%|█████▏    | 4.03M/7.84M [00:01<00:01, 2.55MB/s]
# Uploading:  55%|█████▌    | 4.33M/7.84M [00:01<00:01, 2.63MB/s]
# Uploading:  59%|█████▉    | 4.61M/7.84M [00:01<00:01, 2.43MB/s]
# Uploading:  63%|██████▎   | 4.92M/7.84M [00:01<00:01, 2.60MB/s]
# Uploading:  67%|██████▋   | 5.23M/7.84M [00:01<00:01, 2.73MB/s]
# Uploading:  70%|███████   | 5.52M/7.84M [00:01<00:01, 2.42MB/s]
# Uploading:  74%|███████▍  | 5.83M/7.84M [00:02<00:00, 2.61MB/s]
# Uploading:  78%|███████▊  | 6.09M/7.84M [00:02<00:00, 2.48MB/s]
# Uploading:  81%|████████  | 6.36M/7.84M [00:02<00:00, 2.46MB/s]
# Uploading:  85%|████████▌ | 6.67M/7.84M [00:02<00:00, 2.61MB/s]
# Uploading:  88%|████████▊ | 6.94M/7.84M [00:02<00:00, 2.43MB/s]
# Uploading:  92%|█████████▏| 7.22M/7.84M [00:02<00:00, 2.55MB/s]
# Uploading:  96%|█████████▌| 7.50M/7.84M [00:02<00:00, 2.59MB/s]
# Uploading: 100%|██████████| 7.84M/7.84M [00:04<00:00, 1.77MB/s]
# 11it [01:19,  5.30s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:   6%|▌         | 544k/9.62M [00:00<00:05, 1.61MB/s]
# Uploading:   8%|▊         | 800k/9.62M [00:00<00:07, 1.19MB/s]
# Uploading:  14%|█▍        | 1.34M/9.62M [00:00<00:05, 1.51MB/s]
# Uploading:  21%|██        | 2.00M/9.62M [00:01<00:03, 2.41MB/s]
# Uploading:  24%|██▍       | 2.34M/9.62M [00:01<00:03, 2.01MB/s]
# Uploading:  27%|██▋       | 2.61M/9.62M [00:01<00:04, 1.74MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:01<00:03, 1.98MB/s]
# Uploading:  33%|███▎      | 3.17M/9.62M [00:01<00:03, 1.81MB/s]
# Uploading:  36%|███▌      | 3.47M/9.62M [00:01<00:03, 2.05MB/s]
# Uploading:  39%|███▉      | 3.73M/9.62M [00:02<00:03, 1.94MB/s]
# Uploading:  41%|████      | 3.95M/9.62M [00:02<00:02, 2.01MB/s]
# Uploading:  44%|████▍     | 4.25M/9.62M [00:02<00:02, 2.26MB/s]
# Uploading:  47%|████▋     | 4.50M/9.62M [00:02<00:02, 2.05MB/s]
# Uploading:  50%|█████     | 4.81M/9.62M [00:02<00:02, 2.30MB/s]
# Uploading:  53%|█████▎    | 5.06M/9.62M [00:02<00:02, 2.14MB/s]
# Uploading:  55%|█████▌    | 5.30M/9.62M [00:02<00:02, 2.20MB/s]
# Uploading:  58%|█████▊    | 5.59M/9.62M [00:02<00:01, 2.41MB/s]
# Uploading:  61%|██████    | 5.84M/9.62M [00:03<00:01, 2.22MB/s]
# Uploading:  64%|██████▍   | 6.14M/9.62M [00:03<00:01, 2.40MB/s]
# Uploading:  66%|██████▋   | 6.39M/9.62M [00:03<00:01, 2.21MB/s]
# Uploading:  69%|██████▉   | 6.64M/9.62M [00:03<00:01, 2.27MB/s]
# Uploading:  72%|███████▏  | 6.97M/9.62M [00:03<00:01, 2.49MB/s]
# Uploading:  75%|███████▌  | 7.22M/9.62M [00:03<00:01, 2.37MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  81%|████████  | 7.78M/9.62M [00:03<00:00, 2.37MB/s]
# Uploading:  83%|████████▎ | 8.02M/9.62M [00:04<00:00, 2.32MB/s]
# Uploading:  86%|████████▋ | 8.31M/9.62M [00:04<00:00, 2.52MB/s]
# Uploading:  89%|████████▉ | 8.56M/9.62M [00:04<00:00, 2.42MB/s]
# Uploading:  92%|█████████▏| 8.81M/9.62M [00:04<00:00, 2.39MB/s]
# Uploading:  95%|█████████▍| 9.11M/9.62M [00:04<00:00, 2.50MB/s]
# Uploading:  97%|█████████▋| 9.36M/9.62M [00:04<00:00, 2.51MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.83MB/s]
# 12it [01:25,  5.37s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▋        | 1.58M/9.62M [00:00<00:01, 5.38MB/s]
# Uploading:  22%|██▏       | 2.09M/9.62M [00:00<00:01, 5.32MB/s]
# Uploading:  27%|██▋       | 2.61M/9.62M [00:00<00:02, 3.29MB/s]
# Uploading:  32%|███▏      | 3.03M/9.62M [00:00<00:02, 3.07MB/s]
# Uploading:  35%|███▍      | 3.34M/9.62M [00:01<00:02, 2.96MB/s]
# Uploading:  38%|███▊      | 3.69M/9.62M [00:01<00:02, 3.06MB/s]
# Uploading:  42%|████▏     | 4.00M/9.62M [00:01<00:02, 2.69MB/s]
# Uploading:  45%|████▍     | 4.30M/9.62M [00:01<00:02, 2.77MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:01<00:02, 2.56MB/s]
# Uploading:  50%|█████     | 4.84M/9.62M [00:01<00:01, 2.57MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:01<00:01, 2.76MB/s]
# Uploading:  57%|█████▋    | 5.47M/9.62M [00:01<00:01, 2.48MB/s]
# Uploading:  60%|█████▉    | 5.75M/9.62M [00:01<00:01, 2.59MB/s]
# Uploading:  63%|██████▎   | 6.02M/9.62M [00:02<00:01, 2.50MB/s]
# Uploading:  65%|██████▌   | 6.28M/9.62M [00:02<00:01, 2.52MB/s]
# Uploading:  68%|██████▊   | 6.58M/9.62M [00:02<00:01, 2.60MB/s]
# Uploading:  71%|███████   | 6.84M/9.62M [00:02<00:01, 2.62MB/s]
# Uploading:  74%|███████▍  | 7.11M/9.62M [00:03<00:04, 536kB/s]
# Uploading:  80%|███████▉  | 7.67M/9.62M [00:04<00:02, 770kB/s]
# Uploading:  86%|████████▌ | 8.28M/9.62M [00:04<00:01, 1.05MB/s]
# Uploading:  93%|█████████▎| 8.92M/9.62M [00:04<00:00, 1.53MB/s]
# Uploading:  96%|█████████▌| 9.22M/9.62M [00:05<00:00, 1.47MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.66MB/s]
# 13it [01:31,  5.58s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.34M/9.62M [00:00<00:02, 4.10MB/s]
# Uploading:  18%|█▊        | 1.75M/9.62M [00:00<00:02, 3.85MB/s]
# Uploading:  22%|██▏       | 2.11M/9.62M [00:00<00:02, 3.04MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:00<00:02, 3.01MB/s]
# Uploading:  28%|██▊       | 2.70M/9.62M [00:00<00:02, 2.60MB/s]
# Uploading:  32%|███▏      | 3.03M/9.62M [00:01<00:02, 2.74MB/s]
# Uploading:  34%|███▍      | 3.31M/9.62M [00:01<00:02, 2.78MB/s]
# Uploading:  37%|███▋      | 3.58M/9.62M [00:01<00:02, 2.47MB/s]
# Uploading:  40%|███▉      | 3.83M/9.62M [00:01<00:02, 2.49MB/s]
# Uploading:  42%|████▏     | 4.08M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  45%|████▍     | 4.33M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  48%|████▊     | 4.62M/9.62M [00:01<00:02, 2.57MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:01<00:02, 2.43MB/s]
# Uploading:  54%|█████▎    | 5.16M/9.62M [00:01<00:01, 2.43MB/s]
# Uploading:  57%|█████▋    | 5.52M/9.62M [00:02<00:01, 2.61MB/s]
# Uploading:  60%|█████▉    | 5.77M/9.62M [00:02<00:01, 2.44MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:02<00:01, 2.59MB/s]
# Uploading:  66%|██████▋   | 6.38M/9.62M [00:02<00:01, 2.61MB/s]
# Uploading:  69%|██████▉   | 6.62M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  72%|███████▏  | 6.94M/9.62M [00:02<00:01, 2.58MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:02<00:01, 2.41MB/s]
# Uploading:  78%|███████▊  | 7.48M/9.62M [00:02<00:00, 2.53MB/s]
# Uploading:  81%|████████  | 7.75M/9.62M [00:03<00:00, 2.59MB/s]
# Uploading:  83%|████████▎ | 8.02M/9.62M [00:03<00:00, 2.50MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:03<00:00, 2.51MB/s]
# Uploading:  89%|████████▊ | 8.53M/9.62M [00:03<00:00, 2.57MB/s]
# Uploading:  91%|█████████▏| 8.78M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  95%|█████████▍| 9.12M/9.62M [00:03<00:00, 2.67MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.78MB/s]
# 14it [01:36,  5.61s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  11%|█         | 1.08M/9.62M [00:00<00:02, 3.40MB/s]
# Uploading:  17%|█▋        | 1.61M/9.62M [00:00<00:02, 3.97MB/s]
# Uploading:  21%|██▏       | 2.05M/9.62M [00:00<00:03, 2.64MB/s]
# Uploading:  25%|██▍       | 2.36M/9.62M [00:00<00:03, 2.25MB/s]
# Uploading:  28%|██▊       | 2.69M/9.62M [00:01<00:03, 2.42MB/s]
# Uploading:  31%|███       | 2.95M/9.62M [00:01<00:03, 2.12MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:01<00:02, 2.28MB/s]
# Uploading:  36%|███▋      | 3.50M/9.62M [00:01<00:03, 2.01MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:01<00:02, 2.09MB/s]
# Uploading:  42%|████▏     | 4.05M/9.62M [00:01<00:02, 2.11MB/s]
# Uploading:  44%|████▍     | 4.27M/9.62M [00:01<00:02, 2.07MB/s]
# Uploading:  48%|████▊     | 4.62M/9.62M [00:02<00:02, 2.41MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:02<00:02, 2.02MB/s]
# Uploading:  55%|█████▍    | 5.25M/9.62M [00:02<00:01, 2.44MB/s]
# Uploading:  57%|█████▋    | 5.52M/9.62M [00:02<00:02, 2.09MB/s]
# Uploading:  60%|██████    | 5.78M/9.62M [00:02<00:01, 2.21MB/s]
# Uploading:  63%|██████▎   | 6.02M/9.62M [00:02<00:01, 2.07MB/s]
# Uploading:  65%|██████▍   | 6.23M/9.62M [00:02<00:01, 2.07MB/s]
# Uploading:  68%|██████▊   | 6.52M/9.62M [00:02<00:01, 2.16MB/s]
# Uploading:  70%|███████   | 6.73M/9.62M [00:03<00:01, 2.12MB/s]
# Uploading:  73%|███████▎  | 6.98M/9.62M [00:03<00:01, 2.20MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:01, 2.15MB/s]
# Uploading:  77%|███████▋  | 7.42M/9.62M [00:03<00:01, 2.11MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:03<00:00, 2.22MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:03<00:00, 2.16MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:03<00:00, 2.11MB/s]
# Uploading:  87%|████████▋ | 8.38M/9.62M [00:03<00:00, 2.14MB/s]
# Uploading:  89%|████████▉ | 8.59M/9.62M [00:03<00:00, 2.07MB/s]
# Uploading:  92%|█████████▏| 8.84M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading:  94%|█████████▍| 9.08M/9.62M [00:04<00:00, 2.25MB/s]
# Uploading:  97%|█████████▋| 9.30M/9.62M [00:04<00:00, 2.15MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.92MB/s]
# 15it [01:42,  5.50s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▍        | 1.41M/9.62M [00:00<00:01, 4.44MB/s]
# Uploading:  20%|██        | 1.94M/9.62M [00:00<00:01, 4.71MB/s]
# Uploading:  25%|██▌       | 2.42M/9.62M [00:00<00:02, 2.77MB/s]
# Uploading:  29%|██▊       | 2.75M/9.62M [00:00<00:02, 2.46MB/s]
# Uploading:  32%|███▏      | 3.05M/9.62M [00:01<00:02, 2.51MB/s]
# Uploading:  34%|███▍      | 3.31M/9.62M [00:01<00:02, 2.27MB/s]
# Uploading:  38%|███▊      | 3.61M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  40%|████      | 3.86M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  43%|████▎     | 4.11M/9.62M [00:01<00:02, 2.11MB/s]
# Uploading:  46%|████▌     | 4.42M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  49%|████▊     | 4.67M/9.62M [00:01<00:02, 2.13MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:02<00:02, 2.28MB/s]
# Uploading:  54%|█████▍    | 5.20M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:02<00:02, 2.11MB/s]
# Uploading:  60%|█████▉    | 5.73M/9.62M [00:02<00:01, 2.33MB/s]
# Uploading:  62%|██████▏   | 5.97M/9.62M [00:02<00:01, 2.03MB/s]
# Uploading:  65%|██████▌   | 6.30M/9.62M [00:02<00:01, 2.31MB/s]
# Uploading:  68%|██████▊   | 6.53M/9.62M [00:02<00:01, 2.06MB/s]
# Uploading:  71%|███████   | 6.80M/9.62M [00:02<00:01, 2.22MB/s]
# Uploading:  73%|███████▎  | 7.06M/9.62M [00:03<00:01, 2.33MB/s]
# Uploading:  76%|███████▌  | 7.30M/9.62M [00:03<00:01, 2.11MB/s]
# Uploading:  79%|███████▉  | 7.61M/9.62M [00:03<00:00, 2.30MB/s]
# Uploading:  82%|████████▏ | 7.84M/9.62M [00:03<00:00, 2.10MB/s]
# Uploading:  84%|████████▍ | 8.12M/9.62M [00:03<00:00, 2.29MB/s]
# Uploading:  87%|████████▋ | 8.38M/9.62M [00:03<00:00, 2.37MB/s]
# Uploading:  89%|████████▉ | 8.61M/9.62M [00:03<00:00, 2.18MB/s]
# Uploading:  92%|█████████▏| 8.83M/9.62M [00:03<00:00, 2.09MB/s]
# Uploading:  95%|█████████▍| 9.09M/9.62M [00:03<00:00, 2.24MB/s]
# Uploading:  97%|█████████▋| 9.31M/9.62M [00:04<00:00, 2.16MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.02MB/s]
# 16it [01:47,  5.35s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.50M/9.62M [00:00<00:01, 5.39MB/s]
# Uploading:  21%|██        | 2.02M/9.62M [00:00<00:01, 5.34MB/s]
# Uploading:  26%|██▋       | 2.53M/9.62M [00:00<00:02, 3.11MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:00<00:02, 3.09MB/s]
# Uploading:  34%|███▍      | 3.25M/9.62M [00:01<00:02, 2.75MB/s]
# Uploading:  38%|███▊      | 3.66M/9.62M [00:01<00:02, 2.96MB/s]
# Uploading:  41%|████▏     | 3.97M/9.62M [00:01<00:02, 2.62MB/s]
# Uploading:  45%|████▍     | 4.28M/9.62M [00:01<00:02, 2.66MB/s]
# Uploading:  47%|████▋     | 4.55M/9.62M [00:01<00:02, 2.61MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:01<00:01, 2.72MB/s]
# Uploading:  54%|█████▍    | 5.17M/9.62M [00:01<00:01, 2.80MB/s]
# Uploading:  57%|█████▋    | 5.45M/9.62M [00:03<00:07, 585kB/s]
# Uploading:  62%|██████▏   | 5.98M/9.62M [00:03<00:04, 881kB/s]
# Uploading:  66%|██████▌   | 6.36M/9.62M [00:03<00:02, 1.15MB/s]
# Uploading:  70%|██████▉   | 6.69M/9.62M [00:03<00:02, 1.27MB/s]
# Uploading:  73%|███████▎  | 6.98M/9.62M [00:03<00:01, 1.49MB/s]
# Uploading:  76%|███████▌  | 7.28M/9.62M [00:04<00:01, 1.55MB/s]
# Uploading:  79%|███████▊  | 7.56M/9.62M [00:04<00:01, 1.77MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:04<00:00, 1.85MB/s]
# Uploading:  85%|████████▌ | 8.22M/9.62M [00:04<00:00, 2.02MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:04<00:00, 2.13MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:04<00:00, 2.01MB/s]
# Uploading:  94%|█████████▍| 9.03M/9.62M [00:04<00:00, 2.27MB/s]
# Uploading:  96%|█████████▋| 9.28M/9.62M [00:05<00:00, 2.13MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.71MB/s]
# 17it [01:53,  5.52s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.53M/9.62M [00:00<00:01, 5.23MB/s]
# Uploading:  21%|██        | 2.03M/9.62M [00:00<00:01, 4.61MB/s]
# Uploading:  25%|██▌       | 2.45M/9.62M [00:00<00:02, 3.39MB/s]
# Uploading:  29%|██▊       | 2.77M/9.62M [00:00<00:02, 3.28MB/s]
# Uploading:  32%|███▏      | 3.08M/9.62M [00:00<00:02, 2.86MB/s]
# Uploading:  35%|███▍      | 3.36M/9.62M [00:01<00:02, 2.85MB/s]
# Uploading:  38%|███▊      | 3.62M/9.62M [00:01<00:02, 2.83MB/s]
# Uploading:  40%|████      | 3.89M/9.62M [00:01<00:02, 2.66MB/s]
# Uploading:  43%|████▎     | 4.16M/9.62M [00:01<00:02, 2.67MB/s]
# Uploading:  46%|████▌     | 4.42M/9.62M [00:01<00:02, 2.56MB/s]
# Uploading:  49%|████▊     | 4.69M/9.62M [00:01<00:02, 2.52MB/s]
# Uploading:  52%|█████▏    | 5.05M/9.62M [00:01<00:01, 2.82MB/s]
# Uploading:  55%|█████▌    | 5.33M/9.62M [00:01<00:01, 2.62MB/s]
# Uploading:  58%|█████▊    | 5.59M/9.62M [00:01<00:01, 2.59MB/s]
# Uploading:  62%|██████▏   | 5.94M/9.62M [00:02<00:01, 2.86MB/s]
# Uploading:  65%|██████▍   | 6.22M/9.62M [00:02<00:01, 2.54MB/s]
# Uploading:  68%|██████▊   | 6.52M/9.62M [00:02<00:01, 2.65MB/s]
# Uploading:  71%|███████   | 6.80M/9.62M [00:02<00:01, 2.72MB/s]
# Uploading:  73%|███████▎  | 7.06M/9.62M [00:02<00:01, 2.63MB/s]
# Uploading:  76%|███████▋  | 7.34M/9.62M [00:02<00:00, 2.66MB/s]
# Uploading:  79%|███████▉  | 7.62M/9.62M [00:02<00:00, 2.73MB/s]
# Uploading:  82%|████████▏ | 7.89M/9.62M [00:02<00:00, 2.53MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:04<00:02, 532kB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:04<00:00, 1.09MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:04<00:00, 1.19MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.76MB/s]
# 18it [01:58,  5.59s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▎        | 1.31M/9.62M [00:00<00:02, 4.33MB/s]
# Uploading:  19%|█▊        | 1.78M/9.62M [00:00<00:01, 4.44MB/s]
# Uploading:  23%|██▎       | 2.22M/9.62M [00:00<00:02, 2.99MB/s]
# Uploading:  27%|██▋       | 2.56M/9.62M [00:00<00:03, 2.46MB/s]
# Uploading:  30%|███       | 2.89M/9.62M [00:01<00:02, 2.65MB/s]
# Uploading:  33%|███▎      | 3.19M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:01<00:02, 2.45MB/s]
# Uploading:  40%|███▉      | 3.81M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  42%|████▏     | 4.05M/9.62M [00:01<00:02, 2.26MB/s]
# Uploading:  46%|████▌     | 4.39M/9.62M [00:01<00:02, 2.54MB/s]
# Uploading:  48%|████▊     | 4.66M/9.62M [00:01<00:02, 2.17MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:01<00:02, 2.37MB/s]
# Uploading:  54%|█████▍    | 5.22M/9.62M [00:02<00:02, 2.13MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  60%|██████    | 5.78M/9.62M [00:02<00:01, 2.28MB/s]
# Uploading:  63%|██████▎   | 6.02M/9.62M [00:02<00:01, 2.09MB/s]
# Uploading:  66%|██████▋   | 6.39M/9.62M [00:02<00:01, 2.46MB/s]
# Uploading:  69%|██████▉   | 6.64M/9.62M [00:02<00:01, 2.08MB/s]
# Uploading:  73%|███████▎  | 7.05M/9.62M [00:02<00:01, 2.42MB/s]
# Uploading:  76%|███████▌  | 7.30M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  80%|████████  | 7.72M/9.62M [00:03<00:00, 2.52MB/s]
# Uploading:  83%|████████▎ | 7.98M/9.62M [00:03<00:00, 2.13MB/s]
# Uploading:  86%|████████▌ | 8.23M/9.62M [00:03<00:00, 2.19MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:03<00:00, 1.98MB/s]
# Uploading:  90%|█████████ | 8.67M/9.62M [00:03<00:00, 1.88MB/s]
# Uploading:  93%|█████████▎| 8.92M/9.62M [00:04<00:00, 875kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:06<00:00, 1.48MB/s][A
# 19it [02:05,  5.96s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  12%|█▏        | 1.12M/9.62M [00:00<00:02, 3.56MB/s]
# Uploading:  15%|█▌        | 1.47M/9.62M [00:00<00:02, 3.36MB/s]
# Uploading:  19%|█▊        | 1.78M/9.62M [00:00<00:03, 2.55MB/s]
# Uploading:  21%|██        | 2.03M/9.62M [00:00<00:03, 2.53MB/s]
# Uploading:  24%|██▎       | 2.28M/9.62M [00:00<00:03, 2.31MB/s]
# Uploading:  26%|██▌       | 2.50M/9.62M [00:01<00:03, 2.23MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:01<00:03, 2.27MB/s]
# Uploading:  31%|███       | 2.95M/9.62M [00:01<00:03, 2.11MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:01<00:03, 2.11MB/s]
# Uploading:  36%|███▌      | 3.42M/9.62M [00:01<00:02, 2.21MB/s]
# Uploading:  38%|███▊      | 3.64M/9.62M [00:01<00:03, 1.96MB/s]
# Uploading:  41%|████      | 3.91M/9.62M [00:01<00:02, 2.14MB/s]
# Uploading:  43%|████▎     | 4.12M/9.62M [00:01<00:02, 2.14MB/s]
# Uploading:  45%|████▌     | 4.36M/9.62M [00:01<00:02, 2.13MB/s]
# Uploading:  48%|████▊     | 4.62M/9.62M [00:02<00:02, 2.29MB/s]
# Uploading:  51%|█████     | 4.86M/9.62M [00:02<00:02, 1.97MB/s]
# Uploading:  54%|█████▍    | 5.19M/9.62M [00:02<00:02, 2.27MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:02<00:01, 2.28MB/s]
# Uploading:  59%|█████▉    | 5.66M/9.62M [00:02<00:01, 2.26MB/s]
# Uploading:  62%|██████▏   | 5.92M/9.62M [00:02<00:01, 2.31MB/s]
# Uploading:  64%|██████▍   | 6.16M/9.62M [00:02<00:01, 2.12MB/s]
# Uploading:  67%|██████▋   | 6.41M/9.62M [00:02<00:01, 2.24MB/s]
# Uploading:  70%|██████▉   | 6.69M/9.62M [00:03<00:01, 2.33MB/s]
# Uploading:  72%|███████▏  | 6.92M/9.62M [00:03<00:01, 2.15MB/s]
# Uploading:  74%|███████▍  | 7.16M/9.62M [00:03<00:01, 2.22MB/s]
# Uploading:  77%|███████▋  | 7.42M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  80%|███████▉  | 7.66M/9.62M [00:03<00:00, 2.25MB/s]
# Uploading:  82%|████████▏ | 7.91M/9.62M [00:03<00:00, 2.35MB/s]
# Uploading:  85%|████████▍ | 8.14M/9.62M [00:03<00:00, 2.23MB/s]
# Uploading:  87%|████████▋ | 8.38M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  89%|████████▉ | 8.61M/9.62M [00:03<00:00, 2.33MB/s]
# Uploading:  92%|█████████▏| 8.84M/9.62M [00:04<00:00, 2.22MB/s]
# Uploading:  94%|█████████▍| 9.06M/9.62M [00:04<00:00, 2.21MB/s]
# Uploading:  97%|█████████▋| 9.34M/9.62M [00:04<00:00, 2.37MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.95MB/s]
# 20it [02:10,  5.72s/it]
# Uploading:   0%|          | 0.00/7.73M [00:00<?, ?B/s]
# Uploading:  20%|█▉        | 1.44M/7.37M [00:00<00:02, 2.99MB/s]
# Uploading:  29%|██▉       | 2.12M/7.37M [00:00<00:02, 2.37MB/s]
# Uploading:  34%|███▍      | 2.50M/7.37M [00:01<00:01, 2.59MB/s]
# Uploading:  38%|███▊      | 2.80M/7.37M [00:01<00:02, 2.23MB/s]
# Uploading:  42%|████▏     | 3.12M/7.37M [00:01<00:01, 2.37MB/s]
# Uploading:  47%|████▋     | 3.44M/7.37M [00:01<00:01, 2.09MB/s]
# Uploading:  52%|█████▏    | 3.81M/7.37M [00:01<00:01, 2.39MB/s]
# Uploading:  56%|█████▌    | 4.09M/7.37M [00:01<00:01, 2.11MB/s]
# Uploading:  59%|█████▉    | 4.36M/7.37M [00:01<00:01, 2.16MB/s]
# Uploading:  64%|██████▍   | 4.73M/7.37M [00:02<00:01, 2.25MB/s]
# Uploading:  67%|██████▋   | 4.97M/7.37M [00:02<00:01, 2.19MB/s]
# Uploading:  72%|███████▏  | 5.33M/7.37M [00:02<00:00, 2.53MB/s]
# Uploading:  76%|███████▌  | 5.59M/7.37M [00:02<00:00, 2.14MB/s]
# Uploading:  81%|████████  | 5.94M/7.37M [00:02<00:00, 2.44MB/s]
# Uploading:  84%|████████▍ | 6.20M/7.37M [00:02<00:00, 2.25MB/s]
# Uploading:  87%|████████▋ | 6.44M/7.37M [00:02<00:00, 2.26MB/s]
# Uploading:  91%|█████████ | 6.70M/7.37M [00:03<00:00, 2.29MB/s]
# Uploading:  94%|█████████▍| 6.94M/7.37M [00:03<00:00, 2.12MB/s]
# Uploading: 100%|██████████| 7.37M/7.37M [00:04<00:00, 1.88MB/s]
# 21it [02:14,  5.24s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.52M/9.62M [00:00<00:01, 5.24MB/s]
# Uploading:  21%|██        | 2.03M/9.62M [00:00<00:01, 4.96MB/s]
# Uploading:  26%|██▌       | 2.50M/9.62M [00:00<00:02, 3.28MB/s]
# Uploading:  30%|██▉       | 2.84M/9.62M [00:00<00:02, 2.94MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:00<00:02, 2.81MB/s]
# Uploading:  37%|███▋      | 3.53M/9.62M [00:01<00:02, 3.06MB/s]
# Uploading:  40%|███▉      | 3.83M/9.62M [00:01<00:02, 2.33MB/s]
# Uploading:  44%|████▍     | 4.23M/9.62M [00:01<00:02, 2.49MB/s]
# Uploading:  47%|████▋     | 4.50M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  51%|█████     | 4.88M/9.62M [00:01<00:01, 2.70MB/s]
# Uploading:  54%|█████▎    | 5.16M/9.62M [00:01<00:01, 2.41MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:01<00:01, 2.44MB/s]
# Uploading:  59%|█████▉    | 5.72M/9.62M [00:02<00:01, 2.57MB/s]
# Uploading:  62%|██████▏   | 5.98M/9.62M [00:02<00:01, 2.42MB/s]
# Uploading:  65%|██████▌   | 6.27M/9.62M [00:02<00:01, 2.55MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:02<00:01, 2.60MB/s]
# Uploading:  71%|███████   | 6.81M/9.62M [00:02<00:01, 2.61MB/s]
# Uploading:  74%|███████▎  | 7.08M/9.62M [00:02<00:01, 2.46MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:02<00:00, 2.76MB/s]
# Uploading:  80%|████████  | 7.73M/9.62M [00:04<00:03, 568kB/s]
# Uploading:  90%|█████████ | 8.69M/9.62M [00:04<00:00, 1.11MB/s]
# Uploading:  94%|█████████▍| 9.03M/9.62M [00:04<00:00, 1.32MB/s]
# Uploading:  97%|█████████▋| 9.31M/9.62M [00:04<00:00, 1.35MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.74MB/s]
# 22it [02:20,  5.41s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.38M/9.62M [00:00<00:01, 4.57MB/s]
# Uploading:  19%|█▉        | 1.83M/9.62M [00:00<00:01, 4.56MB/s]
# Uploading:  24%|██▎       | 2.27M/9.62M [00:00<00:02, 3.13MB/s]
# Uploading:  28%|██▊       | 2.67M/9.62M [00:00<00:02, 3.39MB/s]
# Uploading:  32%|███▏      | 3.03M/9.62M [00:00<00:02, 2.69MB/s]
# Uploading:  36%|███▌      | 3.42M/9.62M [00:01<00:02, 2.96MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  43%|████▎     | 4.17M/9.62M [00:01<00:02, 2.63MB/s]
# Uploading:  46%|████▋     | 4.45M/9.62M [00:01<00:02, 2.34MB/s]
# Uploading:  51%|█████     | 4.89M/9.62M [00:01<00:01, 2.72MB/s]
# Uploading:  54%|█████▍    | 5.17M/9.62M [00:01<00:01, 2.35MB/s]
# Uploading:  58%|█████▊    | 5.62M/9.62M [00:02<00:01, 2.84MB/s]
# Uploading:  62%|██████▏   | 5.94M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  66%|██████▌   | 6.31M/9.62M [00:02<00:01, 2.69MB/s]
# Uploading:  69%|██████▊   | 6.61M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  72%|███████▏  | 6.92M/9.62M [00:02<00:01, 2.53MB/s]
# Uploading:  75%|███████▌  | 7.25M/9.62M [00:02<00:00, 2.68MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:02<00:00, 2.49MB/s]
# Uploading:  81%|████████  | 7.81M/9.62M [00:02<00:00, 2.58MB/s]
# Uploading:  84%|████████▍ | 8.09M/9.62M [00:03<00:00, 2.64MB/s]
# Uploading:  87%|████████▋ | 8.36M/9.62M [00:03<00:00, 2.67MB/s]
# Uploading:  90%|████████▉ | 8.62M/9.62M [00:03<00:00, 2.60MB/s]
# Uploading:  92%|█████████▏| 8.89M/9.62M [00:03<00:00, 2.65MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.74MB/s]
# 23it [02:26,  5.52s/it]
# Uploading:   0%|          | 0.00/25.7M [00:00<?, ?B/s]
# Uploading:   4%|▍         | 1.09M/24.5M [00:00<00:07, 3.45MB/s]
# Uploading:   6%|▌         | 1.53M/24.5M [00:00<00:06, 3.70MB/s]
# Uploading:   8%|▊         | 1.91M/24.5M [00:00<00:09, 2.58MB/s]
# Uploading:  10%|▉         | 2.38M/24.5M [00:00<00:09, 2.47MB/s]
# Uploading:  11%|█         | 2.62M/24.5M [00:01<00:09, 2.43MB/s]
# Uploading:  12%|█▏        | 2.97M/24.5M [00:01<00:10, 2.22MB/s]
# Uploading:  13%|█▎        | 3.19M/24.5M [00:01<00:10, 2.22MB/s]
# Uploading:  15%|█▍        | 3.56M/24.5M [00:01<00:09, 2.21MB/s]
# Uploading:  15%|█▌        | 3.78M/24.5M [00:01<00:10, 2.12MB/s]
# Uploading:  17%|█▋        | 4.16M/24.5M [00:01<00:08, 2.49MB/s]
# Uploading:  18%|█▊        | 4.41M/24.5M [00:01<00:10, 2.02MB/s]
# Uploading:  20%|█▉        | 4.81M/24.5M [00:02<00:09, 2.27MB/s]
# Uploading:  21%|██        | 5.05M/24.5M [00:02<00:09, 2.04MB/s]
# Uploading:  22%|██▏       | 5.42M/24.5M [00:02<00:08, 2.39MB/s]
# Uploading:  23%|██▎       | 5.67M/24.5M [00:02<00:09, 2.03MB/s]
# Uploading:  25%|██▍       | 6.08M/24.5M [00:02<00:07, 2.43MB/s]
# Uploading:  26%|██▌       | 6.34M/24.5M [00:02<00:09, 2.10MB/s]
# Uploading:  27%|██▋       | 6.66M/24.5M [00:02<00:08, 2.32MB/s]
# Uploading:  28%|██▊       | 6.91M/24.5M [00:03<00:08, 2.08MB/s]
# Uploading:  29%|██▉       | 7.12M/24.5M [00:03<00:08, 2.10MB/s]
# Uploading:  30%|███       | 7.42M/24.5M [00:03<00:08, 2.23MB/s]
# Uploading:  31%|███       | 7.66M/24.5M [00:03<00:08, 2.19MB/s]
# Uploading:  32%|███▏      | 7.88M/24.5M [00:03<00:07, 2.20MB/s]
# Uploading:  33%|███▎      | 8.09M/24.5M [00:03<00:07, 2.20MB/s]
# Uploading:  34%|███▍      | 8.34M/24.5M [00:03<00:07, 2.22MB/s]
# Uploading:  35%|███▌      | 8.61M/24.5M [00:03<00:07, 2.36MB/s]
# Uploading:  36%|███▌      | 8.84M/24.5M [00:04<00:07, 2.25MB/s]
# Uploading:  37%|███▋      | 9.06M/24.5M [00:04<00:07, 2.14MB/s]
# Uploading:  38%|███▊      | 9.34M/24.5M [00:04<00:06, 2.33MB/s]
# Uploading:  39%|███▉      | 9.58M/24.5M [00:04<00:06, 2.29MB/s]
# Uploading:  40%|████      | 9.81M/24.5M [00:04<00:06, 2.27MB/s]
# Uploading:  41%|████      | 10.0M/24.5M [00:04<00:06, 2.29MB/s]
# Uploading:  42%|████▏     | 10.3M/24.5M [00:04<00:06, 2.20MB/s]
# Uploading:  43%|████▎     | 10.6M/24.5M [00:04<00:06, 2.33MB/s]
# Uploading:  44%|████▍     | 10.8M/24.5M [00:04<00:06, 2.24MB/s]
# Uploading:  45%|████▍     | 11.0M/24.5M [00:05<00:06, 2.19MB/s]
# Uploading:  46%|████▌     | 11.3M/24.5M [00:05<00:05, 2.32MB/s]
# Uploading:  47%|████▋     | 11.5M/24.5M [00:05<00:05, 2.31MB/s]
# Uploading:  48%|████▊     | 11.8M/24.5M [00:05<00:06, 2.19MB/s]
# Uploading:  49%|████▉     | 12.0M/24.5M [00:05<00:05, 2.30MB/s]
# Uploading:  50%|████▉     | 12.2M/24.5M [00:05<00:05, 2.21MB/s]
# Uploading:  51%|█████     | 12.5M/24.5M [00:05<00:05, 2.27MB/s]
# Uploading:  52%|█████▏    | 12.8M/24.5M [00:05<00:05, 2.33MB/s]
# Uploading:  53%|█████▎    | 13.0M/24.5M [00:05<00:05, 2.24MB/s]
# Uploading:  54%|█████▍    | 13.2M/24.5M [00:06<00:05, 2.25MB/s]
# Uploading:  55%|█████▍    | 13.4M/24.5M [00:06<00:05, 2.30MB/s]
# Uploading:  56%|█████▌    | 13.7M/24.5M [00:06<00:05, 2.17MB/s]
# Uploading:  57%|█████▋    | 13.9M/24.5M [00:06<00:05, 2.09MB/s]
# Uploading:  58%|█████▊    | 14.2M/24.5M [00:06<00:04, 2.27MB/s]
# Uploading:  59%|█████▊    | 14.4M/24.5M [00:07<00:21, 495kB/s]
# Uploading:  62%|██████▏   | 15.2M/24.5M [00:08<00:09, 1.01MB/s]
# Uploading:  63%|██████▎   | 15.4M/24.5M [00:08<00:08, 1.09MB/s]
# Uploading:  64%|██████▍   | 15.6M/24.5M [00:08<00:07, 1.22MB/s]
# Uploading:  65%|██████▍   | 15.8M/24.5M [00:08<00:07, 1.25MB/s]
# Uploading:  66%|██████▌   | 16.1M/24.5M [00:08<00:06, 1.44MB/s]
# Uploading:  67%|██████▋   | 16.3M/24.5M [00:08<00:05, 1.47MB/s]
# Uploading:  68%|██████▊   | 16.6M/24.5M [00:08<00:04, 1.79MB/s]
# Uploading:  69%|██████▉   | 16.9M/24.5M [00:09<00:05, 1.57MB/s]
# Uploading:  70%|███████   | 17.2M/24.5M [00:09<00:04, 1.82MB/s]
# Uploading:  71%|███████   | 17.4M/24.5M [00:09<00:04, 1.76MB/s]
# Uploading:  72%|███████▏  | 17.7M/24.5M [00:09<00:03, 2.03MB/s]
# Uploading:  73%|███████▎  | 18.0M/24.5M [00:09<00:03, 1.88MB/s]
# Uploading:  74%|███████▍  | 18.2M/24.5M [00:09<00:03, 1.95MB/s]
# Uploading:  75%|███████▌  | 18.4M/24.5M [00:09<00:03, 2.03MB/s]
# Uploading:  76%|███████▌  | 18.6M/24.5M [00:10<00:03, 1.96MB/s]
# Uploading:  77%|███████▋  | 18.9M/24.5M [00:10<00:02, 2.17MB/s]
# Uploading:  78%|███████▊  | 19.1M/24.5M [00:10<00:02, 1.99MB/s]
# Uploading:  79%|███████▉  | 19.3M/24.5M [00:10<00:02, 1.98MB/s]
# Uploading:  80%|████████  | 19.6M/24.5M [00:10<00:02, 2.07MB/s]
# Uploading:  81%|████████  | 19.8M/24.5M [00:10<00:02, 2.08MB/s]
# Uploading:  82%|████████▏ | 20.0M/24.5M [00:10<00:02, 2.16MB/s]
# Uploading:  83%|████████▎ | 20.3M/24.5M [00:10<00:02, 2.17MB/s]
# Uploading:  84%|████████▎ | 20.5M/24.5M [00:10<00:01, 2.13MB/s]
# Uploading:  85%|████████▍ | 20.8M/24.5M [00:11<00:01, 2.23MB/s]
# Uploading:  86%|████████▌ | 21.0M/24.5M [00:11<00:01, 2.21MB/s]
# Uploading:  86%|████████▋ | 21.2M/24.5M [00:11<00:01, 2.13MB/s]
# Uploading:  88%|████████▊ | 21.5M/24.5M [00:11<00:01, 2.25MB/s]
# Uploading:  89%|████████▊ | 21.7M/24.5M [00:11<00:01, 2.09MB/s]
# Uploading:  89%|████████▉ | 21.9M/24.5M [00:11<00:01, 2.14MB/s]
# Uploading:  90%|█████████ | 22.2M/24.5M [00:11<00:01, 2.18MB/s]
# Uploading:  91%|█████████▏| 22.4M/24.5M [00:11<00:01, 2.12MB/s]
# Uploading:  92%|█████████▏| 22.6M/24.5M [00:11<00:00, 2.24MB/s]
# Uploading:  93%|█████████▎| 22.9M/24.5M [00:12<00:00, 2.25MB/s]
# Uploading:  94%|█████████▍| 23.1M/24.5M [00:12<00:00, 2.19MB/s]
# Uploading:  95%|█████████▌| 23.3M/24.5M [00:12<00:00, 2.32MB/s]
# Uploading:  96%|█████████▌| 23.6M/24.5M [00:12<00:00, 2.28MB/s]
# Uploading:  97%|█████████▋| 23.8M/24.5M [00:12<00:00, 2.23MB/s]
# Uploading:  98%|█████████▊| 24.1M/24.5M [00:12<00:00, 2.26MB/s]
# Uploading: 100%|██████████| 24.5M/24.5M [00:13<00:00, 1.86MB/s]
# 24it [02:40,  8.02s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▍        | 1.42M/9.62M [00:00<00:01, 4.42MB/s]
# Uploading:  19%|█▉        | 1.86M/9.62M [00:00<00:01, 4.34MB/s]
# Uploading:  24%|██▎       | 2.28M/9.62M [00:00<00:02, 3.09MB/s]
# Uploading:  27%|██▋       | 2.62M/9.62M [00:00<00:02, 3.09MB/s]
# Uploading:  31%|███       | 2.94M/9.62M [00:01<00:02, 2.54MB/s]
# Uploading:  34%|███▍      | 3.27M/9.62M [00:01<00:02, 2.70MB/s]
# Uploading:  37%|███▋      | 3.55M/9.62M [00:01<00:02, 2.34MB/s]
# Uploading:  40%|███▉      | 3.81M/9.62M [00:01<00:02, 2.42MB/s]
# Uploading:  42%|████▏     | 4.06M/9.62M [00:01<00:02, 2.11MB/s]
# Uploading:  46%|████▌     | 4.39M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  48%|████▊     | 4.64M/9.62M [00:01<00:02, 2.00MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:01<00:02, 2.18MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  57%|█████▋    | 5.53M/9.62M [00:02<00:01, 2.16MB/s]
# Uploading:  62%|██████▏   | 5.92M/9.62M [00:02<00:01, 2.16MB/s]
# Uploading:  64%|██████▍   | 6.14M/9.62M [00:02<00:01, 2.16MB/s]
# Uploading:  67%|██████▋   | 6.45M/9.62M [00:02<00:01, 2.40MB/s]
# Uploading:  70%|██████▉   | 6.70M/9.62M [00:02<00:01, 2.01MB/s]
# Uploading:  73%|███████▎  | 7.06M/9.62M [00:02<00:01, 2.33MB/s]
# Uploading:  76%|███████▌  | 7.31M/9.62M [00:03<00:01, 2.04MB/s]
# Uploading:  80%|███████▉  | 7.66M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  82%|████████▏ | 7.91M/9.62M [00:03<00:00, 2.14MB/s]
# Uploading:  85%|████████▌ | 8.22M/9.62M [00:03<00:00, 2.33MB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:03<00:00, 2.38MB/s]
# Uploading:  91%|█████████ | 8.73M/9.62M [00:03<00:00, 2.21MB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  96%|█████████▌| 9.25M/9.62M [00:04<00:00, 2.01MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.03MB/s]
# 25it [02:45,  7.11s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.50M/9.62M [00:00<00:01, 5.08MB/s]
# Uploading:  21%|██        | 1.98M/9.62M [00:00<00:01, 4.85MB/s]
# Uploading:  25%|██▌       | 2.44M/9.62M [00:00<00:02, 3.26MB/s]
# Uploading:  30%|██▉       | 2.84M/9.62M [00:00<00:02, 2.84MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:00<00:02, 2.78MB/s]
# Uploading:  37%|███▋      | 3.53M/9.62M [00:01<00:02, 2.64MB/s]
# Uploading:  40%|███▉      | 3.81M/9.62M [00:01<00:02, 2.65MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:01<00:01, 2.85MB/s]
# Uploading:  47%|████▋     | 4.50M/9.62M [00:01<00:02, 2.53MB/s]
# Uploading:  51%|█████     | 4.86M/9.62M [00:01<00:01, 2.81MB/s]
# ...
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:05<00:01, 2.04MB/s]
# Uploading:  70%|███████   | 6.75M/9.62M [00:05<00:01, 2.06MB/s]
# Uploading:  73%|███████▎  | 7.05M/9.62M [00:06<00:01, 2.31MB/s]
# Uploading:  76%|███████▌  | 7.28M/9.62M [00:06<00:01, 1.95MB/s]
# Uploading:  78%|███████▊  | 7.53M/9.62M [00:06<00:01, 2.01MB/s]
# Uploading:  82%|████████▏ | 7.86M/9.62M [00:06<00:00, 2.23MB/s]
# Uploading:  84%|████████▍ | 8.09M/9.62M [00:06<00:00, 2.18MB/s]
# Uploading:  87%|████████▋ | 8.36M/9.62M [00:06<00:00, 2.20MB/s]
# Uploading:  89%|████████▉ | 8.58M/9.62M [00:06<00:00, 2.03MB/s]
# Uploading:  92%|█████████▏| 8.81M/9.62M [00:06<00:00, 2.13MB/s]
# Uploading:  95%|█████████▍| 9.09M/9.62M [00:07<00:00, 2.26MB/s]
# Uploading:  97%|█████████▋| 9.33M/9.62M [00:07<00:00, 2.16MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:08<00:00, 1.23MB/s]
# 72it [07:18,  6.84s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:02, 3.83MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:00<00:03, 2.57MB/s]
# Uploading:  27%|██▋       | 2.64M/9.62M [00:00<00:02, 2.70MB/s]
# Uploading:  30%|███       | 2.92M/9.62M [00:01<00:03, 2.30MB/s]
# Uploading:  33%|███▎      | 3.16M/9.62M [00:01<00:03, 2.26MB/s]
# Uploading:  35%|███▌      | 3.38M/9.62M [00:01<00:02, 2.20MB/s]
# Uploading:  37%|███▋      | 3.58M/9.62M [00:01<00:04, 1.44MB/s]
# Uploading:  40%|███▉      | 3.83M/9.62M [00:01<00:03, 1.58MB/s]
# Uploading:  42%|████▏     | 4.03M/9.62M [00:02<00:03, 1.64MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:02<00:03, 1.56MB/s]
# Uploading:  48%|████▊     | 4.58M/9.62M [00:02<00:02, 1.94MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:02<00:02, 1.75MB/s]
# Uploading:  52%|█████▏    | 5.02M/9.62M [00:02<00:02, 1.82MB/s]
# Uploading:  55%|█████▌    | 5.30M/9.62M [00:02<00:02, 2.02MB/s]
# Uploading:  57%|█████▋    | 5.50M/9.62M [00:02<00:02, 1.90MB/s]
# Uploading:  60%|██████    | 5.80M/9.62M [00:02<00:01, 2.02MB/s]
# Uploading:  63%|██████▎   | 6.03M/9.62M [00:03<00:01, 2.11MB/s]
# Uploading:  65%|██████▍   | 6.25M/9.62M [00:03<00:01, 2.12MB/s]
# Uploading:  67%|██████▋   | 6.47M/9.62M [00:03<00:01, 2.08MB/s]
# Uploading:  70%|██████▉   | 6.72M/9.62M [00:03<00:01, 2.22MB/s]
# Uploading:  72%|███████▏  | 6.95M/9.62M [00:03<00:01, 2.24MB/s]
# Uploading:  75%|███████▍  | 7.17M/9.62M [00:03<00:01, 2.10MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:03<00:01, 2.26MB/s]
# Uploading:  80%|███████▉  | 7.67M/9.62M [00:03<00:00, 2.19MB/s]
# Uploading:  82%|████████▏ | 7.89M/9.62M [00:03<00:00, 2.19MB/s]
# Uploading:  85%|████████▍ | 8.16M/9.62M [00:04<00:00, 2.34MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:04<00:00, 2.19MB/s]
# Uploading:  89%|████████▉ | 8.61M/9.62M [00:04<00:00, 2.20MB/s]
# Uploading:  92%|█████████▏| 8.88M/9.62M [00:04<00:00, 2.31MB/s]
# Uploading:  95%|█████████▍| 9.11M/9.62M [00:04<00:00, 2.12MB/s]
# Uploading:  98%|█████████▊| 9.39M/9.62M [00:04<00:00, 2.33MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.79MB/s]
# 73it [07:23,  6.47s/it]
# Uploading:   0%|          | 0.00/8.57M [00:00<?, ?B/s]
# Uploading:  19%|█▊        | 1.52M/8.18M [00:00<00:01, 3.98MB/s]
# Uploading:  24%|██▍       | 1.98M/8.18M [00:00<00:01, 3.92MB/s]
# Uploading:  29%|██▉       | 2.36M/8.18M [00:00<00:02, 2.67MB/s]
# Uploading:  35%|███▌      | 2.89M/8.18M [00:00<00:01, 2.91MB/s]
# Uploading:  39%|███▉      | 3.19M/8.18M [00:01<00:02, 2.36MB/s]
# Uploading:  43%|████▎     | 3.52M/8.18M [00:01<00:01, 2.52MB/s]
# Uploading:  46%|████▌     | 3.78M/8.18M [00:01<00:02, 2.03MB/s]
# Uploading:  53%|█████▎    | 4.30M/8.18M [00:01<00:01, 2.65MB/s]
# Uploading:  56%|█████▋    | 4.61M/8.18M [00:01<00:01, 2.15MB/s]
# Uploading:  62%|██████▏   | 5.05M/8.18M [00:02<00:01, 2.38MB/s]
# Uploading:  65%|██████▍   | 5.31M/8.18M [00:02<00:01, 2.17MB/s]
# Uploading:  71%|███████   | 5.81M/8.18M [00:02<00:00, 2.78MB/s]
# Uploading:  75%|███████▍  | 6.12M/8.18M [00:02<00:00, 2.24MB/s]
# Uploading:  78%|███████▊  | 6.39M/8.18M [00:02<00:00, 2.11MB/s]
# Uploading:  83%|████████▎ | 6.80M/8.18M [00:02<00:00, 2.53MB/s]
# Uploading:  87%|████████▋ | 7.08M/8.18M [00:02<00:00, 2.38MB/s]
# Uploading:  90%|████████▉ | 7.34M/8.18M [00:03<00:00, 2.40MB/s]
# Uploading:  94%|█████████▍| 7.70M/8.18M [00:03<00:00, 2.68MB/s]
# Uploading: 100%|██████████| 8.18M/8.18M [00:04<00:00, 2.05MB/s]
# 74it [07:28,  5.79s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  19%|█▉        | 1.88M/9.62M [00:00<00:01, 6.45MB/s]
# Uploading:  26%|██▌       | 2.50M/9.62M [00:00<00:01, 5.11MB/s]
# Uploading:  31%|███       | 2.95M/9.62M [00:00<00:01, 3.77MB/s]
# Uploading:  35%|███▍      | 3.34M/9.62M [00:00<00:01, 3.73MB/s]
# Uploading:  39%|███▊      | 3.72M/9.62M [00:00<00:01, 3.76MB/s]
# Uploading:  42%|████▏     | 4.08M/9.62M [00:01<00:01, 3.27MB/s]
# Uploading:  47%|████▋     | 4.55M/9.62M [00:01<00:01, 3.45MB/s]
# Uploading:  51%|█████     | 4.89M/9.62M [00:02<00:05, 948kB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:02<00:04, 1.01MB/s]
# Uploading:  60%|█████▉    | 5.75M/9.62M [00:03<00:03, 1.15MB/s]
# Uploading:  68%|██████▊   | 6.55M/9.62M [00:03<00:01, 1.82MB/s]
# Uploading:  71%|███████▏  | 6.88M/9.62M [00:03<00:01, 1.74MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:01, 1.93MB/s]
# Uploading:  78%|███████▊  | 7.50M/9.62M [00:03<00:01, 2.02MB/s]
# Uploading:  81%|████████  | 7.77M/9.62M [00:03<00:00, 2.09MB/s]
# Uploading:  84%|████████▍ | 8.11M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:04<00:00, 2.25MB/s]
# Uploading:  90%|████████▉ | 8.66M/9.62M [00:04<00:00, 2.37MB/s]
# Uploading:  93%|█████████▎| 8.94M/9.62M [00:04<00:00, 2.49MB/s]
# Uploading:  96%|█████████▌| 9.20M/9.62M [00:04<00:00, 2.41MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.85MB/s]
# 75it [07:33,  5.69s/it]
# Uploading:   0%|          | 0.00/8.33M [00:00<?, ?B/s]
# Uploading:  24%|██▍       | 1.89M/7.94M [00:00<00:01, 5.25MB/s]
# Uploading:  30%|███       | 2.41M/7.94M [00:00<00:01, 5.00MB/s]
# Uploading:  36%|███▌      | 2.88M/7.94M [00:00<00:01, 3.68MB/s]
# Uploading:  41%|████      | 3.22M/7.94M [00:00<00:01, 3.59MB/s]
# Uploading:  46%|████▌     | 3.67M/7.94M [00:01<00:01, 3.33MB/s]
# Uploading:  50%|█████     | 3.98M/7.94M [00:01<00:01, 2.87MB/s]
# Uploading:  54%|█████▎    | 4.27M/7.94M [00:01<00:01, 2.88MB/s]
# Uploading:  59%|█████▉    | 4.70M/7.94M [00:01<00:01, 3.27MB/s]
# Uploading:  63%|██████▎   | 5.03M/7.94M [00:01<00:01, 2.96MB/s]
# Uploading:  67%|██████▋   | 5.33M/7.94M [00:01<00:01, 2.61MB/s]
# Uploading:  70%|███████   | 5.59M/7.94M [00:01<00:01, 2.34MB/s]
# Uploading:  73%|███████▎  | 5.83M/7.94M [00:02<00:01, 1.69MB/s]
# Uploading:  79%|███████▉  | 6.30M/7.94M [00:02<00:00, 2.17MB/s]
# Uploading:  83%|████████▎ | 6.61M/7.94M [00:02<00:00, 2.38MB/s]
# Uploading:  87%|████████▋ | 6.88M/7.94M [00:02<00:00, 2.24MB/s]
# Uploading:  92%|█████████▏| 7.34M/7.94M [00:02<00:00, 2.70MB/s]
# Uploading: 100%|██████████| 7.94M/7.94M [00:06<00:00, 1.36MB/s]
# 76it [07:39,  5.83s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  15%|█▌        | 1.45M/9.62M [00:00<00:01, 4.97MB/s]
# Uploading:  20%|██        | 1.94M/9.62M [00:00<00:01, 4.67MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:00<00:02, 3.69MB/s]
# Uploading:  28%|██▊       | 2.72M/9.62M [00:00<00:02, 3.50MB/s]
# Uploading:  32%|███▏      | 3.11M/9.62M [00:00<00:01, 3.52MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:01<00:02, 2.84MB/s]
# Uploading:  39%|███▉      | 3.75M/9.62M [00:01<00:02, 2.80MB/s]
# Uploading:  42%|████▏     | 4.03M/9.62M [00:01<00:02, 2.82MB/s]
# Uploading:  45%|████▍     | 4.31M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  49%|████▊     | 4.69M/9.62M [00:01<00:01, 2.78MB/s]
# Uploading:  52%|█████▏    | 4.97M/9.62M [00:01<00:01, 2.55MB/s]
# Uploading:  54%|█████▍    | 5.23M/9.62M [00:01<00:01, 2.54MB/s]
# Uploading:  58%|█████▊    | 5.56M/9.62M [00:01<00:01, 2.73MB/s]
# Uploading:  61%|██████    | 5.84M/9.62M [00:02<00:01, 2.09MB/s]
# Uploading:  67%|██████▋   | 6.47M/9.62M [00:02<00:01, 2.86MB/s]
# Uploading:  70%|███████   | 6.78M/9.62M [00:02<00:01, 2.38MB/s]
# Uploading:  75%|███████▍  | 7.19M/9.62M [00:02<00:00, 2.74MB/s]
# Uploading:  78%|███████▊  | 7.55M/9.62M [00:02<00:00, 2.53MB/s]
# Uploading:  81%|████████▏ | 7.83M/9.62M [00:02<00:00, 2.62MB/s]
# Uploading:  86%|████████▌ | 8.27M/9.62M [00:02<00:00, 2.91MB/s]
# Uploading:  89%|████████▉ | 8.56M/9.62M [00:03<00:01, 977kB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.94MB/s]
# 77it [07:44,  5.64s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.39M/9.62M [00:00<00:02, 3.63MB/s]
# Uploading:  22%|██▏       | 2.12M/9.62M [00:00<00:02, 2.90MB/s]
# Uploading:  28%|██▊       | 2.70M/9.62M [00:00<00:02, 3.49MB/s]
# Uploading:  32%|███▏      | 3.12M/9.62M [00:01<00:02, 2.62MB/s]
# Uploading:  36%|███▌      | 3.44M/9.62M [00:01<00:02, 2.30MB/s]
# Uploading:  39%|███▉      | 3.73M/9.62M [00:01<00:02, 2.43MB/s]
# Uploading:  43%|████▎     | 4.12M/9.62M [00:01<00:02, 2.29MB/s]
# Uploading:  46%|████▌     | 4.41M/9.62M [00:01<00:02, 2.30MB/s]
# Uploading:  50%|████▉     | 4.78M/9.62M [00:01<00:01, 2.58MB/s]
# Uploading:  53%|█████▎    | 5.06M/9.62M [00:02<00:02, 2.30MB/s]
# Uploading:  56%|█████▌    | 5.38M/9.62M [00:02<00:01, 2.43MB/s]
# Uploading:  58%|█████▊    | 5.62M/9.62M [00:02<00:01, 2.15MB/s]
# Uploading:  63%|██████▎   | 6.02M/9.62M [00:02<00:01, 2.52MB/s]
# Uploading:  65%|██████▌   | 6.28M/9.62M [00:02<00:01, 2.15MB/s]
# Uploading:  68%|██████▊   | 6.53M/9.62M [00:02<00:01, 2.20MB/s]
# Uploading:  72%|███████▏  | 6.89M/9.62M [00:02<00:01, 2.50MB/s]
# Uploading:  74%|███████▍  | 7.16M/9.62M [00:03<00:01, 2.24MB/s]
# Uploading:  77%|███████▋  | 7.45M/9.62M [00:03<00:00, 2.37MB/s]
# Uploading:  80%|████████  | 7.70M/9.62M [00:03<00:00, 2.24MB/s]
# Uploading:  83%|████████▎ | 7.95M/9.62M [00:03<00:00, 2.28MB/s]
# Uploading:  86%|████████▌ | 8.25M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  88%|████████▊ | 8.48M/9.62M [00:03<00:00, 2.36MB/s]
# Uploading:  91%|█████████ | 8.72M/9.62M [00:03<00:00, 2.26MB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:03<00:00, 2.47MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:03<00:00, 2.43MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:04<00:00, 2.04MB/s]
# 78it [07:49,  5.43s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  16%|█▌        | 1.56M/9.62M [00:00<00:01, 4.36MB/s]
# Uploading:  23%|██▎       | 2.19M/9.62M [00:00<00:01, 4.95MB/s]
# Uploading:  28%|██▊       | 2.73M/9.62M [00:00<00:02, 3.24MB/s]
# Uploading:  32%|███▏      | 3.11M/9.62M [00:01<00:02, 2.50MB/s]
# Uploading:  37%|███▋      | 3.53M/9.62M [00:01<00:02, 2.76MB/s]
# Uploading:  40%|███▉      | 3.84M/9.62M [00:01<00:02, 2.40MB/s]
# Uploading:  44%|████▍     | 4.22M/9.62M [00:01<00:02, 2.64MB/s]
# Uploading:  47%|████▋     | 4.52M/9.62M [00:01<00:02, 2.18MB/s]
# Uploading:  51%|█████     | 4.89M/9.62M [00:01<00:01, 2.50MB/s]
# Uploading:  54%|█████▍    | 5.17M/9.62M [00:01<00:02, 2.33MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:02<00:01, 2.35MB/s]
# Uploading:  60%|██████    | 5.81M/9.62M [00:02<00:01, 2.46MB/s]
# Uploading:  63%|██████▎   | 6.06M/9.62M [00:02<00:01, 2.30MB/s]
# Uploading:  66%|██████▋   | 6.38M/9.62M [00:02<00:01, 2.47MB/s]
# Uploading:  69%|██████▉   | 6.62M/9.62M [00:02<00:01, 2.45MB/s]
# Uploading:  71%|███████▏  | 6.88M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  75%|███████▍  | 7.20M/9.62M [00:03<00:03, 805kB/s]
# Uploading:  84%|████████▎ | 8.05M/9.62M [00:03<00:01, 1.61MB/s]
# Uploading:  88%|████████▊ | 8.42M/9.62M [00:04<00:00, 1.60MB/s]
# Uploading:  91%|█████████ | 8.75M/9.62M [00:04<00:00, 1.61MB/s]
# Uploading:  94%|█████████▎| 9.02M/9.62M [00:04<00:00, 1.78MB/s]
# Uploading:  97%|█████████▋| 9.34M/9.62M [00:04<00:00, 1.80MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.84MB/s]
# 79it [07:55,  5.45s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  14%|█▍        | 1.36M/9.62M [00:00<00:01, 4.56MB/s]
# Uploading:  19%|█▊        | 1.80M/9.62M [00:00<00:02, 3.98MB/s]
# Uploading:  22%|██▏       | 2.16M/9.62M [00:00<00:02, 2.98MB/s]
# Uploading:  26%|██▌       | 2.48M/9.62M [00:00<00:02, 3.05MB/s]
# Uploading:  29%|██▉       | 2.78M/9.62M [00:00<00:02, 2.51MB/s]
# Uploading:  32%|███▏      | 3.11M/9.62M [00:01<00:02, 2.71MB/s]
# Uploading:  35%|███▌      | 3.39M/9.62M [00:01<00:02, 2.72MB/s]
# Uploading:  38%|███▊      | 3.67M/9.62M [00:01<00:02, 2.36MB/s]
# Uploading:  41%|████      | 3.95M/9.62M [00:01<00:02, 2.44MB/s]
# Uploading:  44%|████▎     | 4.20M/9.62M [00:01<00:02, 2.27MB/s]
# Uploading:  46%|████▋     | 4.47M/9.62M [00:01<00:02, 2.38MB/s]
# Uploading:  49%|████▉     | 4.75M/9.62M [00:01<00:02, 2.52MB/s]
# Uploading:  52%|█████▏    | 5.00M/9.62M [00:01<00:02, 2.30MB/s]
# Uploading:  55%|█████▍    | 5.28M/9.62M [00:02<00:01, 2.33MB/s]
# Uploading:  57%|█████▋    | 5.52M/9.62M [00:02<00:01, 2.18MB/s]
# Uploading:  61%|██████    | 5.83M/9.62M [00:02<00:01, 2.46MB/s]
# Uploading:  63%|██████▎   | 6.08M/9.62M [00:02<00:01, 2.41MB/s]
# Uploading:  66%|██████▌   | 6.33M/9.62M [00:02<00:01, 2.37MB/s]
# Uploading:  69%|██████▉   | 6.62M/9.62M [00:02<00:01, 2.49MB/s]
# Uploading:  72%|███████▏  | 6.91M/9.62M [00:02<00:01, 2.51MB/s]
# Uploading:  74%|███████▍  | 7.16M/9.62M [00:02<00:01, 2.36MB/s]
# Uploading:  77%|███████▋  | 7.44M/9.62M [00:02<00:00, 2.47MB/s]
# Uploading:  80%|███████▉  | 7.69M/9.62M [00:03<00:00, 2.32MB/s]
# Uploading:  82%|████████▏ | 7.92M/9.62M [00:03<00:00, 2.25MB/s]
# Uploading:  85%|████████▌ | 8.22M/9.62M [00:03<00:00, 2.47MB/s]
# Uploading:  88%|████████▊ | 8.47M/9.62M [00:03<00:00, 2.41MB/s]
# Uploading:  90%|█████████ | 8.70M/9.62M [00:03<00:00, 2.30MB/s]
# Uploading:  94%|█████████▍| 9.06M/9.62M [00:03<00:00, 2.67MB/s]
# Uploading:  97%|█████████▋| 9.33M/9.62M [00:03<00:00, 2.31MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.91MB/s]
# 80it [08:00,  5.40s/it]
# Uploading:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Uploading:  11%|█         | 1.06M/9.62M [00:00<00:02, 3.04MB/s]
# Uploading:  18%|█▊        | 1.73M/9.62M [00:00<00:03, 2.57MB/s]
# Uploading:  22%|██▏       | 2.08M/9.62M [00:00<00:02, 2.77MB/s]
# Uploading:  25%|██▍       | 2.38M/9.62M [00:01<00:03, 2.16MB/s]
# Uploading:  29%|██▊       | 2.77M/9.62M [00:01<00:02, 2.48MB/s]
# Uploading:  32%|███▏      | 3.05M/9.62M [00:01<00:03, 2.00MB/s]
# Uploading:  34%|███▍      | 3.30M/9.62M [00:01<00:03, 2.06MB/s]
# Uploading:  37%|███▋      | 3.52M/9.62M [00:01<00:03, 1.93MB/s]
# Uploading:  39%|███▉      | 3.77M/9.62M [00:01<00:02, 2.08MB/s]
# Uploading:  42%|████▏     | 4.03M/9.62M [00:01<00:02, 2.02MB/s]
# Uploading:  44%|████▍     | 4.23M/9.62M [00:01<00:02, 2.02MB/s]
# Uploading:  47%|████▋     | 4.48M/9.62M [00:02<00:02, 2.15MB/s]
# Uploading:  49%|████▉     | 4.70M/9.62M [00:02<00:02, 1.88MB/s]
# Uploading:  51%|█████     | 4.92M/9.62M [00:02<00:02, 1.95MB/s]
# Uploading:  54%|█████▍    | 5.20M/9.62M [00:02<00:02, 2.09MB/s]
# Uploading:  56%|█████▋    | 5.42M/9.62M [00:02<00:02, 1.97MB/s]
# Uploading:  59%|█████▉    | 5.67M/9.62M [00:02<00:02, 2.02MB/s]
# Uploading:  61%|██████    | 5.88M/9.62M [00:02<00:01, 1.99MB/s]
# Uploading:  63%|██████▎   | 6.09M/9.62M [00:02<00:01, 2.03MB/s]
# Uploading:  66%|██████▌   | 6.31M/9.62M [00:03<00:01, 2.09MB/s]
# Uploading:  68%|██████▊   | 6.52M/9.62M [00:03<00:01, 2.04MB/s]
# Uploading:  70%|███████   | 6.73M/9.62M [00:03<00:01, 2.07MB/s]
# Uploading:  72%|███████▏  | 6.94M/9.62M [00:03<00:01, 2.02MB/s]
# Uploading:  74%|███████▍  | 7.16M/9.62M [00:03<00:01, 2.07MB/s]
# Uploading:  76%|███████▋  | 7.36M/9.62M [00:03<00:01, 2.06MB/s]
# Uploading:  79%|███████▊  | 7.56M/9.62M [00:03<00:01, 2.08MB/s]
# Uploading:  81%|████████  | 7.77M/9.62M [00:03<00:00, 2.06MB/s]
# Uploading:  83%|████████▎ | 7.97M/9.62M [00:03<00:00, 2.03MB/s]
# Uploading:  85%|████████▍ | 8.17M/9.62M [00:04<00:00, 2.04MB/s]
# Uploading:  87%|████████▋ | 8.39M/9.62M [00:04<00:00, 1.96MB/s]
# Uploading:  90%|████████▉ | 8.66M/9.62M [00:04<00:00, 2.11MB/s]
# Uploading:  92%|█████████▏| 8.86M/9.62M [00:04<00:00, 2.11MB/s]
# Uploading:  94%|█████████▍| 9.06M/9.62M [00:04<00:00, 2.10MB/s]
# Uploading:  96%|█████████▋| 9.27M/9.62M [00:04<00:00, 2.09MB/s]
# Uploading: 100%|██████████| 9.62M/9.62M [00:05<00:00, 1.80MB/s]
# 81it [08:06,  6.00s/it]

# %%
# If you have a dem generated you can upload it so we dont need to reprocess.
ingest.upload_dem_to_db(method='agisoft',  # the method used to generate the dem.
                        dem_date='11/25/2024',  # the date the dem was generated.
                        file_name='dem.tif')
# Out:
# Saving to /Volumes/aps1_prod_tnau_fg_catalog_1336582592012881/tier1_raw/data/tnau-coimbatore/bets/2025:ind:maize:spring/west_field_03/section_b/drone/corn_health_assessment_flight/2024-11-25/dem/agisoft_2024-11-25/dem.tif
# Uploading:  30%|██▉       | 440M/1.45G [00:41<00:53, 20.4MB/s]

# %%
# f"{drone_flight_path}/orthomosaic/{method}_{date}/{image_name}"
ingest.upload_orthomosaic_to_db(method='agisoft',  # the method used to generate the ortho.
                                ortho_date='11/25/2024',  # the date the ortho was generated.
                                file_name='ms.tif')  # if RGB then you can name it rgb.tif
