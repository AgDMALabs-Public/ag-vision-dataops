# %%
from uuid import uuid4
import os
import pandas as pd
from databricks.sdk import WorkspaceClient

from ag_vision.drone.ingest import DroneDataIngest

# %%
w = WorkspaceClient(profile='agpile') # set your profile, if you only have one you can remove profile.
w.config.host

# %% [markdown]
# # Set the Variables below along with Metadata

# %%
FLIGHT_DATE = '11/25/2025'

YEAR = 2025
COUNTRY = 'IND' # Three letter coutry code.
CROP = 'maize'
CROP_GROWTH_STAGE = 'VT'
SEASON = 'spring'

TRIAL_NAME = 'BETS'
SITE = 'TNAU-Coimbatore'
FIELD = 'West_Field_03'
LOCATION = 'Section_B'

MISSION_NAME = 'corn_health_assessment_flight'
CAMERA_TYPE = 'multi-spec' # can be rgb or multi-spec


LOCAL_DATA_DIR = '/Users/danielwilliams/Documents/Field Data/drone_upload_test'
RAW_IMAGES_DIR = f'{LOCAL_DATA_DIR}/raw_flight_data/'
PLOT_BOUNDARY_FILE = f"{LOCAL_DATA_DIR}/plot_boundary.geojson"
GROUND_CONTROL_PT_FILE = f"{LOCAL_DATA_DIR}/gcp_details.geojson"
ORTHOMOSAIC_FILE = f"{LOCAL_DATA_DIR}/30112024_ORTHO.tif"
DEM_FILE = f"{LOCAL_DATA_DIR}/30112024_DSM.tif"

ORTHO_METHOD = 'agisoft'
ORTHO_DATE = '11/25/2024'

DB_VOLUME = '/Volumes/ue1_prod_catalog_119738067017277/tier1_raw/data'

flight_metadata = {
    "id": str(uuid4()),
    "name": MISSION_NAME,
    "task": "drone_phenotyping",
    "location": {
        "site": SITE.lower(),  # Try to keep these standard ORG-Site EX CIAT-Cali, or CIAT-Arusha....
        "field": FIELD.lower(),
        # what is the name of the field that the trial was run on? The field and location can be the same name if there is no difference.
        "location": LOCATION.lower()
        # The location corresponds to a specific field book. If data is in EBS match the location name.
    },
    "trialProperties": {
        "name": TRIAL_NAME
    },
    "drone_acquisition_properties": {
        'date': FLIGHT_DATE,
        'drone_make': "DJI",
        'drone_model': "Phantom Mavic 4 Enterprise",
        'camera_make': "Sony",
        'camera_model': "UCM-R",
        'groundControlPoints': True,
        'reflectancePanels': True,
        'reflectancePanelType': 'Micasense',
        'flightHeight': 90.0,
        'horizontalOverlapPercentage': 75.0,
        'verticalOverlapPercentage': 75.0,
        'gpsQuality': "RTK",
        'multispecChannels': ["Red", "Green", "Blue", "NIR"]
    },
    "agronomic_properties": {
        "crop_type": CROP,  # Required
        "growth_stage": CROP_GROWTH_STAGE,  # optional
        "soil_color": None,
        "weed_pressure": None,
        "irrigation_level": None,
        "tillage_type": None,
        "fertilizer_level": None
    }
}

# %% [markdown]
# # List out the flight data to upload.

# %%
files = os.listdir(RAW_IMAGES_DIR)
files = [RAW_IMAGES_DIR + x for x in files]
print(f"Number of files found {len(files)}")

# %% [markdown]
# # Start of the ingest process.

# %%
ingest = DroneDataIngest(platform='local',  # DONT CHANGE THIS
                         cloud_bucket=DB_VOLUME,
                         cloud_client=w, # should not need to change.
                         flight_date=FLIGHT_DATE,
                         plot_boundary_key=PLOT_BOUNDARY_FILE,
                         gcp_key=GROUND_CONTROL_PT_FILE,
                         orthomosaic_key=ORTHOMOSAIC_FILE,
                         dem_key=DEM_FILE,
                         flight_metadata_key=f"{LOCAL_DATA_DIR}/flight_details.json")

# %%
ingest.load_metadata_from_dict(metadata_dict=flight_metadata)

# season is needed to generate the mission dir, This has lots of Validation and will throw assert errors.
ingest.add_season_code_to_metadata(year=YEAR,
                                   country=COUNTRY,
                                   crop=CROP,
                                   time_of_year=SEASON)

# This is the main dir where all the data will be stored.
ingest.generate_drone_mission_dir_path()

# %%
# This saves the metadata locally do it can be uploaded.
ingest.save_flight_metadata_to_json_local()

# %%
# This will be a list of all the raw files from the flight eg: nav, bin, tif, and jpg files.
ingest.generate_raw_ingest_df(file_list=files)

# %%
ingest.raw_ingest_df['img_ext'].unique()

# %% [markdown]
# # Camera Logic.
# * This was needed to get the camera type since RGB and MS data was in the same folder.
# * If there is data from only one camera then we can just set camera with df['camera'] = CAMERA_TYPE

# %%
# Adding the camera col so the RGB and flight data will go into the RGB folder, and the MS and flight data will go into the multi-spec folder.
def determine_camera_type(f_name):
    if "_MS_" in f_name:
        return 'multi-spec'
    elif ".JPG" in f_name:
        return 'rgb'
    else:
        return 'flight_data'

ingest.raw_ingest_df['camera'] = ingest.raw_ingest_df['file_name'].apply(determine_camera_type)
flight_data = ingest.raw_ingest_df[ingest.raw_ingest_df['camera'] == 'flight_data']
flight_data.head()

# %%
f_ingest_df_list = []

# The flight data needs to be saved with both camera data sets.
for idx, df in ingest.raw_ingest_df.groupby('camera'):
    if idx in ['rgb', 'multi-spec']:
        out_df = pd.concat([df, flight_data])
        out_df['camera'] = idx
        f_ingest_df_list.append(out_df)

f_ingest_df = pd.concat(f_ingest_df_list)

# %%
ingest.raw_ingest_df = f_ingest_df

# %% [markdown]
# # Continuation of the code after the camera type logic for mixed camera folders.

# %%
# generates the new path names where to save it in databricks
ingest.generate_raw_image_dst_path_name()

# %%
# Upload the metadata to databricks
ingest.upload_metadata_to_db()

# %%
# uploads the plot boundaries to databricks
ingest.upload_plot_boundary_to_db()

# %%
# Uploads the ground control points to databricks
ingest.upload_gcp_to_db()

# %%
# uploads all the raw flight data to databricks
ingest.upload_raw_flight_data_to_db()

# %%
# If you have a dem generated, you can upload it so we don't need to reprocess.
ingest.upload_dem_to_db(method=ORTHO_METHOD,  # the method used to generate the dem.
                        dem_date=ORTHO_DATE,  # the date the dem was generated.
                        file_name='dem.tif')

# %%
# f"{drone_flight_path}/orthomosaic/{method}_{date}/{image_name}"
ingest.upload_orthomosaic_to_db(method=ORTHO_METHOD,  # the method used to generate the ortho.
                                ortho_date=ORTHO_DATE, # the date the ortho was generated.
                                camera=CAMERA_TYPE, # The camera that was used.
                                file_name=f'{CAMERA_TYPE}.tif')  # if RGB then you can name it rgb.tif
